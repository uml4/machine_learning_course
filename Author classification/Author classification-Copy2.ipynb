# %% [markdown]
# # 1. Introduction

# %% [markdown]
# Using NLP and techniques of supervised learning (including Deep
# Learning) and unsupervised learning (emphasizing on unsupervised
# for this project), and collect thousand texts from Gutenberg project
# (and 7 novels) for at least 10 authors, build a project to classify
# text-author. The project should follow the guideline as:
#
#     1. Pre-process data using Spacy and other methods.
#     2. Perform data exploration
#     3. Using Bag of Word, apply supervised models such as Naive
#     Bayes, Logistic Regression, Decision Tree, Random Forest,
#     KNN, SVM and Gradient Boosting, including GridSearchCV.
#     4. Similar to 3., but using TF-IDF.
#     5. Similar to 3., but using word2vec.
#     6. Appy RNN to do classification.
#     7. Using unsupervised technique, visualize bar graphs for clusters
#     containing 10 author documents. Adjust by silhouette scores.
#     8. Using LSA, LDA and NNMF, print out top ten words (with their
#     highest loading) for each topic modeling. Analyze and compare
#     among three methods.
#     9. Write up analysis and conclusions.

# %% [markdown]
# # 2. Import Library

# %%
import logging
import numpy as np
import pandas as pd
from time import time  # To time our operations
import nltk
from nltk.corpus import webtext
#to remove HTML tags from the doc
from bs4 import BeautifulSoup 
from nltk.corpus import stopwords
from nltk.corpus import gutenberg
import re
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split,StratifiedKFold
from sklearn import metrics
from sklearn.metrics import accuracy_score, f1_score

from sklearn.ensemble import RandomForestClassifier

from sklearn.naive_bayes import MultinomialNB
from sklearn.naive_bayes import BernoulliNB
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
# Grid search cross validation
from sklearn.model_selection import GridSearchCV

from collections import defaultdict  # For word frequency

# for visualise the word2vec model
import matplotlib.pyplot as plt
# %matplotlib inline
 
import seaborn as sns
sns.set_style("darkgrid")

from sklearn.decomposition import PCA
from sklearn.manifold import TSNE

# %% [markdown]
# # 3.  Download gutenberg

# %%
# nltk.download('gutenberg')
# Out:
# [nltk_data] Downloading package gutenberg to
# [nltk_data]     C:\Users\Owner\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\gutenberg.zip.
# True

# %%
gutenberg_files = nltk.corpus.gutenberg.fileids()
print(gutenberg_files)
# Out:
# ['austen-emma.txt', 'austen-persuasion.txt', 'austen-sense.txt', 'bible-kjv.txt', 'blake-poems.txt', 'bryant-stories.txt', 'burgess-busterbrown.txt', 'carroll-alice.txt', 'chesterton-ball.txt', 'chesterton-brown.txt', 'chesterton-thursday.txt', 'edgeworth-parents.txt', 'melville-moby_dick.txt', 'milton-paradise.txt', 'shakespeare-caesar.txt', 'shakespeare-hamlet.txt', 'shakespeare-macbeth.txt', 'whitman-leaves.txt']

# %%
len(gutenberg_files)
# Out:
# 18

# %%
blake_words = nltk.corpus.gutenberg.words('blake-poems.txt')
print(len(blake_words))
# Out:
# 8354

# %%
# nltk.download('punkt')
macbeth_sentences = gutenberg.sents('blake-poems.txt')
macbeth_sentences
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Owner\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# [['[', 'Poems', 'by', 'William', 'Blake', '1789', ']'], ['SONGS', 'OF', 'INNOCENCE', 'AND', 'OF', 'EXPERIENCE', 'and', 'THE', 'BOOK', 'of', 'THEL'], ...]

# %%
# macbeth_sentences[1]

# %%
# num_words = gutenberg.words('blake-poems.txt')

# %%
# num_words[1]

# %%
# nltk.corpus.gutenberg.raw('blake-poems.txt')

# %%
# html tags and comments are removed and stored in sample1

sample1 = BeautifulSoup(nltk.corpus.gutenberg.raw('blake-poems.txt') ,"html.parser")

# using get_text() we can see only text in html doc

print(sample1.get_text())
# Out:
# [Poems by William Blake 1789]
#
#
# SONGS OF INNOCENCE AND OF EXPERIENCE
# and THE BOOK of THEL
#
#
#  SONGS OF INNOCENCE
#
#
#  INTRODUCTION
#
#  Piping down the valleys wild,
#    Piping songs of pleasant glee,
#  On a cloud I saw a child,
#    And he laughing said to me:
#
#  "Pipe a song about a Lamb!"
#    So I piped with merry cheer.
#  "Piper, pipe that song again;"
#    So I piped: he wept to hear.
#
#  "Drop thy pipe, thy happy pipe;
#    Sing thy songs of happy cheer:!"
#  So I sang the same again,
#    While he wept with joy to hear.
#
#  "Piper, sit thee down and write
#    In a book, that all may read."
#  So he vanish'd from my sight;
#    And I pluck'd a hollow reed,
#
#  And I made a rural pen,
#    And I stain'd the water clear,
#  And I wrote my happy songs
#    Every child may joy to hear.
#
#
#  THE SHEPHERD
#
#  How sweet is the Shepherd's sweet lot!
#  From the morn to the evening he stays;
#  He shall follow his sheep all the day,
#  And his tongue shall be filled with praise.
#
#  For he hears the lambs' innocent call,
#  And he hears the ewes' tender reply;
#  He is watching while they are in peace,
#  For they know when their Shepherd is nigh.
#
#
#  THE ECHOING GREEN
#
#  The sun does arise,
#  And make happy the skies;
#  The merry bells ring
#  To welcome the Spring;
#  The skylark and thrush,
#  The birds of the bush,
#  Sing louder around
#  To the bells' cheerful sound;
#  While our sports shall be seen
#  On the echoing Green.
#
#  Old John, with white hair,
#  Does laugh away care,
#  Sitting under the oak,
#  Among the old folk.
#  They laugh at our play,
#  And soon they all say,
#  "Such, such were the joys
#  When we all -- girls and boys --
#  In our youth-time were seen
#  On the echoing Green."
#
#  Till the little ones, weary,
#  No more can be merry:
#  The sun does descend,
#  And our sports have an end.
#  Round the laps of their mothers
#  Many sisters and brothers,
#  Like birds in their nest,
#  Are ready for rest,
#  And sport no more seen
#  On the darkening green.
#
#
#  THE LAMB
#
#    Little Lamb, who make thee
#    Dost thou know who made thee,
#  Gave thee life, and bid thee feed
#  By the stream and o'er the mead;
#  Gave thee clothing of delight,
#  Softest clothing, wolly, bright;
#  Gave thee such a tender voice,
#  Making all the vales rejoice?
#    Little Lamb, who made thee?
#    Dost thou know who made thee?
#
#    Little Lamb, I'll tell thee;
#    Little Lamb, I'll tell thee:
#  He is called by thy name,
#  For He calls Himself a Lamb
#  He is meek, and He is mild,
#  He became a little child.
#  I a child, and thou a lamb,
#  We are called by His name.
#    Little Lamb, God bless thee!
#    Little Lamb, God bless thee!
#
#
#  THE LITTLE BLACK BOY
#
#  My mother bore me in the southern wild,
#    And I  am black, but oh my soul is white!
#  White as an angel is the English child,
#    But I am black, as if bereaved of light.
#
#  My mother taught me underneath a tree,
#    And, sitting down before the heat of day,
#  She took me on her lap and kissed me,
#    And, pointed to the east, began to say:
#
#  "Look on the rising sun: there God does live,
#    And gives His light, and gives His heat away,
#  And flowers and trees and beasts and men receive
#    Comfort in morning, joy in the noonday.
#
#  "And we are put on earth a little space,
#    That we may learn to bear the beams of love
#  And these black bodies and this sunburnt face
#    Is but a cloud, and like a shady grove.
#
#  "For when our souls have learn'd the heat to bear,
#    The cloud will vanish, we shall hear His voice,
#  Saying, 'Come out from the grove, my love and care
#    And round my golden tent like lambs rejoice',"
#
#  Thus did my mother say, and kissed me;
#  And thus I say to little English boy.
#  When I from black and he from white cloud free,
#  And round the tent of God like lambs we joy
#
#  I'll shade him from the heat till he can bear
#  To lean in joy upon our Father's knee;
#  And then I'll stand and stroke his silver hair,
#  And be like him, and he will then love me.
#
#
#  THE BLOSSOM
#
#  Merry, merry sparrow!
#  Under leaves so green
#  A happy blossom
#  Sees you, swift as arrow,
#  Seek your cradle narrow,
#  Near my bosom.
#  Pretty, pretty robin!
#  Under leaves so green
#  A happy blossom
#  Hears you sobbing, sobbing,
#  Pretty, pretty robin,
#  Near my bosom.
#
#
#  THE CHIMNEY-SWEEPER
#
#  When my mother died I was very young,
#  And my father sold me while yet my tongue
#  Could scarcely cry "Weep! weep! weep! weep!"
#  So your chimneys I sweep, and in soot I sleep.
#
#  There's little Tom Dacre, who cried when his head,
#  That curled like a lamb's back, was shaved; so I said,
#  "Hush, Tom! never mind it, for, when your head's bare,
#  You know that the soot cannot spoil your white hair."
#
#  And so he was quiet, and that very night,
#  As Tom was a-sleeping, he had such a sight! --
#  That thousands of sweepers, Dick, Joe, Ned, and Jack,
#  Were all of them locked up in coffins of black.
#
#  And by came an angel, who had a bright key,
#  And he opened the coffins, and let them all free;
#  Then down a green plain, leaping, laughing, they run,
#  And wash in a river, and shine in the sun.
#
#  Then naked and white, all their bags left behind,
#  They rise upon clouds, and sport in the wind;
#  And the Angel told Tom, if he'd be a good boy,
#  He'd have God for his father, and never want joy.
#
#  And so Tom awoke, and we rose in the dark,
#  And got with our bags and our brushes to work.
#  Though the morning was cold, Tom was happy and warm:
#  So, if all do their duty, they need not fear harm.
#
#
#  THE LITTLE BOY LOST
#
#  "Father, father, where are you going?
#    Oh do not walk so fast!
#  Speak, father, speak to you little boy,
#    Or else I shall be lost."
#
#  The night was dark, no father was there,
#    The child was wet with dew;
#  The mire was deep, and the child did weep,
#    And away the vapour flew.
#
#
#  THE LITTLE BOY FOUND
#
#  The little boy lost in the lonely fen,
#    Led by the wandering light,
#  Began to cry, but God, ever nigh,
#    Appeared like his father, in white.
#
#  He kissed the child, and by the hand led,
#    And to his mother brought,
#  Who in sorrow pale, through the lonely dale,
#    The little boy weeping sought.
#
#
#  LAUGHING SONG
#
#  When the green woods laugh with the voice of joy,
#  And the dimpling stream runs laughing by;
#  When the air does laugh with our merry wit,
#  And the green hill laughs with the noise of it;
#
#  when the meadows laugh with lively green,
#  And the grasshopper laughs in the merry scene,
#  When Mary and Susan and Emily
#  With their sweet round mouths sing "Ha, ha he!"
#
#  When the painted birds laugh in the shade,
#  Where our table with cherries and nuts is spread:
#  Come live, and be merry, and join with me,
#  To sing the sweet chorus of "Ha, ha, he!"
#
#
#  A  SONG
#
#  Sweet dreams, form a shade
#  O'er my lovely infant's head!
#  Sweet dreams of pleasant streams
#  By happy, silent, moony beams!
#
#  Sweet Sleep, with soft down
#  Weave thy brows an infant crown
#  Sweet Sleep, angel mild,
#  Hover o'er my happy child!
#
#  Sweet smiles, in the night
#  Hover over my delight!
#  Sweet smiles, mother's smile,
#  All the livelong night beguile.
#
#  Sweet moans, dovelike sighs,
#  Chase not slumber from thine eyes!
#  Sweet moan, sweeter smile,
#  All the dovelike moans beguile.
#
#  Sleep, sleep, happy child!
#  All creation slept and smiled.
#  Sleep, sleep, happy sleep,
#  While o'er thee doth mother weep.
#
#  Sweet babe, in thy face
#  Holy image I can trace;
#  Sweet babe, once like thee
#  Thy Maker lay, and wept for me:
#
#  Wept for me, for thee, for all,
#  When He was an infant small.
#  Thou His image ever see,
#  Heavenly face that smiles on thee!
#
#  Smiles on thee, on me, on all,
#  Who became an infant small;
#  Infant smiles are his own smiles;
#  Heaven and earth to peace beguiles.
#
#
#  DIVINE IMAGE
#
#  To Mercy, Pity, Peace, and Love,
#    All pray in their distress,
#  And to these virtues of delight
#    Return their thankfulness.
#
#  For Mercy, Pity, Peace, and Love,
#    Is God our Father dear;
#  And Mercy, Pity, Peace, and Love,
#    Is man, his child and care.
#
#  For Mercy has a human heart
#    Pity, a human face;
#  And Love, the human form divine;
#    And Peace, the human dress.
#
#  Then every man, of every clime,
#    That prays in his distress,
#  Prays to the human form divine:
#    Love, Mercy, Pity, Peace.
#
#  And all must love the human form,
#    In heathen, Turk, or Jew.
#  Where Mercy, Love, and Pity dwell,
#    There God is dwelling too.
#
#
#  HOLY THURSDAY
#
#  'Twas on a Holy Thursday, their innocent faces clean,
#  Came children walking two and two, in read, and blue, and green:
#  Grey-headed beadles walked before, with wands as white as snow,
#  Till into the high dome of Paul's they like Thames waters flow.
#
#  Oh what a multitude they seemed, these flowers of London town!
#  Seated in companies they sit, with radiance all their own.
#  The hum of multitudes was there, but multitudes of lambs,
#  Thousands of little boys and girls raising their innocent hands.
#
#  Now like a mighty wild they raise to heaven the voice of song,
#  Or like harmonious thunderings the seats of heaven among:
#  Beneath them sit the aged man, wise guardians of the poor.
#  Then cherish pity, lest you drive an angel from your door.
#
#
#  NIGHT
#
#  The sun descending in the west,
#  The evening star does shine;
#  The birds are silent in their nest,
#  And I must seek for mine.
#    The moon, like a flower
#    In heaven's high bower,
#    With silent delight,
#    Sits and smiles on the night.
#
#  Farewell, green fields and happy grove,
#  Where flocks have ta'en delight.
#  Where lambs have nibbled, silent move
#  The feet of angels bright;
#    Unseen they pour blessing,
#    And joy without ceasing,
#    On each bud and blossom,
#    And each sleeping bosom.
#
#  They look in every thoughtless nest
#  Where birds are covered warm;
#  They visit caves of every beast,
#  To keep them all from harm:
#    If they see any weeping
#    That should have been sleeping,
#    They pour sleep on their head,
#    And sit down by their bed.
#
#  When wolves and tigers howl for prey,
#  They pitying stand and weep;
#  Seeking to drive their thirst away,
#  And keep them from the sheep.
#    But, if they rush dreadful,
#    The angels, most heedful,
#    Receive each mild spirit,
#    New worlds to inherit.
#
#
#  And there the lion's ruddy eyes
#  Shall flow with tears of gold:
#  And pitying the tender cries,
#  And walking round the fold:
#    Saying: "Wrath by His meekness,
#    And, by His health, sickness,
#    Are driven away
#    From our immortal day.
#
#  "And now beside thee, bleating lamb,
#  I can lie down and sleep,
#  Or think on Him who bore thy name,
#  Graze after thee, and weep.
#    For, washed in life's river,
#    My bright mane for ever
#    Shall shine like the gold,
#    As I guard o'er the fold."
#
#
#  SPRING
#
#       Sound the flute!
#       Now it's mute!
#       Bird's delight,
#       Day and night,
#       Nightingale,
#       In the dale,
#       Lark in sky,--
#       Merrily,
#  Merrily merrily, to welcome in the year.
#
#       Little boy,
#       Full of joy;
#       Little girl,
#       Sweet and small;
#       Cock does crow,
#       So do you;
#       Merry voice,
#       Infant noise;
#  Merrily, merrily, to welcome in the year.
#
#       Little lamb,
#       Here I am;
#       Come and lick
#       My white neck;
#       Let me pull
#       Your soft wool;
#       Let me kiss
#       Your soft face;
#  Merrily, merrily, to welcome in the year.
#
#
#  NURSE'S SONG
#
#  When the voices of children are heard on the green,
#    And laughing is heard on the hill,
#  My heart is at rest within my breast,
#    And everything else is still.
#  "Then come home, my children, the sun is gone down,
#    And the dews of night arise;
#  Come, come, leave off play, and let us away,
#    Till the morning appears in the skies."
#
#  "No, no, let us play, for it is yet day,
#    And we cannot go to sleep;
#  Besides, in the sky the little birds fly,
#    And the hills are all covered with sheep."
#  "Well, well, go and play till the light fades away,
#    And then go home to bed."
#  The little ones leaped, and shouted, and laughed,
#    And all the hills echoed.
#
#
#  INFANT JOY
#
#  "I have no name;
#  I am but two days old."
#  What shall I call thee?
#  "I happy am,
#  Joy is my name."
#  Sweet joy befall thee!
#
#  Pretty joy!
#  Sweet joy, but two days old.
#  Sweet Joy I call thee:
#  Thou dost smile,
#  I sing the while;
#  Sweet joy befall thee!
#
#
#  A DREAM
#
#  Once a dream did weave a shade
#  O'er my angel-guarded bed,
#  That an emmet lost its way
#  Where on grass methought I lay.
#
#  Troubled, wildered, and forlorn,
#  Dark, benighted, travel-worn,
#  Over many a tangle spray,
#  All heart-broke, I heard her say:
#
#  "Oh my children! do they cry,
#  Do they hear their father sigh?
#  Now they look abroad to see,
#  Now return and weep for me."
#
#  Pitying, I dropped a tear:
#  But I saw a glow-worm near,
#  Who replied, "What wailing wight
#  Calls the watchman of the night?
#
#  "I am set to light the ground,
#  While the beetle goes his round:
#  Follow now the beetle's hum;
#  Little wanderer, hie thee home!"
#
#
#  ON ANOTHER'S SORROW
#
#  Can I see another's woe,
#  And not be in sorrow too?
#  Can I see another's grief,
#  And not seek for kind relief?
#
#  Can I see a falling tear,
#  And not feel my sorrow's share?
#  Can a father see his child
#  Weep, nor be with sorrow filled?
#
#  Can a mother sit and hear
#  An infant groan, an infant fear?
#  No, no!  never can it be!
#  Never, never can it be!
#
#  And can He who smiles on all
#  Hear the wren with sorrows small,
#  Hear the small bird's grief and care,
#  Hear the woes that infants bear --
#
#  And not sit beside the next,
#  Pouring pity in their breast,
#  And not sit the cradle near,
#  Weeping tear on infant's tear?
#
#  And not sit both night and day,
#  Wiping all our tears away?
#  Oh no! never can it be!
#  Never, never can it be!
#
#  He doth give his joy to all:
#  He becomes an infant small,
#  He becomes a man of woe,
#  He doth feel the sorrow too.
#
#  Think not thou canst sigh a sigh,
#  And thy Maker is not by:
#  Think not thou canst weep a tear,
#  And thy Maker is not year.
#
#  Oh He gives to us his joy,
#  That our grief He may destroy:
#  Till our grief is fled an gone
#  He doth sit by us and moan.
#
#
#  SONGS OF EXPERIENCE
#
#
#  INTRODUCTION
#
#  Hear the voice of the Bard,
#  Who present, past, and future, sees;
#  Whose ears have heard
#  The Holy Word
#  That walked among the ancient tree;
#
#  Calling the lapsed soul,
#  And weeping in the evening dew;
#  That might control
#  The starry pole,
#  And fallen, fallen light renew!
#
#  "O Earth, O Earth, return!
#  Arise from out the dewy grass!
#  Night is worn,
#  And the morn
#  Rises from the slumbrous mass.
#
#  "Turn away no more;
#  Why wilt thou turn away?
#  The starry floor,
#  The watery shore,
#  Are given thee till the break of day."
#
#
#  EARTH'S ANSWER
#
#  Earth raised up her head
#  From the darkness dread and drear,
#  Her light fled,
#  Stony, dread,
#  And her locks covered with grey despair.
#
#  "Prisoned on watery shore,
#  Starry jealousy does keep my den
#  Cold and hoar;
#  Weeping o're,
#  I hear the father of the ancient men.
#
#  "Selfish father of men!
#  Cruel, jealous, selfish fear!
#  Can delight,
#  Chained in night,
#  The virgins of youth and morning bear?
#
#
#  "Does spring hide its joy,
#  When buds and blossoms grow?
#  Does the sower
#  Sow by night,
#  Or the plowman in darkness plough?
#
#  "Break this heavy chain,
#  That does freeze my bones around!
#  Selfish, vain,
#  Eternal bane,
#  That free love with bondage bound."
#
#
#  THE CLOD AND THE PEBBLE
#
#  "Love seeketh not itself to please,
#    Nor for itself hath any care,
#  But for another gives it ease,
#    And builds a heaven in hell's despair."
#
#  So sang a little clod of clay,
#    Trodden with the cattle's feet,
#  But a pebble of the brook
#    Warbled out these metres meet:
#
#  "Love seeketh only Self to please,
#    To bind another to its delight,
#  Joys in another's loss of ease,
#    And builds a hell in heaven's despite."
#
#
#  HOLY THURSDAY
#
#  Is this a holy thing to see
#    In a rich and fruitful land, --
#  Babes reduced to misery,
#    Fed with cold and usurous hand?
#
#  Is that trembling cry a song?
#    Can it be a song of joy?
#  And so many children poor?
#    It is a land of poverty!
#
#  And their son does never shine,
#    And their fields are bleak and bare,
#  And their ways are filled with thorns:
#    It is eternal winter there.
#
#  For where'er the sun does shine,
#    And where'er the rain does fall,
#  Babes should never hunger there,
#    Nor poverty the mind appall.
#
#
#  THE LITTLE GIRL LOST
#
#  In futurity
#  I prophetic see
#  That the earth from sleep
#  (Grave the sentence deep)
#
#  Shall arise, and seek
#  for her Maker meek;
#  And the desert wild
#  Become a garden mild.
#
#  In the southern clime,
#  Where the summer's prime
#  Never fades away,
#  Lovely Lyca lay.
#
#  Seven summers old
#  Lovely Lyca told.
#  She had wandered long,
#  Hearing wild birds' song.
#
#  "Sweet sleep, come to me
#  Underneath this tree;
#  Do father, mother, weep?
#  Where can Lyca sleep?
#
#  "Lost in desert wild
#  Is your little child.
#  How can Lyca sleep
#  If her mother weep?
#
#  "If her heart does ache,
#  Then let Lyca wake;
#  If my mother sleep,
#  Lyca shall not weep.
#
#  "Frowning, frowning night,
#  O'er this desert bright
#  Let thy moon arise,
#  While I close my eyes."
#
#  Sleeping Lyca lay
#  While the beasts of prey,
#  Come from caverns deep,
#  Viewed the maid asleep.
#
#  The kingly lion stood,
#  And the virgin viewed:
#  Then he gambolled round
#  O'er the hallowed ground.
#
#  Leopards, tigers, play
#  Round her as she lay;
#  While the lion old
#  Bowed his mane of gold,
#
#  And her breast did lick
#  And upon her neck,
#  From his eyes of flame,
#  Ruby tears there came;
#
#  While the lioness
#  Loosed her slender dress,
#  And naked they conveyed
#  To caves the sleeping maid.
#
#
#  THE LITTLE GIRL FOUND
#
#  All the night in woe
#  Lyca's parents go
#  Over valleys deep,
#  While the deserts weep.
#
#  Tired and woe-begone,
#  Hoarse with making moan,
#  Arm in arm, seven days
#  They traced the desert ways.
#
#  Seven nights they sleep
#  Among shadows deep,
#  And dream they see their child
#  Starved in desert wild.
#
#  Pale through pathless ways
#  The fancied image strays,
#  Famished, weeping, weak,
#  With hollow piteous shriek.
#
#  Rising from unrest,
#  The trembling woman presse
#  With feet of weary woe;
#  She could no further go.
#
#  In his arms he bore
#  Her, armed with sorrow sore;
#  Till before their way
#  A couching lion lay.
#
#  Turning back was vain:
#  Soon his heavy mane
#  Bore them to the ground,
#  Then he stalked around,
#
#  Smelling to his prey;
#  But their fears allay
#  When he licks their hands,
#  And silent by them stands.
#
#  They look upon his eyes,
#  Filled with deep surprise;
#  And wondering behold
#  A spirit armed in gold.
#
#  On his head a crown,
#  On his shoulders down
#  Flowed his golden hair.
#  Gone was all their care.
#
#  "Follow me," he said;
#  "Weep not for the maid;
#  In my palace deep,
#  Lyca lies asleep."
#
#  Then they followed
#  Where the vision led,
#  And saw their sleeping child
#  Among tigers wild.
#
#  To this day they dwell
#  In a lonely dell,
#  Nor fear the wolvish howl
#  Nor the lion's growl.
#
#
#  THE CHIMNEY SWEEPER
#
#  A little black thing in the snow,
#  Crying "weep! weep!" in notes of woe!
#  "Where are thy father and mother? Say!"--
#  "They are both gone up to the church to pray.
#
#  "Because I was happy upon the heath,
#  And smiled among the winter's snow,
#  They clothed me in the clothes of death,
#  And taught me to sing the notes of woe.
#
#  "And because I am happy and dance and sing,
#  They think they have done me no injury,
#  And are gone to praise God and his priest and king,
#  Who make up a heaven of our misery."
#
#
#  NURSE'S SONG
#
#  When voices of children are heard on the green,
#  And whisperings are in the dale,
#  The days of my youth rise fresh in my mind,
#  My face turns green and pale.
#
#  Then come home, my children, the sun is gone down,
#  And the dews of night arise;
#  Your spring and your day are wasted in play,
#  And your winter and night in disguise.
#
#
#  THE SICK ROSE
#
#  O rose, thou art sick!
#    The invisible worm,
#  That flies in the night,
#    In the howling storm,
#
#  Has found out thy bed
#    Of crimson joy,
#  And his dark secret love
#    Does thy life destroy.
#
#
#  THE FLY
#
#  Little Fly,
#  Thy summer's play
#  My thoughtless hand
#  Has brushed away.
#
#  Am not I
#  A fly like thee?
#  Or art not thou
#  A man like me?
#
#  For I dance
#  And drink, and sing,
#  Till some blind hand
#  Shall brush my wing.
#
#  If thought is life
#  And strength and breath
#  And the want
#  Of thought is death;
#
#  Then am I
#  A happy fly,
#  If I live,
#  Or if I die.
#
#
#  THE ANGEL
#
#  I dreamt a dream!  What can it mean?
#  And that I was a maiden Queen
#  Guarded by an Angel mild:
#  Witless woe was ne'er beguiled!
#
#  And I wept both night and day,
#  And he wiped my tears away;
#  And I wept both day and night,
#  And hid from him my heart's delight.
#
#  So he took his wings, and fled;
#  Then the morn blushed rosy red.
#  I dried my tears, and armed my fears
#  With ten-thousand shields and spears.
#
#  Soon my Angel came again;
#  I was armed, he came in vain;
#  For the time of youth was fled,
#  And grey hairs were on my head.
#
#
#  THE TIGER
#
#  Tiger, tiger, burning bright
#  In the forest of the night,
#  What immortal hand or eye
#  Could Frame thy fearful symmetry?
#
#  In what distant deeps or skies
#  Burnt the fire of thine eyes?
#  On what wings dare he aspire?
#  What the hand dare seize the fire?
#
#  And what shoulder and what art
#  Could twist the sinews of thy heart?
#  And, when thy heart began to beat,
#  What dread hand and what dread feet?
#
#  What the hammer?  what the chain?
#  In what furnace was thy brain?
#  What the anvil? what dread grasp
#  Dare its deadly terrors clasp?
#
#  When the stars threw down their spears,
#  And watered heaven with their tears,
#  Did he smile his work to see?
#  Did he who made the lamb make thee?
#
#  Tiger, tiger, burning bright
#  In the forests of the night,
#  What immortal hand or eye
#  Dare frame thy fearful symmetry?
#
#
#  MY PRETTY ROSE TREE
#
#  A flower was offered to me,
#    Such a flower as May never bore;
#  But I said "I've a pretty rose tree,"
#    And I passed the sweet flower o'er.
#
#  Then I went to my pretty rose tree,
#    To tend her by day and by night;
#  But my rose turned away with jealousy,
#    And her thorns were my only delight.
#
#
#  AH SUNFLOWER
#
#  Ah Sunflower, weary of time,
#    Who countest the steps of the sun;
#  Seeking after that sweet golden clime
#    Where the traveller's journey is done;
#
#  Where the Youth pined away with desire,
#    And the pale virgin shrouded in snow,
#  Arise from their graves, and aspire
#    Where my Sunflower wishes to go!
#
#
#  THE LILY
#
#  The modest Rose puts forth a thorn,
#  The humble sheep a threat'ning horn:
#  While the Lily white shall in love delight,
#  Nor a thorn nor a threat stain her beauty bright.
#
#
#  THE GARDEN OF LOVE
#
#  I laid me down upon a bank,
#    Where Love lay sleeping;
#  I heard among the rushes dank
#    Weeping, weeping.
#
#  Then I went to the heath and the wild,
#    To the thistles and thorns of the waste;
#  And they told me how they were beguiled,
#    Driven out, and compelled to the chaste.
#
#  I went to the Garden of Love,
#    And saw what I never had seen;
#  A Chapel was built in the midst,
#    Where I used to play on the green.
#
#  And the gates of this Chapel were shut
#    And "Thou shalt not," writ over the door;
#  So I turned to the Garden of Love
#    That so many sweet flowers bore.
#
#  And I saw it was filled with graves,
#    And tombstones where flowers should be;
#  And priests in black gowns were walking their rounds,
#    And binding with briars my joys and desires.
#
#
#  THE LITTLE VAGABOND
#
#  Dear mother, dear mother, the Church is cold;
#  But the Alehouse is healthy, and pleasant, and warm.
#  Besides, I can tell where I am used well;
#  The poor parsons with wind like a blown bladder swell.
#
#  But, if at the Church they would give us some ale,
#  And a pleasant fire our souls to regale,
#  We'd sing and we'd pray all the livelong day,
#  Nor ever once wish from the Church to stray.
#
#  Then the Parson might preach, and drink, and sing,
#  And we'd be as happy as birds in the spring;
#  And modest Dame Lurch, who is always at church,
#  Would not have bandy children, nor fasting, nor birch.
#
#  And God, like a father, rejoicing to see
#  His children as pleasant and happy as he,
#  Would have no more quarrel with the Devil or the barrel,
#  But kiss him, and give him both drink and apparel.
#
#
#  LONDON
#
#  I wandered through each chartered street,
#    Near where the chartered Thames does flow,
#  A mark in every face I meet,
#    Marks of weakness, marks of woe.
#
#  In every cry of every man,
#    In every infant's cry of fear,
#  In every voice, in every ban,
#    The mind-forged manacles I hear:
#
#  How the chimney-sweeper's cry
#    Every blackening church appals,
#  And the hapless soldier's sigh
#    Runs in blood down palace-walls.
#
#  But most, through midnight streets I hear
#    How the youthful harlot's curse
#  Blasts the new-born infant's tear,
#    And blights with plagues the marriage-hearse.
#
#
#  THE HUMAN ABSTRACT
#
#  Pity would be no more
#  If we did not make somebody poor,
#  And Mercy no more could be
#  If all were as happy as we.
#
#  And mutual fear brings Peace,
#  Till the selfish loves increase
#  Then Cruelty knits a snare,
#  And spreads his baits with care.
#
#  He sits down with his holy fears,
#  And waters the ground with tears;
#  Then Humility takes its root
#  Underneath his foot.
#
#  Soon spreads the dismal shade
#  Of Mystery over his head,
#  And the caterpillar and fly
#  Feed on the Mystery.
#
#  And it bears the fruit of Deceit,
#  Ruddy and sweet to eat,
#  And the raven his nest has made
#  In its thickest shade.
#
#  The gods of the earth and sea
#  Sought through nature to find this tree,
#  But their search was all in vain:
#  There grows one in the human Brain.
#
#
#  INFANT SORROW
#
#  My mother groaned, my father wept:
#  Into the dangerous world I leapt,
#  Helpless, naked, piping loud,
#  Like a fiend hid in a cloud.
#
#  Struggling in my father's hands,
#  Striving against my swaddling-bands,
#  Bound and weary, I thought best
#  To sulk upon my mother's breast.
#
#
#  A POISON TREE
#
#  I was angry with my friend:
#  I told my wrath, my wrath did end.
#  I was angry with my foe:
#  I told it not, my wrath did grow.
#
#  And I watered it in fears
#  Night and morning with my tears,
#  And I sunned it with smiles
#  And with soft deceitful wiles.
#
#  And it grew both day and night,
#  Till it bore an apple bright,
#  And my foe beheld it shine,
#  and he knew that it was mine, --
#
#  And into my garden stole
#  When the night had veiled the pole;
#  In the morning, glad, I see
#  My foe outstretched beneath the tree.
#
#
#  A LITTLE BOY LOST
#
#  "Nought loves another as itself,
#    Nor venerates another so,
#  Nor is it possible to thought
#    A greater than itself to know.
#
#  "And, father, how can I love you
#    Or any of my brothers more?
#  I love you like the little bird
#    That picks up crumbs around the door."
#
#  The Priest sat by and heard the child;
#    In trembling zeal he seized his hair,
#  He led him by his little coat,
#    And all admired the priestly care.
#
#  And standing on the altar high,
#    "Lo, what a fiend is here! said he:
#  "One who sets reason up for judge
#    Of our most holy mystery."
#
#  The weeping child could not be heard,
#    The weeping parents wept in vain:
#  They stripped him to his little shirt,
#    And bound him in an iron chain,
#
#  And burned him in a holy place
#    Where many had been burned before;
#  The weeping parents wept in vain.
#    Are such thing done on Albion's shore?
#
#
#  A LITTLE GIRL LOST
#
#  Children of the future age,
#  Reading this indignant page,
#  Know that in a former time
#  Love, sweet love, was thought a crime.
#
#  In the age of gold,
#  Free from winter's cold,
#  Youth and maiden bright,
#  To the holy light,
#  Naked in the sunny beams delight.
#
#  Once a youthful pair,
#  Filled with softest care,
#  Met in garden bright
#  Where the holy light
#  Had just removed the curtains of the night.
#
#  Then, in rising day,
#  On the grass they play;
#  Parents were afar,
#  Strangers came not near,
#  And the maiden soon forgot her fear.
#
#  Tired with kisses sweet,
#  They agree to meet
#  When the silent sleep
#  Waves o'er heaven's deep,
#  And the weary tired wanderers weep.
#
#  To her father white
#  Came the maiden bright;
#  But his loving look,
#  Like the holy book
#  All her tender limbs with terror shook.
#
#  "Ona, pale and weak,
#  To thy father speak!
#  Oh the trembling fear!
#  Oh the dismal care
#  That shakes the blossoms of my hoary hair!"
#
#
#  THE SCHOOLBOY
#
#  I love to rise on a summer morn,
#    When birds are singing on every tree;
#  The distant huntsman winds his horn,
#    And the skylark sings with me:
#    Oh what sweet company!
#
#  But to go to school in a summer morn, --
#    Oh it drives all joy away!
#  Under a cruel eye outworn,
#    The little ones spend the day
#    In sighing and dismay.
#
#  Ah then at times I drooping sit,
#    And spend many an anxious hour;
#  Nor in my book can I take delight,
#    Nor sit in learning's bower,
#    Worn through with the dreary shower.
#
#  How can the bird that is born for joy
#    Sit in a cage and sing?
#  How can a child, when fears annoy,
#    But droop his tender wing,
#    And forget his youthful spring?
#
#  Oh father and mother, if buds are nipped,
#    And blossoms blown away;
#  And if the tender plants are stripped
#    Of their joy in the springing day,
#    By sorrow and care's dismay, --
#
#  How shall the summer arise in joy,
#    Or the summer fruits appear?
#  Or how shall we gather what griefs destroy,
#    Or bless the mellowing year,
#    When the blasts of winter appear?
#
#
#  TO TERZAH
#
#  Whate'er is born of mortal birth
#  Must be consumed with the earth,
#  To rise from generation free:
#  Then what have I to do with thee?
#  The sexes sprang from shame and pride,
#  Blown in the morn, in evening died;
#  But mercy changed death into sleep;
#  The sexes rose to work and weep.
#
#  Thou, mother of my mortal part,
#  With cruelty didst mould my heart,
#  And with false self-deceiving tears
#  Didst bind my nostrils, eyes, and ears,
#
#  Didst close my tongue in senseless clay,
#  And me to mortal life betray.
#  The death of Jesus set me free:
#  Then what have I to do with thee?
#
#
#  THE VOICE OF THE ANCIENT BARD
#
#  Youth of delight!  come hither
#  And see the opening morn,
#  Image of Truth new-born.
#  Doubt is fled, and clouds of reason,
#  Dark disputes and artful teazing.
#  Folly is an endless maze;
#  Tangled roots perplex her ways;
#  How many have fallen there!
#  They stumble all night over bones of the dead;
#  And feel -- they know not what but care;
#  And wish to lead others, when they should be led.
#
#
# APPENDIX
#
#  A DIVINE IMAGE
#
#  Cruelty has a human heart,
#    And Jealousy a human face;
#  Terror the human form divine,
#    And Secresy the human dress.
#
#  The human dress is forged iron,
#    The human form a fiery forge,
#  The human face a furnace sealed,
#    The human heart its hungry gorge.
#
#  NOTE:  Though written and engraved by Blake, "A DIVINE IMAGE" was never
# included in the SONGS OF INNOCENCE AND OF EXPERIENCE.
#
#
#
#
#
#
# William Blake's
#
# THE BOOK of THEL
#
#
# THEL'S Motto
#
# Does the Eagle know what is in the pit?
# Or wilt thou go ask the Mole:
# Can Wisdom be put in a silver rod?
# Or Love in a golden bowl?
#
#
# THE BOOK of THEL
#
# The Author & Printer Willm. Blake. 1780
#
#
# THEL
#
# I
#
# The daughters of Mne Seraphim led round their sunny flocks,
# All but the youngest: she in paleness sought the secret air.
# To fade away like morning beauty from her mortal day:
# Down by the river of Adona her soft voice is heard;
# And thus her gentle lamentation falls like morning dew.
#
# O life of this our spring!  why fades the lotus of the water?
# Why fade these children of the spring? born but to smile & fall.
# Ah! Thel is like a watry bow, and like a parting cloud,
# Like a reflection in a glass: like shadows in the water
# Like dreams of infants, like a smile upon an infants face.
# Like the doves voice, like transient day, like music in the air:
# Ah! gentle may I lay me down and gentle rest my head.
# And gentle sleep the sleep of death, and gently hear the voice
# Of him that walketh in the garden in the evening time.
#
# The Lilly of the valley breathing in the humble grass
# Answerd the lovely maid and said: I am a watry weed,
# And I am very small and love to dwell in lowly vales:
# So weak the gilded butterfly scarce perches on my head
# Yet I am visited from heaven and he that smiles on all
# Walks in the valley, and each morn over me spreads his hand
# Saying, rejoice thou humble grass, thou new-born lily flower.
# Thou gentle maid of silent valleys and of modest brooks:
# For thou shall be clothed in light, and fed with morning manna:
# Till summers heat melts thee beside the fountains and the springs
# To flourish in eternal vales: they why should Thel complain.
# Why should the mistress of the vales of Har, utter a sigh.
#
# She ceasd & smild in tears, then sat down in her silver shrine.
#
# Thel answerd, O thou little virgin of the peaceful valley.
# Giving to those that cannot crave, the voiceless, the o'er tired
# The breath doth nourish the innocent lamb, he smells the milky garments
# He crops thy flowers while thou sittest smiling in his face,
# Wiping his mild and meekin mouth from all contagious taints.
# Thy wine doth purify the golden honey; thy perfume.
# Which thou dost scatter on every little blade of grass that springs
# Revives the milked cow, & tames the fire-breathing steed.
# But Thel is like a faint cloud kindled at the rising sun:
# I vanish from my pearly throne, and who shall find my place.
#
# Queen of the vales the Lily answered, ask the tender cloud,
# And it shall tell thee why it glitters in the morning sky.
# And why it scatters its bright beauty thro the humid air.
# Descend O little cloud & hover before the eyes of Thel.
#
# The Cloud descended and the Lily bowd her modest head:
# And went to mind her numerous charge among the verdant grass.
#
#
# II.
#
# O little Cloud the virgin said, I charge thee to tell me
# Why thou complainest now when in one hour thou fade away:
# Then we shall seek thee but not find: ah Thel is like to thee.
# I pass away, yet I complain, and no one hears my voice.
#
# The Cloud then shewd his golden head & his bright form emerg'd.
# Hovering and glittering on the air before the face of Thel.
#
# O virgin know'st thou not our steeds drink of the golden springs
# Where Luvah doth renew his horses: lookst thou on my youth.
# And fearest thou because I vanish and am seen no more.
# Nothing remains; O maid I tell thee, when I pass away.
# It is to tenfold life, to love, to peace, and raptures holy:
# Unseen descending, weigh my light wings upon balmy flowers:
# And court the fair eyed dew, to take me to her shining tent
# The weeping virgin, trembling kneels before the risen sun.
# Till we arise link'd in a golden band and never part:
# But walk united bearing food to all our tender flowers.
#
# Dost thou O little cloud?  I fear that I am not like thee:
# For I walk through the vales of Har, and smell the sweetest flowers:
# But I feed not the little flowers: I hear the warbling birds,
# But I feed not the warbling birds, they fly and seek their food:
# But Thel delights in these no more because I fade away
# And all shall say, without a use this shining women liv'd,
# Or did she only live to be at death the food of worms.
#
# The Cloud reclind upon his airy throne and answerd thus.
#
# Then if thou art the food of worms, O virgin of the skies,
# How great thy use, how great thy blessing, every thing that lives.
# Lives not alone nor or itself: fear not and I will call,
# The weak worm from its lowly bed, and thou shalt hear its voice.
# Come forth worm and the silent valley, to thy pensive queen.
#
# The helpless worm arose and sat upon the Lillys leaf,
# And the bright Cloud saild on, to find his partner in the vale.
#
#
# III.
#
# Then Thel astonish'd view'd the Worm upon its dewy bed.
#
# Art thou a Worm?  image of weakness.  art thou but a Worm?
# I see thee like an infant wrapped in the Lillys leaf;
# Ah weep not little voice, thou can'st not speak, but thou can'st weep:
# Is this a Worm?  I see they lay helpless & naked: weeping
# And none to answer, none to cherish thee with mothers smiles.
#
# The Clod of Clay heard the Worms voice & rais'd her pitying head:
# She bowd over the weeping infant, and her life exhald
# In milky fondness, then on Thel she fix'd her humble eyes
#
# O beauty of the vales of Har, we live not for ourselves,
# Thou seest me the meanest thing, and so I am indeed:
# My bosom of itself is cold, and of itself is dark,
#
# But he that loves the lowly, pours his oil upon my head
# And kisses me, and binds his nuptial bands around my breast.
# And says; Thou mother of my children, I have loved thee
# And I have given thee a crown that none can take away.
# But how this is sweet maid, I know not, and I cannot know
# I ponder, and I cannot ponder; yet I live and love.
#
# The daughter of beauty wip'd her pitying tears with her white veil,
# And said, Alas!  I knew not this, and therefore did I weep:
# That God would love a Worm I knew, and punish the evil foot
# That wilful bruis'd its helpless form: but that he cherish'd it
# With milk and oil I never knew, and therefore did I weep,
# And I complaind in the mild air, because I fade away.
# And lay me down in thy cold bed, and leave my shining lot.
#
# Queen of the vales, the matron Clay answered: I heard thy sighs.
# And all thy moans flew o'er my roof, but I have call'd them down:
# Wilt thou O Queen enter my house, tis given thee to enter,
# And to return: fear nothing, enter with thy virgin feet.
#
#
# IV.
#
# The eternal gates terrific porter lifted the northern bar:
# Thel enter'd in & saw the secrets of the land unknown;
# She saw the couches of the dead, & where the fibrous roots
# Of every heart on earth infixes deep its restless twists:
# A land of sorrows & of tears where never smile was seen.
#
# She wandered in the land of clouds thro' valleys dark, listning
# Dolors & lamentations: waiting oft beside the dewy grave
# She stood in silence, listning to the voices of the ground,
# Till to her own grave plot she came, & there she sat down.
# And heard this voice of sorrow breathed from the hollow pit.
#
# Why cannot the Ear be closed to its own destruction?
# Or the glistening Eye to the poison of a smile!
# Why are Eyelids stord with arrows ready drawn,
# Where a thousand fighting men in ambush lie!
# Or an Eye of gifts & graces showring fruits & coined gold!
#
# Why a Tongue impress'd with honey from every wind?
# Why an Ear, a whirlpool fierce to draw creations in?
# Why a Nostril wide inhaling terror trembling & affright
# Why a tender curb upon the youthful burning boy?
# Why a little curtain of flesh on the bed of our desire?
#
# The Virgin started from her seat, & with a shriek,
# Fled back unhinderd till she came into the vales of Har

# %%
# a '^' within square brackets searches anything other than the one on it
# hence here it matches everything from numbers and punctuations etc , leaving only the words

# letters_only = re.sub("[^a-zA-Z]"," ",sample1.get_text())
# print(letters_only)

# %%
# changing all the words to lowercase to create a bag of words later

lower_case = letters_only.lower()

# the whole doc is now split to create an array from which most common words called "stop words" will be removed

words = lower_case.split()

# %%
# nltk.download('stopwords')

# most common stopwords used in english language

# print(stopwords.words("english"))

# %% [markdown]
# ##  Stop words

# %%
# removing  stopwords from sample1 so that relevant words can be filtered out and stored in words

words = [w for w in words if w not in stopwords.words("english")]
# print(words)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-6cda93297f7e> in <module>
#       1 # removing  stopwords from sample1 so that relevant words can be filtered out and stored in words
#       2
# ----> 3 words = [w for w in words if w not in stopwords.words("english")]
#       4 # print(words)
#
# NameError: name 'words' is not defined

# %% [markdown]
# # 4 Building words - labels dataset

# %%
# the above code cleans only one review , let's make a function to clean all the reviews
def review_to_words(raw_review):
    #remove html using BeautifulSoup
    review_text = BeautifulSoup(raw_review,"html.parser").get_text()
    #removing raw letters,numbers,punctuations
    letters_only = re.sub("[^a-zA-Z]"," ",review_text)
    #creating an array , resolving whitespaces
    words = letters_only.lower().split()
    #create an array of stopwords so that we don't have to access corpus to search for a stopword
    stop = set(stopwords.words("english"))
    #removing stopwords from the raw_review
    meaningful_words = [w for w in words if w not in stop]
    #return a string with only the words that are important
    return(" ".join(meaningful_words))

# %%
# emma=gutenberg.sents('austen-emma.txt')
# sentences = [" ".join(list_of_words) for list_of_words in emma]
# ['she was happy','It was her own good']

# %%
# Split corpus into sentence
# Passing the gutenberg corpus to this function results in:

# ['[Emma by Jane Austen 1816]',
#  'VOLUME I',
#  'CHAPTER I',
#  'Emma Woodhouse, handsome, clever, and rich, with a comfortable home and happy disposition, seemed to unite some of the best blessings of existence; and had lived nearly twenty-one years in the world with very little to distress or vex her.',
#  "She was the youngest of the two daughters of a most affectionate, indulgent father; and had, in consequence of her sister's marriage, been mistress of his house from a very early period.",
#  ...]
def sentences_from_corpus(corpus, fileids = None):

    from nltk.corpus.reader.plaintext import read_blankline_block, concat

    def read_sent_block(stream):
        sents = []
        for para in corpus._para_block_reader(stream):
            sents.extend([s.replace('\n', ' ') for s in corpus._sent_tokenizer.tokenize(para)])
        return sents

    return concat([corpus.CorpusView(path, read_sent_block, encoding=enc)
                   for (path, enc, fileid)
                   in corpus.abspaths(fileids, True, True)])

# %%
# array_data = []
# array_label = []
# corpus_sentences_arr = sentences_from_corpus(gutenberg , fileids = 'austen-emma.txt')
# for corpus_sentence in corpus_sentences_arr :
#         array_data.append(corpus_sentence)
#         array_label.append('austen-emma.txt')

# %%
# len(array_label)
# Out:
# 7752

# %%
# s = 'austen-emma.txt'
# result = re.sub(r'^(\w+)-(\w+).(\w+)', r'\1', s, 1)

# print(result)
# Out:
# austen

# %%
array_data = []
array_label = []
for fileid in gutenberg.fileids():
    corpus_sentences_arr =  sentences_from_corpus(gutenberg , fileids = fileid )
    for corpus_sentence in corpus_sentences_arr :
        array_data.append(corpus_sentence)
        array_label.append(re.sub(r'^(\w+)-(\w+).(\w+)', r'\1', fileid, 1))

# %% [markdown]
# ## Create CSV Dataset

# %%
#----------------------------------------------------------

csv_array = []
for i in range(0, len(array_data)):
    csv_array.append([array_data[i], array_label[i]])

# format of array [[string, label], [string, label], [string, label]]
import csv
header = ['sentences', 'author']
with open('data.csv', 'w') as target:
    writer = csv.writer(target)
    writer.writerow(i for i in header)
    writer.writerows(csv_array)
#     for j in some_list:
#         writer.writerow(j)
#     writer.writerows(zip(csv_array))

# %% [markdown]
# ## Load  CSV Dataset

# %%
data = pd.read_csv('data.csv',  encoding = "ISO-8859-1")

# %%
data
# Out:
#                                                sentences   author
# 0                             [Emma by Jane Austen 1816]   austen
# 1                                               VOLUME I   austen
# 2                                              CHAPTER I   austen
# 3      Emma Woodhouse, handsome, clever, and rich, wi...   austen
# 4      She was the youngest of the two daughters of a...   austen
# ...                                                  ...      ...
# 98547  Now for my last--let me look back a moment; Th...  whitman
# 98548  Long have we lived, joy'd, caress'd together; ...  whitman
# 98549  Yet let me not be too hasty, Long indeed have ...  whitman
# 98550  May-be it is you the mortal knob really undoin...  whitman
# 98551                                          my Fancy.  whitman
#
# [98552 rows x 2 columns]

# %% [markdown]
# ## Data Exploration

# %%
# Percentage of missing values
data.isnull().sum()/len(data)*100
# Out:
# sentences    0.0
# author       0.0
# dtype: float64

# %%
data.describe()
# Out:
#        sentences author
# count      98552  98552
# unique     93787     12
# top         Ham.  bible
# freq         252  30103

# %%
data['author'].value_counts()
# Out:
# bible          30103
# austen         16498
# chesterton     12327
# edgeworth      10230
# melville       10059
# shakespeare     7176
# whitman         4250
# bryant          2863
# milton          1851
# carroll         1703
# burgess         1054
# blake            438
# Name: author, dtype: int64

# %% [markdown]
# #### > Imbalance data ( RandomForest or DecisionTree might fit)

# %% [markdown]
# ### Label Encoding authors

# %%
## Collect all unique author names from author column
author_names = data['author'].unique()
print (author_names)
# Out:
# ['austen' 'bible' 'blake' 'bryant' 'burgess' 'carroll' 'chesterton'
#  'edgeworth' 'melville' 'milton' 'shakespeare' 'whitman']

# %%
authorname_to_id = {}
assign_id = 0
for name in author_names:
    authorname_to_id[name] = assign_id
    assign_id += 1  ## Get a new id for new author
    
##  Print the dictionary created
for key, values in authorname_to_id.items():
    print (key, values)
# Out:
# austen 0
# bible 1
# blake 2
# bryant 3
# burgess 4
# carroll 5
# chesterton 6
# edgeworth 7
# melville 8
# milton 9
# shakespeare 10
# whitman 11

# %%
## convert the author name to id --> So when we predict the result humans can understand
# """
# 0 EAP
# 1 HPL
# 2 MWS
# """ 
id_to_author_name = {v: k for k, v in authorname_to_id.items()}
for key, values in id_to_author_name.items():
    print (key, values)
# Out:
# 0 austen
# 1 bible
# 2 blake
# 3 bryant
# 4 burgess
# 5 carroll
# 6 chesterton
# 7 edgeworth
# 8 melville
# 9 milton
# 10 shakespeare
# 11 whitman

# %%
## Add a new column to pandas dataframe, with the author name mapping
def get_author_id(author_name):
    return authorname_to_id[author_name]

data['author_id'] = data['author'].map(get_author_id)

# %%
data.head()
# Out:
#                                            sentences  author  author_id
# 0                         [Emma by Jane Austen 1816]  austen          0
# 1                                           VOLUME I  austen          0
# 2                                          CHAPTER I  austen          0
# 3  Emma Woodhouse, handsome, clever, and rich, wi...  austen          0
# 4  She was the youngest of the two daughters of a...  austen          0

# %% [markdown]
# ## Text Pre Processing - Clean text

# %%
data['sentences'][8]
# Out:
# "Even before Miss Taylor had ceased to hold the nominal office of governess, the mildness of her temper had hardly allowed her to impose any restraint; and the shadow of authority being now long passed away, they had been living together as friend and friend very mutually attached, and Emma doing just what she liked; highly esteeming Miss Taylor's judgment, but directed chiefly by her own."

# %%
data['author'][8]
# Out:
# 'austen'

# %%
corpus = [] # List for storing cleaned data
for i in range(len(data)): # for each obervation in the dataset
   #Adding the cleaned sentence to a list
   corpus.append(review_to_words (data['sentences'][i]) )
# Out:
# c:\python\python37\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'.'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# c:\python\python37\lib\site-packages\bs4\__init__.py:357: UserWarning: "http://www.gutenberg.net/donation.html" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# c:\python\python37\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'...'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# c:\python\python37\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'....'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)

# %%
corpus[8]
# Out:
# 'even miss taylor ceased hold nominal office governess mildness temper hardly allowed impose restraint shadow authority long passed away living together friend friend mutually attached emma liked highly esteeming miss taylor judgment directed chiefly'

# %%
len(corpus)
# Out:
# 98552

# %%
# Create a dataframe for clean word
df_clean = pd.DataFrame({'clean': corpus,  'author_id': data['author_id'] })
df_clean = df_clean.dropna().drop_duplicates()
df_clean.shape
# Out:
# (91044, 2)

# %% [markdown]
# # 5 Bag of Word - Naive Bayes

# %%
from sklearn.feature_extraction.text import CountVectorizer
# creating a function, vectorizer to convert the words into vectors

vectorizer = CountVectorizer(
#     analyzer="word",
#                             preprocessor=None,
#                             stop_words="english",
#                             max_features=5000,
        min_df = 20
                            )

# converting reviews from text into features

train_data_features_bow = vectorizer.fit_transform(corpus)

# %%
#change the classifier into array

# train_data_features_bow = train_data_features_bow.toarray()

# %%
train_data_features_bow.shape
# Out:
# (98552, 6054)

# %%
len(vectorizer.vocabulary_)
# Out:
# 6054

# %%
count_list = np.asarray(train_data_features_bow.sum(axis=0))

# %%
len(count_list[0])
# Out:
# 6054

# %%
word_list = vectorizer.get_feature_names();

# %%
print (dict(zip(word_list,count_list[0])))
# Out:
# {'aaron': 352, 'abbey': 67, 'abhor': 24, 'abhorred': 28, 'abiathar': 31, 'abide': 99, 'abideth': 30, 'abijah': 20, 'abilities': 26, 'abimelech': 66, 'abishai': 25, 'able': 399, 'abner': 63, 'aboard': 29, 'abode': 81, 'abominable': 36, 'abomination': 80, 'abominations': 77, 'abound': 25, 'abraham': 261, 'abram': 61, 'abroad': 124, 'abrupt': 26, 'abruptly': 63, 'absalom': 108, 'absence': 69, 'absent': 63, 'absolute': 42, 'absolutely': 75, 'absurd': 34, 'abundance': 85, 'abundantly': 37, 'abyss': 23, 'accent': 31, 'accept': 97, 'acceptable': 39, 'accepted': 71, 'accepting': 27, 'accident': 64, 'accompanied': 37, 'accomplish': 34, 'accomplished': 52, 'accord': 26, 'according': 867, 'accordingly': 29, 'account': 257, 'accounted': 29, 'accounts': 35, 'accursed': 43, 'accuse': 30, 'accused': 27, 'achish': 21, 'acknowledge': 62, 'acknowledged': 42, 'acquaintance': 217, 'acquainted': 110, 'across': 237, 'act': 138, 'acted': 31, 'acting': 30, 'action': 71, 'actions': 32, 'active': 52, 'activity': 27, 'actor': 29, 'acts': 90, 'actual': 27, 'actually': 91, 'adam': 148, 'add': 91, 'added': 276, 'addition': 35, 'additional': 30, 'address': 51, 'addressed': 39, 'addressing': 30, 'admirable': 26, 'admiral': 101, 'admiration': 85, 'admire': 49, 'admired': 58, 'admit': 49, 'admitted': 45, 'adonijah': 26, 'adorned': 23, 'adultery': 42, 'advance': 71, 'advanced': 56, 'advancing': 61, 'advantage': 116, 'advantages': 37, 'adventure': 25, 'adventures': 33, 'adversaries': 36, 'adversary': 30, 'advice': 77, 'advise': 44, 'advised': 22, 'afar': 71, 'affair': 85, 'affairs': 44, 'affect': 25, 'affected': 51, 'affection': 167, 'affectionate': 56, 'affections': 35, 'afflict': 38, 'afflicted': 63, 'affliction': 101, 'afford': 65, 'afforded': 25, 'afore': 25, 'afraid': 498, 'aft': 34, 'afternoon': 46, 'afterward': 86, 'afterwards': 235, 'againe': 74, 'age': 226, 'aged': 26, 'agent': 34, 'ages': 77, 'agitated': 25, 'agitation': 55, 'ago': 191, 'agony': 43, 'agree': 55, 'agreeable': 120, 'agreed': 81, 'ah': 199, 'ahab': 605, 'ahasuerus': 33, 'ahaz': 44, 'ahaziah': 37, 'ahead': 59, 'ai': 36, 'aid': 38, 'air': 608, 'airs': 26, 'alarm': 76, 'alarmed': 46, 'alas': 83, 'alice': 401, 'alike': 80, 'alive': 187, 'alligator': 36, 'allow': 120, 'allowed': 104, 'almighty': 100, 'almost': 765, 'aloft': 84, 'alone': 499, 'along': 453, 'alongside': 29, 'aloud': 81, 'already': 310, 'also': 2186, 'altar': 402, 'altars': 59, 'alter': 29, 'alteration': 25, 'altered': 51, 'although': 42, 'altogether': 140, 'alway': 24, 'always': 1013, 'amalek': 24, 'amalekites': 24, 'amazed': 38, 'amazement': 48, 'amaziah': 40, 'ambition': 41, 'ambitious': 27, 'amen': 86, 'america': 103, 'american': 72, 'amiable': 76, 'amid': 92, 'amidst': 22, 'ammon': 92, 'ammonites': 23, 'amnon': 28, 'among': 1405, 'amongst': 93, 'amorites': 73, 'amount': 25, 'ample': 47, 'amused': 38, 'amusement': 54, 'anarchist': 44, 'anarchists': 33, 'anarchy': 23, 'anchor': 40, 'ancient': 115, 'angel': 314, 'angels': 169, 'anger': 312, 'angle': 31, 'angrily': 25, 'angry': 176, 'anguish': 44, 'animal': 53, 'animals': 57, 'animated': 27, 'animation': 21, 'anne': 556, 'announce': 41, 'announced': 25, 'anoint': 37, 'anointed': 108, 'anointing': 30, 'anon': 35, 'another': 1256, 'answer': 481, 'answered': 806, 'answering': 57, 'answers': 28, 'ant': 52, 'antique': 24, 'antony': 76, 'anxiety': 65, 'anxious': 112, 'anxiously': 35, 'anybody': 114, 'anyhow': 33, 'anyone': 75, 'anything': 394, 'anywhere': 72, 'apart': 61, 'apartment': 20, 'apology': 33, 'apostle': 34, 'apostles': 62, 'apparel': 32, 'apparent': 37, 'apparently': 43, 'apparition': 21, 'appeal': 26, 'appear': 220, 'appearance': 171, 'appearances': 23, 'appeared': 310, 'appearing': 40, 'appears': 61, 'appetite': 38, 'applause': 33, 'apple': 53, 'apples': 49, 'application': 26, 'applied': 35, 'apply': 22, 'appoint': 46, 'appointed': 164, 'appointment': 20, 'apprehension': 22, 'approach': 80, 'approached': 31, 'approaching': 43, 'approbation': 48, 'approve': 30, 'approved': ...

# %%
vectorizer.vocabulary_.get(u'authority')
# Out:
# 359

# %%
X_bow = train_data_features_bow

#dependent variable,y will be 1 for positive and 0 for negative review

y = data['author']

# %%
# 98552 rows and 5000 features

print (X_bow.shape) 
print (y.shape)
# Out:
# (98552, 6054)
# (98552,)

# %% [markdown]
# ## Applying MultinomialNaiveBayes for classification

# %%
# splitting the training data into test and train

X_train_bow, X_test_bow, y_train_bow, y_test_bow = train_test_split(X_bow, y,test_size=0.25,random_state=123)

# %%
naive = MultinomialNB()
classifier_bow = naive.fit(X_train_bow,y_train_bow)
predict_bow = classifier_bow.predict(X_test_bow)



# cm = confusion_matrix(predict_bow,y_test_bow)
# cm

# %%
a = classifier_bow.score(X_train_bow, y_train_bow)
b = classifier_bow.score(X_test_bow, y_test_bow)
print('Accuracy on training set: {:.2f}'
     .format(a))
print('Accuracy  on test set: {:.2f}'
     .format(b))
# Out:
# Accuracy on training set: 0.79
# Accuracy  on test set: 0.77

# %%
print(classification_report(y_test_bow, predict_bow))
# Out:
#               precision    recall  f1-score   support
#
#       austen       0.75      0.81      0.78      4232
#        bible       0.81      0.96      0.88      7583
#        blake       0.70      0.18      0.28       107
#       bryant       0.70      0.49      0.58       692
#      burgess       0.91      0.56      0.70       259
#      carroll       0.85      0.49      0.62       419
#   chesterton       0.74      0.68      0.71      3042
#    edgeworth       0.66      0.65      0.65      2470
#     melville       0.77      0.64      0.70      2520
#       milton       0.71      0.79      0.75       473
#  shakespeare       0.86      0.69      0.77      1790
#      whitman       0.69      0.57      0.63      1051
#
#     accuracy                           0.77     24638
#    macro avg       0.76      0.63      0.67     24638
# weighted avg       0.77      0.77      0.76     24638

# %% [markdown]
# ### Test Bag of Word Model

# %%
docs_new_bow = ['Even before Miss Taylor had ceased to hold the nominal office of governess',
                'Piping down the valleys wild',
                   'How sweet is the Shepherd sweet lot!',
                 'From the morn to the evening he stays',
                  "The sun does arise, And make happy the skies;  The merry bells ring To welcome the Spring;The skylark and thrush"
               ]
X_new_counts_bow = vectorizer.transform(docs_new_bow)

predicted = classifier_bow.predict(X_new_counts_bow)
predicted
# Out:
# array(['austen', 'melville', 'blake', 'milton', 'blake'], dtype='<U11')

# %% [markdown]
#  ### conclusion
#  > The first sentence is right , the second one is wrong -> should be William Blake -> the data of  William Blake is imbalance
#  > The model is not really good

# %% [markdown]
# ### Try with GridSearchCV  & LogisticRegression

# %%
# C is the most important , C is the the inverse of regularization strength , C = 1/λ , the smaller the better
grid={'C': [ 0.1, 1, 10, 100], "penalty":["l1","l2"]}# l1 lasso l2 ridge   'C': [0.001, 0.01, 0.1, 1, 10, 100, 1000]
logreg=LogisticRegression()
logreg_cv=GridSearchCV(logreg,grid,cv=3, scoring = 'accuracy', n_jobs =-1)

# %%
logreg_cv.fit(X_train_bow,y_train_bow)
# Out:
# c:\python\python37\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# c:\python\python37\lib\site-packages\sklearn\linear_model\logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# GridSearchCV(cv=3, error_score='raise-deprecating',
#              estimator=LogisticRegression(C=1.0, class_weight=None, dual=False,
#                                           fit_intercept=True,
#                                           intercept_scaling=1, l1_ratio=None,
#                                           max_iter=100, multi_class='warn',
#                                           n_jobs=None, penalty='l2',
#                                           random_state=None, solver='warn',
#                                           tol=0.0001, verbose=0,
#                                           warm_start=False),
#              iid='warn', n_jobs=-1,
#              param_grid={'C': [0.1, 1, 10, 100], 'penalty': ['l1', 'l2']},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring='accuracy', verbose=0)

# %%
print("tuned hpyerparameters :(best parameters) ",logreg_cv.best_params_)
print("accuracy :",logreg_cv.best_score_)
# Out:
# tuned hpyerparameters :(best parameters)  {'C': 10, 'penalty': 'l2'}
# accuracy : 0.759801931974998

# %% [markdown]
# # 6 TF-IDF   -  Naive Bayes

# %%
from sklearn.feature_extraction.text import TfidfTransformer

tfidf_transformer = TfidfTransformer()
X_tfidf = tfidf_transformer.fit_transform(train_data_features_bow)
X_tfidf.shape
# Out:
# (98552, 6054)

# %%
# splitting the training data into test and train

X_train_tfidf, X_test_tfidf, y_train_tfidf, y_test_tfidf = train_test_split(X_tfidf, y,test_size=0.25,random_state=123)

# %%
naive_tfidf = MultinomialNB()
classifier_tfidf = naive_tfidf.fit(X_train_tfidf,y_train_tfidf)
predict_tfidf = classifier_tfidf.predict(X_test_tfidf)

# %%
a = classifier_tfidf.score(X_train_tfidf, y_train_tfidf)
b = classifier_tfidf.score(X_test_tfidf, y_test_tfidf)
print('Accuracy on training set: {:.2f}'
     .format(a))
print('Accuracy  on test set: {:.2f}'
     .format(b))
# Out:
# Accuracy on training set: 0.76
# Accuracy  on test set: 0.75

# %% [markdown]
#  > worse than Bag Of Word  ????????

# %%
print(classification_report(y_test_tfidf, predict_tfidf))
# Out:
# c:\python\python37\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
#               precision    recall  f1-score   support
#
#       austen       0.69      0.87      0.77      4232
#        bible       0.75      0.99      0.86      7583
#        blake       0.00      0.00      0.00       107
#       bryant       0.91      0.25      0.39       692
#      burgess       0.97      0.30      0.46       259
#      carroll       0.99      0.25      0.40       419
#   chesterton       0.69      0.69      0.69      3042
#    edgeworth       0.74      0.60      0.66      2470
#     melville       0.76      0.63      0.69      2520
#       milton       0.98      0.37      0.54       473
#  shakespeare       0.94      0.65      0.77      1790
#      whitman       0.83      0.36      0.50      1051
#
#     accuracy                           0.75     24638
#    macro avg       0.77      0.50      0.56     24638
# weighted avg       0.76      0.75      0.73     24638

# %% [markdown]
# >   blake   :    0.00    -> learn nothing for blake

# %% [markdown]
# ## Apply with RandomForest

# %%
from sklearn.ensemble import RandomForestClassifier
rf_tfidf = RandomForestClassifier(class_weight="balanced")
rf_tfidf.fit(X_train_tfidf,y_train_tfidf)
predict_tfidf = rf_tfidf.predict(X_test_tfidf)
print('accuracy %s' % accuracy_score(predict_tfidf,y_test_tfidf))
print(classification_report(y_test_tfidf, predict_tfidf))
# Out:
# c:\python\python37\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# accuracy 0.6561003328192223
#               precision    recall  f1-score   support
#
#       austen       0.60      0.72      0.66      4232
#        bible       0.78      0.91      0.84      7583
#        blake       0.31      0.07      0.12       107
#       bryant       0.55      0.36      0.44       692
#      burgess       0.62      0.57      0.59       259
#      carroll       0.62      0.47      0.54       419
#   chesterton       0.54      0.50      0.52      3042
#    edgeworth       0.60      0.44      0.51      2470
#     melville       0.65      0.49      0.56      2520
#       milton       0.58      0.30      0.40       473
#  shakespeare       0.60      0.74      0.66      1790
#      whitman       0.45      0.30      0.36      1051
#
#     accuracy                           0.66     24638
#    macro avg       0.57      0.49      0.52     24638
# weighted avg       0.64      0.66      0.64     24638

# %% [markdown]
# ### Apply with LogisticRegression

# %%
logreg = LogisticRegression(n_jobs=-1, C=10, penalty= 'l2')
logreg = logreg.fit(X_train_tfidf,y_train_tfidf)
predict_tfidf_logreg = logreg.predict(X_test_tfidf)
print('accuracy %s' % accuracy_score(predict_tfidf_logreg,y_test_tfidf))
print(classification_report(y_test_tfidf, predict_tfidf_logreg))
# Out:
# c:\python\python37\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# c:\python\python37\lib\site-packages\sklearn\linear_model\logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# c:\python\python37\lib\site-packages\sklearn\linear_model\logistic.py:1544: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 8.
#   " = {}.".format(effective_n_jobs(self.n_jobs)))
# accuracy 0.7843980842600861
#               precision    recall  f1-score   support
#
#       austen       0.76      0.81      0.79      4232
#        bible       0.92      0.96      0.94      7583
#        blake       0.70      0.21      0.33       107
#       bryant       0.71      0.54      0.62       692
#      burgess       0.87      0.59      0.70       259
#      carroll       0.84      0.50      0.63       419
#   chesterton       0.69      0.71      0.70      3042
#    edgeworth       0.69      0.66      0.67      2470
#     melville       0.72      0.67      0.70      2520
#       milton       0.88      0.61      0.72       473
#  shakespeare       0.68      0.84      0.75      1790
#      whitman       0.67      0.57      0.61      1051
#
#     accuracy                           0.78     24638
#    macro avg       0.76      0.64      0.68     24638
# weighted avg       0.78      0.78      0.78     24638

# %% [markdown]
# ### Test TF-IDF Model

# %%
docs_new_tfidf = ['Even before Miss Taylor had ceased to hold the nominal office of governess',
                'Piping down the valleys wild',
                   'How sweet is the Shepherd sweet lot!',
                 'From the morn to the evening he stays',
                  "The sun does arise, And make happy the skies;  The merry bells ring To welcome the Spring;The skylark and thrush"
               ]
X_new_counts_tfidf = vectorizer.transform(docs_new_tfidf)
X_new_tfidf = tfidf_transformer.transform(X_new_counts_tfidf)

predicted = classifier_tfidf.predict(X_new_tfidf)
predicted
# Out:
# array(['austen', 'bible', 'bible', 'austen', 'whitman'], dtype='<U11')

# %%
# With RandomForest
predicted_2 = rf_tfidf.predict(X_new_tfidf)
predicted_2
# Out:
# array(['austen', 'whitman', 'blake', 'whitman', 'melville'], dtype=object)

# %% [markdown]
#  ### conclusion
#  > The first sentence is right , the second one is wrong -> should be William Blake -> the data of  William Blake is imbalance
#  > The model is not really good

# %% [markdown]
# # 7 - word2vec

# %% [markdown]
# # 7.1 - Bigrams
#
# We are using Gensim Phrases package to automatically detect common phrases (bigrams) from a list of sentences. https://radimrehurek.com/gensim/models/phrases.html
#
# The main reason we do this is to catch words like "mr_burns" or "bart_simpson" !

# %%
from gensim.models.phrases import Phrases, Phraser

# %%
sent = [row.split() for row in df_clean['clean']]

# %%
sent
# Out:
# [['emma', 'jane', 'austen'],
#  ['volume'],
#  ['chapter'],
#  ['emma',
#   'woodhouse',
#   'handsome',
#   'clever',
#   'rich',
#   'comfortable',
#   'home',
#   'happy',
#   'disposition',
#   'seemed',
#   'unite',
#   'best',
#   'blessings',
#   'existence',
#   'lived',
#   'nearly',
#   'twenty',
#   'one',
#   'years',
#   'world',
#   'little',
#   'distress',
#   'vex'],
#  ['youngest',
#   'two',
#   'daughters',
#   'affectionate',
#   'indulgent',
#   'father',
#   'consequence',
#   'sister',
#   'marriage',
#   'mistress',
#   'house',
#   'early',
#   'period'],
#  ['mother',
#   'died',
#   'long',
#   'ago',
#   'indistinct',
#   'remembrance',
#   'caresses',
#   'place',
#   'supplied',
#   'excellent',
#   'woman',
#   'governess',
#   'fallen',
#   'little',
#   'short',
#   'mother',
#   'affection'],
#  ['sixteen',
#   'years',
#   'miss',
#   'taylor',
#   'mr',
#   'woodhouse',
#   'family',
#   'less',
#   'governess',
#   'friend',
#   'fond',
#   'daughters',
#   'particularly',
#   'emma'],
#  ['intimacy', 'sisters'],
#  ['even',
#   'miss',
#   'taylor',
#   'ceased',
#   'hold',
#   'nominal',
#   'office',
#   'governess',
#   'mildness',
#   'temper',
#   'hardly',
#   'allowed',
#   'impose',
#   'restraint',
#   'shadow',
#   'authority',
#   'long',
#   'passed',
#   'away',
#   'living',
#   'together',
#   'friend',
#   'friend',
#   'mutually',
#   'attached',
#   'emma',
#   'liked',
#   'highly',
#   'esteeming',
#   'miss',
#   'taylor',
#   'judgment',
#   'directed',
#   'chiefly'],
#  ['real',
#   'evils',
#   'indeed',
#   'emma',
#   'situation',
#   'power',
#   'rather',
#   'much',
#   'way',
#   'disposition',
#   'think',
#   'little',
#   'well',
#   'disadvantages',
#   'threatened',
#   'alloy',
#   'many',
#   'enjoyments'],
#  ['danger',
#   'however',
#   'present',
#   'unperceived',
#   'means',
#   'rank',
#   'misfortunes'],
#  ['sorrow',
#   'came',
#   'gentle',
#   'sorrow',
#   'shape',
#   'disagreeable',
#   'consciousness',
#   'miss',
#   'taylor',
#   'married'],
#  ['miss', 'taylor', 'loss', 'first', 'brought', 'grief'],
#  ['wedding',
#   'day',
#   'beloved',
#   'friend',
#   'emma',
#   'first',
#   'sat',
#   'mournful',
#   'thought',
#   'continuance'],
#  ['wedding',
#   'bride',
#   'people',
#   'gone',
#   'father',
#   'left',
#   'dine',
#   'together',
#   'prospect',
#   'third',
#   'cheer',
#   'long',
#   'evening'],
#  ['father', 'composed', 'sleep', 'dinner', 'usual', 'sit', 'think', 'lost'],
#  ['event', 'every', 'promise', 'happiness', 'friend'],
#  ['mr',
#   'weston',
#   'man',
#   'unexceptionable',
#   'character',
#   'easy',
#   'fortune',
#   'suitable',
#   'age',
#   'pleasant',
#   'manners',
#   'satisfaction',
#   'considering',
#   'self',
#   'denying',
#   'generous',
#   'friendship',
#   'always',
#   'wished',
#   'promoted',
#   'match',
#   'black',
#   'morning',
#   'work'],
#  ['want', 'miss', 'taylor', 'would', 'felt', 'every', 'hour', 'every', 'day'],
#  ['recalled',
#   'past',
#   'kindness',
#   'kindness',
#   'affection',
#   'sixteen',
#   'years',
#   'taught',
#   'played',
#   'five',
#   'years',
#   'old',
#   'devoted',
#   'powers',
#   'attach',
#   'amuse',
#   'health',
#   'nursed',
#   'various',
#   'illnesses',
#   'childhood'],
#  ['large',
#   'debt',
#   'gratitude',
#   'owing',
#   'intercourse',
#   'last',
#   'seven',
#   'years',
#   'equal',
#   'footing',
#   'perfect',
#   'unreserve',
#   'soon',
#   'followed',
#   'isabella',
#   'marriage',
#   'left',
#   'yet',
#   'dearer',
#   'tenderer',
#   'recollection'],
#  ['friend',
#   'companion',
#   'possessed',
#   'intelligent',
#   'well',
#   'informed',
#   'useful',
#   'gentle',
#   'knowing',
#   'ways',
#   'family',
#   'interested',
#   'concerns',
#   'peculiarly',
#   'interested',
#   'every',
#   'pleasure',
#   'every',
#   'scheme',
#   'one',
#   'could',
#   'speak',
#   'every',
#   'thought',
#   'arose',
#   'affection',
#   'could',
#   'never',
#   'find',
#   'fault'],
#  ['bear',
#   'change',
#   'true',
#   'friend',
#   'going',
#   'half',
#   'mile',
#   'emma',
#   'aware',
#   'great',
#   'must',
#   'difference',
#   'mrs',
#   'weston',
#   'half',
#   'mile',
#   'miss',
#   'taylor',
#   'house',
#   'advantages',
#   'natural',
#   'domestic',
#   'great',
#   'danger',
#   'suffering',
#   'intellectual',
#   'solitude'],
#  ['dearly', 'loved', 'father', 'companion'],
#  ['could', 'meet', 'conversation', 'rational', 'playful'],
#  ['evil',
#   'actual',
#   'disparity',
#   'ages',
#   'mr',
#   'woodhouse',
#   'married',
#   'early',
#   'much',
#   'increased',
#   'constitution',
#   'habits',
#   'valetudinarian',
#   'life',
#   'without',
#   'activity',
#   'mind',
#   'body',
#   'much',
#   'older',
#   'man',
#   'ways',
#   'years',
#   'though',
#   'everywhere',
#   'beloved',
#   'friendliness',
#   'heart',
#   'amiable',
#   'temper',
#   'talents',
#   'could',
#   'recommended',
#   'time'],
#  ['sister',
#   'though',
#   'comparatively',
#   'little',
#   'removed',
#   'matrimony',
#   'settled',
#   'london',
#   'sixteen',
#   'miles',
#   'much',
#   'beyond',
#   'daily',
#   'reach',
#   'many',
#   'long',
#   'october',
#   'november',
#   'evening',
#   'must',
#   'struggled',
#   'hartfield',
#   'christmas',
#   'brought',
#   'next',
#   'visit',
#   'isabella',
#   'husband',
#   'little',
#   'children',
#   'fill',
#   'house',
#   'give',
#   'pleasant',
#   'society'],
#  ['highbury',
#   'large',
#   'populous',
#   'village',
#   'almost',
#   'amounting',
#   'town',
#   'hartfield',
#   'spite',
#   'separate',
#   'lawn',
#   'shrubberies',
#   'name',
#   'really',
#   'belong',
#   'afforded',
#   'equals'],
#  ['woodhouses', 'first', 'consequence'],
#  ['looked'],
#  ['many',
#   'acquaintance',
#   'place',
#   'father',
#   'universally',
#   'civil',
#   'one',
#   'among',
#   'could',
#   'accepted',
#   'lieu',
#   'miss',
#   'taylor',
#   'even',
#   'half',
#   'day'],
#  ['melancholy',
#   'change',
#   'emma',
#   'could',
#   'sigh',
#   'wish',
#   'impossible',
#   'things',
#   'till',
#   'father',
#   'awoke',
#   'made',
#   'necessary',
#   'cheerful'],
#  ['spirits', 'required', 'support'],
#  ['nervous',
#   'man',
#   'easily',
#   'depressed',
#   'fond',
#   'every',
#   'body',
#   'used',
#   'hating',
#   'part',
#   'hating',
#   'change',
#   'every',
#   'kind'],
#  ['matrimony',
#   'origin',
#   'change',
#   'always',
#   'disagreeable',
#   'means',
#   'yet',
#   'reconciled',
#   'daughter',
#   'marrying',
#   'could',
#   'ever',
#   'speak',
#   'compassion',
#   'though',
#   'entirely',
#   'match',
#   'affection',
#   'obliged',
#   'part',
#   'miss',
#   'taylor',
#   'habits',
#   'gentle',
#   'selfishness',
#   'never',
#   'able',
#   'suppose',
#   'people',
#   'could',
#   'feel',
#   'differently',
#   'much',
#   'disposed',
#   'think',
#   'miss',
#   'taylor',
#   'done',
#   'sad',
#   'thing',
#   'would',
#   'great',
#   'deal',
#   'happier',
#   'spent',
#   'rest',
#   'life',
#   'hartfield'],
#  ['emma',
#   'smiled',
#   'chatted',
#   'cheerfully',
#   'could',
#   'keep',
#   'thoughts',
#   'tea',
#   'came',
#   'impossible',
#   'say',
#   'exactly',
#   'said',
#   'dinner'],
#  ['poor', 'miss', 'taylor', 'wish'],
#  ['pity', 'mr', 'weston', 'ever', 'thought'],
#  ['cannot', 'agree', 'papa', 'know', 'cannot'],
#  ['mr',
#   'weston',
#   'good',
#   'humoured',
#   'pleasant',
#   'excellent',
#   'man',
#   'thoroughly',
#   'deserves',
#   'good',
#   'wife',
#   'would',
#   'miss',
#   'taylor',
#   'live',
#   'us',
#   'ever',
#   'bear',
#   'odd',
#   'humours',
#   'might',
#   'house'],
#  ['house', 'advantage', 'house'],
#  ['three', 'times', 'large', 'never', 'odd', 'humours', 'dear'],
#  ['often',
#   'shall',
#   'going',
#   'see',
#   'coming',
#   'see',
#   'us',
#   'shall',
#   'always',
#   'meeting'],
#  ['must', 'begin', 'must', 'go', 'pay', 'wedding', 'visit', 'soon'],
#  ['dear', 'get', 'far'],
#  ['randalls', 'distance'],
#  ['could', 'walk', 'half', 'far'],
#  ['papa', 'nobody', 'thought', 'walking'],
#  ['must', 'go', 'carriage', 'sure'],
#  ['carriage'],
#  ['james',
#   'like',
#   'put',
#   'horses',
#   'little',
#   'way',
#   'poor',
#   'horses',
#   'paying',
#   'visit'],
#  ['put', 'mr', 'weston', 'stable', 'papa'],
#  ['know', 'settled', 'already'],
#  ['talked', 'mr', 'weston', 'last', 'night'],
#  ['james',
#   'may',
#   'sure',
#   'always',
#   'like',
#   'going',
#   'randalls',
#   'daughter',
#   'housemaid'],
#  ['doubt', 'whether', 'ever', 'take', 'us', 'anywhere', 'else'],
#  ['papa'],
#  ['got', 'hannah', 'good', 'place'],
#  ['nobody', 'thought', 'hannah', 'till', 'mentioned', 'james', 'obliged'],
#  ['glad', 'think'],
#  ['lucky',
#   'would',
#   'poor',
#   'james',
#   'think',
#   'slighted',
#   'upon',
#   'account',
#   'sure',
#   'make',
#   'good',
#   'servant',
#   'civil',
#   'pretty',
#   'spoken',
#   'girl',
#   'great',
#   'opinion'],
#  ['whenever',
#   'see',
#   'always',
#   'curtseys',
#   'asks',
#   'pretty',
#   'manner',
#   'needlework',
#   'observe',
#   'always',
#   'turns',
#   'lock',
#   'door',
#   'right',
#   'way',
#   'never',
#   'bangs'],
#  ['sure',
#   'excellent',
#   'servant',
#   'great',
#   'comfort',
#   'poor',
#   'miss',
#   'taylor',
#   'somebody',
#   'used',
#   'see'],
#  ['whenever', 'james', 'goes', 'see', 'daughter', 'know', 'hearing', 'us'],
#  ['able', 'tell'],
#  ['emma',
#   'spared',
#   'exertions',
#   'maintain',
#   'happier',
#   'flow',
#   'ideas',
#   'hoped',
#   'help',
#   'backgammon',
#   'get',
#   'father',
#   'tolerably',
#   'evening',
#   'attacked',
#   'regrets'],
#  ['backgammon',
#   'table',
#   'placed',
#   'visitor',
#   'immediately',
#   'afterwards',
#   'walked',
#   'made',
#   'unnecessary'],
#  ['mr',
#   'knightley',
#   'sensible',
#   'man',
#   'seven',
#   'eight',
#   'thirty',
#   'old',
#   'intimate',
#   'friend',
#   'family',
#   'particularly',
#   'connected',
#   'elder',
#   'brother',
#   'isabella',
#   'husband'],
#  ['lived',
#   'mile',
#   'highbury',
#   'frequent',
#   'visitor',
#   'always',
#   'welcome',
#   'time',
#   'welcome',
#   'usual',
#   'coming',
#   'directly',
#   'mutual',
#   'connexions',
#   'london'],
#  ['returned',
#   'late',
#   'dinner',
#   'days',
#   'absence',
#   'walked',
#   'hartfield',
#   'say',
#   'well',
#   'brunswick',
#   'square'],
#  ['happy', 'circumstance', 'animated', 'mr', 'woodhouse', 'time'],
#  ['mr',
#   'knightley',
#   'cheerful',
#   'manner',
#   'always',
#   'good',
#   'many',
#   'inquiries',
#   'poor',
#   'isabella',
#   'children',
#   'answered',
#   'satisfactorily'],
#  ['mr',
#   'woodhouse',
#   'gratefully',
#   'observed',
#   'kind',
#   'mr',
#   'knightley',
#   'come',
#   'late',
#   'hour',
#   'call',
#   'upon',
#   'us'],
#  ['afraid', 'must', 'shocking', 'walk'],
#  ['sir'],
#  ['beautiful',
#   'moonlight',
#   'night',
#   'mild',
#   'must',
#   'draw',
#   'back',
#   'great',
#   'fire'],
#  ['must', 'found', 'damp', 'dirty'],
#  ['wish', 'may', 'catch', 'cold'],
#  ['dirty', 'sir'],
#  ['look', 'shoes'],
#  ['speck'],
#  ['well'],
#  ['quite', 'surprising', 'vast', 'deal', 'rain'],
#  ['rained', 'dreadfully', 'hard', 'half', 'hour', 'breakfast'],
#  ['wanted', 'put', 'wedding'],
#  ['bye', 'wished', 'joy'],
#  ['pretty',
#   'well',
#   'aware',
#   'sort',
#   'joy',
#   'must',
#   'feeling',
#   'hurry',
#   'congratulations',
#   'hope',
#   'went',
#   'tolerably',
#   'well'],
#  ['behave'],
#  ['cried'],
#  ['ah'],
#  ['poor', 'miss', 'taylor'],
#  ['tis', 'sad', 'business'],
#  ['poor',
#   'mr',
#   'miss',
#   'woodhouse',
#   'please',
#   'cannot',
#   'possibly',
#   'say',
#   'poor',
#   'miss',
#   'taylor'],
#  ['great',
#   'regard',
#   'emma',
#   'comes',
#   'question',
#   'dependence',
#   'independence',
#   'rate',
#   'must',
#   'better',
#   'one',
#   'please',
#   'two'],
#  ['especially', 'one', 'two', 'fanciful', 'troublesome', 'creature'],
#  ['said', 'emma', 'playfully'],
#  ['head', 'know', 'would', 'certainly', 'say', 'father'],
#  ['believe', 'true', 'dear', 'indeed', 'said', 'mr', 'woodhouse', 'sigh'],
#  ['afraid', 'sometimes', 'fanciful', 'troublesome'],
#  ['dearest', 'papa'],
#  ['think', 'could', 'mean', 'suppose', 'mr', 'knightley', 'mean'],
#  ['horrible', 'idea'],
#  ['oh'],
#  ['meant'],
#  ['mr', 'knightley', 'loves', 'find', 'fault', 'know', 'joke', 'joke'],
#  ['always', 'say', 'like', 'one', 'another'],
#  ['mr',
#   'knightley',
#   'fact',
#   'one',
#   'people',
#   'could',
#   'see',
#   'faults',
#   'emma',
#   'woodhouse',
#   'one',
#   'ever',
#   'told',
#   'though',
#   'particularly',
#   'agreeable',
#   'emma',
#   'knew',
#   'would',
#   'much',
#   'less',
#   'father',
#   'would',
#   'really',
#   'suspect',
#   'circumstance',
#   'thought',
#   'perfect',
#   'every',
#   'body'],
#  ['emma',
#   'knows',
#   'never',
#   'flatter',
#   'said',
#   'mr',
#   'knightley',
#   'meant',
#   'reflection',
#   'body'],
#  ['miss', 'taylor', 'used', 'two', 'persons', 'please', 'one'],
#  ['chances', 'must', 'gainer'],
#  ['well',
#   'said',
#   'emma',
#   'willing',
#   'let',
#   'pass',
#   'want',
#   'hear',
#   'wedding',
#   'shall',
#   'happy',
#   'tell',
#   'behaved',
#   'charmingly'],
#  ['every',
#   'body',
#   'punctual',
#   'every',
#   'body',
#   'best',
#   'looks',
#   'tear',
#   'hardly',
#   'long',
#   'face',
#   'seen'],
#  ['oh',
#   'felt',
#   'going',
#   'half',
#   'mile',
#   'apart',
#   'sure',
#   'meeting',
#   'every',
#   'day'],
#  ['dear', 'emma', 'bears', 'every', 'thing', 'well', 'said', 'father'],
#  ['mr',
#   'knightley',
#   'really',
#   'sorry',
#   'lose',
#   'poor',
#   'miss',
#   'taylor',
#   'sure',
#   'miss',
#   'thinks'],
#  ['emma', 'turned', 'away', 'head', 'divided', 'tears', 'smiles'],
#  ['impossible', 'emma', 'miss', 'companion', 'said', 'mr', 'knightley'],
#  ['like',
#   'well',
#   'sir',
#   'could',
#   'suppose',
#   'knows',
#   'much',
#   'marriage',
#   'miss',
#   'taylor',
#   'advantage',
#   'knows',
#   'acceptable',
#   'must',
#   'miss',
#   'taylor',
#   'time',
#   'life',
#   'settled',
#   'home',
#   'important',
#   'secure',
#   'comfortable',
#   'provision',
#   'therefore',
#   'cannot',
#   'allow',
#   'feel',
#   'much',
#   'pain',
#   'pleasure'],
#  ['every', 'friend', 'miss', 'taylor', 'must', 'glad', 'happily', 'married'],
#  ['forgotten',
#   'one',
#   'matter',
#   'joy',
#   'said',
#   'emma',
#   'considerable',
#   'one',
#   'made',
#   'match'],
#  ['made',
#   'match',
#   'know',
#   'four',
#   'years',
#   'ago',
#   'take',
#   'place',
#   'proved',
#   'right',
#   'many',
#   'people',
#   'said',
#   'mr',
#   'weston',
#   'would',
#   'never',
#   'marry',
#   'may',
#   'comfort',
#   'thing'],
#  ['mr', 'knightley', 'shook', 'head'],
#  ['father', 'fondly', 'replied', 'ah'],
#  ['dear',
#   'wish',
#   'would',
#   'make',
#   'matches',
#   'foretell',
#   'things',
#   'whatever',
#   'say',
#   'always',
#   'comes',
#   'pass'],
#  ['pray', 'make', 'matches'],
#  ['promise', 'make', 'none', 'papa', 'must', 'indeed', 'people'],
#  ['greatest', 'amusement', 'world'],
#  ['success',
#   'know',
#   'every',
#   'body',
#   'said',
#   'mr',
#   'weston',
#   'would',
#   'never',
#   'marry'],
#  ['oh', 'dear'],
#  ['mr',
#   'weston',
#   'widower',
#   'long',
#   'seemed',
#   'perfectly',
#   'comfortable',
#   'without',
#   'wife',
#   'constantly',
#   'occupied',
#   'either',
#   'business',
#   'town',
#   'among',
#   'friends',
#   'always',
#   'acceptable',
#   'wherever',
#   'went',
#   'always',
#   'cheerful',
#   'mr',
#   'weston',
#   'need',
#   'spend',
#   'single',
#   'evening',
#   'year',
#   'alone',
#   'like'],
#  ['mr', 'weston', 'certainly', 'would', 'never', 'marry'],
#  ['people',
#   'even',
#   'talked',
#   'promise',
#   'wife',
#   'deathbed',
#   'others',
#   'son',
#   'uncle',
#   'letting'],
#  ['manner', 'solemn', 'nonsense', 'talked', 'subject', 'believed', 'none'],
#  ['ever',
#   'since',
#   'day',
#   'four',
#   'years',
#   'ago',
#   'miss',
#   'taylor',
#   'met',
#   'broadway',
#   'lane',
#   'began',
#   'drizzle',
#   'darted',
#   'away',
#   'much',
#   'gallantry',
#   'borrowed',
#   'two',
#   'umbrellas',
#   'us',
#   'farmer',
#   'mitchell',
#   'made',
#   'mind',
#   'subject'],
#  ['planned',
#   'match',
#   'hour',
#   'success',
#   'blessed',
#   'instance',
#   'dear',
#   'papa',
#   'cannot',
#   'think',
#   'shall',
#   'leave',
#   'match',
#   'making'],
#  ['understand', 'mean', 'success', 'said', 'mr', 'knightley'],
#  ['success', 'supposes', 'endeavour'],
#  ['time',
#   'properly',
#   'delicately',
#   'spent',
#   'endeavouring',
#   'last',
#   'four',
#   'years',
#   'bring',
#   'marriage'],
#  ['worthy', 'employment', 'young', 'lady', 'mind'],
#  ['rather',
#   'imagine',
#   'making',
#   'match',
#   'call',
#   'means',
#   'planning',
#   'saying',
#   'one',
#   'idle',
#   'day',
#   'think',
#   'would',
#   'good',
#   'thing',
#   'miss',
#   'taylor',
#   'mr',
#   'weston',
#   'marry',
#   'saying',
#   'every',
#   'afterwards',
#   'talk',
#   'success'],
#  ['merit'],
#  ['proud'],
#  ['made', 'lucky', 'guess', 'said'],
#  ['never',
#   'known',
#   'pleasure',
#   'triumph',
#   'lucky',
#   'guess',
#   'pity',
#   'thought',
#   'cleverer',
#   'depend',
#   'upon',
#   'lucky',
#   'guess',
#   'never',
#   'merely',
#   'luck'],
#  ['always', 'talent'],
#  ['poor',
#   'word',
#   'success',
#   'quarrel',
#   'know',
#   'entirely',
#   'without',
#   'claim'],
#  ['drawn',
#   'two',
#   'pretty',
#   'pictures',
#   'think',
#   'may',
#   'third',
#   'something',
#   'nothing'],
#  ['promoted',
#   'mr',
#   'weston',
#   'visits',
#   'given',
#   'many',
#   'little',
#   'encouragements',
#   'smoothed',
#   'many',
#   'little',
#   'matters',
#   'might',
#   'come',
#   'thing'],
#  ['think', 'must', 'know', 'hartfield', 'enough', 'comprehend'],
#  ['straightforward',
#   'open',
#   'hearted',
#   'man',
#   'like',
#   'weston',
#   'rational',
#   'unaffected',
#   'woman',
#   'like',
#   'miss',
#   'taylor',
#   'may',
#   'safely',
#   'left',
#   'manage',
#   'concerns'],
#  ['likely', 'done', 'harm', 'good', 'interference'],
#  ['emma',
#   'never',
#   'thinks',
#   'good',
#   'others',
#   'rejoined',
#   'mr',
#   'woodhouse',
#   'understanding',
#   'part'],
#  ['dear',
#   'pray',
#   'make',
#   'matches',
#   'silly',
#   'things',
#   'break',
#   'one',
#   'family',
#   'circle',
#   'grievously'],
#  ['one', 'papa', 'mr', 'elton'],
#  ['poor', 'mr', 'elton'],
#  ['like', 'mr', 'elton', 'papa', 'must', 'look', 'wife'],
#  ['nobody',
#   'highbury',
#   'deserves',
#   'whole',
#   'year',
#   'fitted',
#   'house',
#   'comfortably',
#   'would',
#   'shame',
#   'single',
#   'longer',
#   'thought',
#   'joining',
#   'hands',
#   'day',
#   'looked',
#   'much',
#   'would',
#   'like',
#   'kind',
#   'office',
#   'done'],
#  ['think', 'well', 'mr', 'elton', 'way', 'service'],
#  ['mr',
#   'elton',
#   'pretty',
#   'young',
#   'man',
#   'sure',
#   'good',
#   'young',
#   'man',
#   'great',
#   'regard'],
#  ['want', 'shew', 'attention', 'dear', 'ask', 'come', 'dine', 'us', 'day'],
#  ['much', 'better', 'thing'],
#  ['dare', 'say', 'mr', 'knightley', 'kind', 'meet'],
#  ['great',
#   'deal',
#   'pleasure',
#   'sir',
#   'time',
#   'said',
#   'mr',
#   'knightley',
#   'laughing',
#   'agree',
#   'entirely',
#   'much',
#   'better',
#   'thing'],
#  ['invite',
#   'dinner',
#   'emma',
#   'help',
#   'best',
#   'fish',
#   'chicken',
#   'leave',
#   'chuse',
#   'wife'],
#  ['depend', 'upon', 'man', 'six', 'seven', 'twenty', 'take', 'care'],
#  ['chapter', 'ii'],
#  ['mr',
#   'weston',
#   'native',
#   'highbury',
#   'born',
#   'respectable',
#   'family',
#   'last',
#   'two',
#   'three',
#   'generations',
#   'rising',
#   'gentility',
#   'property'],
#  ['received',
#   'good',
#   'education',
#   'succeeding',
#   'early',
#   'life',
#   'small',
#   'independence',
#   'become',
#   'indisposed',
#   'homely',
#   'pursuits',
#   'brothers',
#   'engaged',
#   'satisfied',
#   'active',
#   'cheerful',
#   'mind',
#   'social',
#   'temper',
#   'entering',
#   'militia',
#   'county',
#   'embodied'],
#  ['captain',
#   'weston',
#   'general',
#   'favourite',
#   'chances',
#   'military',
#   'life',
#   'introduced',
#   'miss',
#   'churchill',
#   'great',
#   'yorkshire',
#   'family',
#   'miss',
#   'churchill',
#   'fell',
#   'love',
#   'nobody',
#   'surprized',
#   'except',
#   'brother',
#   'wife',
#   'never',
#   'seen',
#   'full',
#   'pride',
#   'importance',
#   'connexion',
#   'would',
#   'offend'],
#  ['miss',
#   'churchill',
#   'however',
#   'age',
#   'full',
#   'command',
#   'fortune',
#   'though',
#   'fortune',
#   'bore',
#   'proportion',
#   'family',
#   'estate',
#   'dissuaded',
#   'marriage',
#   'took',
#   'place',
#   'infinite',
#   'mortification',
#   'mr',
#   'mrs',
#   'churchill',
#   'threw',
#   'due',
#   'decorum'],
#  ['unsuitable', 'connexion', 'produce', 'much', 'happiness'],
#  ['mrs',
#   'weston',
#   'ought',
#   'found',
#   'husband',
#   'whose',
#   'warm',
#   'heart',
#   'sweet',
#   'temper',
#   'made',
#   'think',
#   'every',
#   'thing',
#   'due',
#   'return',
#   'great',
#   'goodness',
#   'love',
#   'though',
#   'one',
#   'sort',
#   'spirit',
#   'best'],
#  ['resolution',
#   'enough',
#   'pursue',
#   'spite',
#   'brother',
#   'enough',
#   'refrain',
#   'unreasonable',
#   'regrets',
#   'brother',
#   'unreasonable',
#   'anger',
#   'missing',
#   'luxuries',
#   'former',
#   'home'],
#  ['lived',
#   'beyond',
#   'income',
#   'still',
#   'nothing',
#   'comparison',
#   'enscombe',
#   'cease',
#   'love',
#   'husband',
#   'wanted',
#   'wife',
#   'captain',
#   'weston',
#   'miss',
#   'churchill',
#   'enscombe'],
#  ['captain',
#   'weston',
#   'considered',
#   'especially',
#   'churchills',
#   'making',
#   'amazing',
#   'match',
#   'proved',
#   'much',
#   'worst',
#   'bargain',
#   'wife',
#   'died',
#   'three',
#   'years',
#   'marriage',
#   'rather',
#   'poorer',
#   'man',
#   'first',
#   'child',
#   'maintain'],
#  ['expense', 'child', 'however', 'soon', 'relieved'],
#  ['boy',
#   'additional',
#   'softening',
#   'claim',
#   'lingering',
#   'illness',
#   'mother',
#   'means',
#   'sort',
#   'reconciliation',
#   'mr',
#   'mrs',
#   'churchill',
#   'children',
#   'young',
#   'creature',
#   'equal',
#   'kindred',
#   'care',
#   'offered',
#   'take',
#   'whole',
#   'charge',
#   'little',
#   'frank',
#   'soon',
#   'decease'],
#  ['scruples',
#   'reluctance',
#   'widower',
#   'father',
#   'may',
#   'supposed',
#   'felt',
#   'overcome',
#   'considerations',
#   'child',
#   'given',
#   'care',
#   'wealth',
#   'churchills',
#   'comfort',
#   'seek',
#   'situation',
#   'improve',
#   'could'],
#  ['complete', 'change', 'life', 'became', 'desirable'],
#  ['quitted',
#   'militia',
#   'engaged',
#   'trade',
#   'brothers',
#   'already',
#   'established',
#   'good',
#   'way',
#   'london',
#   'afforded',
#   'favourable',
#   'opening'],
#  ['concern', 'brought', 'employment', 'enough'],
#  ['still',
#   'small',
#   'house',
#   'highbury',
#   'leisure',
#   'days',
#   'spent',
#   'useful',
#   'occupation',
#   'pleasures',
#   'society',
#   'next',
#   'eighteen',
#   'twenty',
#   'years',
#   'life',
#   'passed',
#   'cheerfully',
#   'away'],
#  ['time',
#   'realised',
#   'easy',
#   'competence',
#   'enough',
#   'secure',
#   'purchase',
#   'little',
#   'estate',
#   'adjoining',
#   'highbury',
#   'always',
#   'longed',
#   'enough',
#   'marry',
#   'woman',
#   'portionless',
#   'even',
#   'miss',
#   'taylor',
#   'live',
#   'according',
#   'wishes',
#   'friendly',
#   'social',
#   'disposition'],
#  ['time',
#   'since',
#   'miss',
#   'taylor',
#   'begun',
#   'influence',
#   'schemes',
#   'tyrannic',
#   'influence',
#   'youth',
#   'youth',
#   'shaken',
#   'determination',
#   'never',
#   'settling',
#   'till',
#   'could',
#   'purchase',
#   'randalls',
#   'sale',
#   'randalls',
#   'long',
#   'looked',
#   'forward',
#   'gone',
#   'steadily',
#   'objects',
#   'view',
#   'till',
#   'accomplished'],
#  ['made',
#   'fortune',
#   'bought',
#   'house',
#   'obtained',
#   'wife',
#   'beginning',
#   'new',
#   'period',
#   'existence',
#   'every',
#   'probability',
#   'greater',
#   'happiness',
#   'yet',
#   'passed'],
#  ['never',
#   'unhappy',
#   'man',
#   'temper',
#   'secured',
#   'even',
#   'first',
#   'marriage',
#   'second',
#   'must',
#   'shew',
#   'delightful',
#   'well',
#   'judging',
#   'truly',
#   'amiable',
#   'woman',
#   'could',
#   'must',
#   'give',
#   'pleasantest',
#   'proof',
#   'great',
#   'deal',
#   'better',
#   'choose',
#   'chosen',
#   'excite',
#   'gratitude',
#   'feel'],
#  ['please',
#   'choice',
#   'fortune',
#   'frank',
#   'tacitly',
#   'brought',
#   'uncle',
#   'heir',
#   'become',
#   'avowed',
#   'adoption',
#   'assume',
#   'name',
#   'churchill',
#   'coming',
#   'age'],
#  ['unlikely', 'therefore', 'ever', 'want', 'father', 'assistance'],
#  ['father', 'apprehension'],
#  ['aunt',
#   'capricious',
#   'woman',
#   'governed',
#   'husband',
#   'entirely',
#   'mr',
#   'weston',
#   'nature',
#   'imagine',
#   'caprice',
#   'could',
#   'strong',
#   'enough',
#   'affect',
#   'one',
#   'dear',
#   'believed',
#   'deservedly',
#   'dear'],
#  ['saw',
#   'son',
#   'every',
#   'year',
#   'london',
#   'proud',
#   'fond',
#   'report',
#   'fine',
#   'young',
#   'man',
#   'made',
#   'highbury',
#   'feel',
#   'sort',
#   'pride'],
#  ['looked',
#   'sufficiently',
#   'belonging',
#   'place',
#   'make',
#   'merits',
#   'prospects',
#   'kind',
#   'common',
#   'concern'],
#  ['mr',
#   'frank',
#   'churchill',
#   'one',
#   'boasts',
#   'highbury',
#   'lively',
#   'curiosity',
#   'see',
#   'prevailed',
#   'though',
#   'compliment',
#   'little',
#   'returned',
#   'never',
#   'life'],
#  ['coming', 'visit', 'father', 'often', 'talked', 'never', 'achieved'],
#  ['upon',
#   'father',
#   'marriage',
#   'generally',
#   'proposed',
#   'proper',
#   'attention',
#   'visit',
#   'take',
#   'place'],
#  ['dissentient',
#   'voice',
#   'subject',
#   'either',
#   'mrs',
#   'perry',
#   'drank',
#   'tea',
#   'mrs',
#   'miss',
#   'bates',
#   'mrs',
#   'miss',
#   'bates',
#   'returned',
#   'visit'],
#  ['time',
#   'mr',
#   'frank',
#   'churchill',
#   'come',
#   'among',
#   'hope',
#   'strengthened',
#   'understood',
#   'written',
#   'new',
#   'mother',
#   'occasion'],
#  ['days',
#   'every',
#   'morning',
#   'visit',
#   'highbury',
#   'included',
#   'mention',
#   'handsome',
#   'letter',
#   'mrs',
#   'weston',
#   'received'],
#  ['suppose',
#   'heard',
#   'handsome',
#   'letter',
#   'mr',
#   'frank',
#   'churchill',
#   'written',
#   'mrs',
#   'weston'],
#  ['understand', 'handsome', 'letter', 'indeed'],
#  ['mr', 'woodhouse', 'told'],
#  ['mr',
#   'woodhouse',
#   'saw',
#   'letter',
#   'says',
#   'never',
#   'saw',
#   'handsome',
#   'letter',
#   'life'],
#  ['indeed', 'highly', 'prized', 'letter'],
#  ['mrs',
#   'weston',
#   'course',
#   'formed',
#   'favourable',
#   'idea',
#   'young',
#   'man',
#   'pleasing',
#   'attention',
#   'irresistible',
#   'proof',
#   'great',
#   'good',
#   'sense',
#   'welcome',
#   'addition',
#   'every',
#   'source',
#   'every',
#   'expression',
#   'congratulation',
#   'marriage',
#   'already',
#   'secured'],
#  ['felt',
#   'fortunate',
#   'woman',
#   'lived',
#   'long',
#   'enough',
#   'know',
#   'fortunate',
#   'might',
#   'well',
#   'thought',
#   'regret',
#   'partial',
#   'separation',
#   'friends',
#   'whose',
#   'friendship',
#   'never',
#   'cooled',
#   'could',
#   'ill',
#   'bear',
#   'part'],
#  ['knew',
#   'times',
#   'must',
#   'missed',
#   'could',
#   'think',
#   'without',
#   'pain',
#   'emma',
#   'losing',
#   'single',
#   'pleasure',
#   'suffering',
#   'hour',
#   'ennui',
#   'want',
#   'companionableness',
#   'dear',
#   'emma',
#   'feeble',
#   'character',
#   'equal',
#   'situation',
#   'girls',
#   'would',
#   'sense',
#   'energy',
#   'spirits',
#   'might',
#   'hoped',
#   'would',
#   'bear',
#   'well',
#   'happily',
#   'little',
#   'difficulties',
#   'privations'],
#  ['comfort',
#   'easy',
#   'distance',
#   'randalls',
#   'hartfield',
#   'convenient',
#   'even',
#   'solitary',
#   'female',
#   'walking',
#   'mr',
#   'weston',
#   'disposition',
#   'circumstances',
#   'would',
#   'make',
#   'approaching',
#   'season',
#   'hindrance',
#   'spending',
#   'half',
#   'evenings',
#   'week',
#   'together'],
#  ['situation',
#   'altogether',
#   'subject',
#   'hours',
#   'gratitude',
#   'mrs',
#   'weston',
#   'moments',
#   'regret',
#   'satisfaction',
#   'satisfaction',
#   'cheerful',
#   'enjoyment',
#   'apparent',
#   'emma',
#   'well',
#   'knew',
#   'father',
#   'sometimes',
#   'taken',
#   'surprize',
#   'still',
#   'able',
#   'pity',
#   'poor',
#   'miss',
#   'taylor',
#   'left',
#   'randalls',
#   'centre',
#   'every',
#   'domestic',
#   'comfort',
#   'saw',
#   'go',
#   'away',
#   'evening',
#   'attended',
#   'pleasant',
#   'husband',
#   'carriage'],
#  ['never',
#   'go',
#   'without',
#   'mr',
#   'woodhouse',
#   'giving',
#   'gentle',
#   'sigh',
#   'saying',
#   'ah',
#   'poor',
#   'miss',
#   'taylor'],
#  ['would', 'glad', 'stay'],
#  ['recovering',
#   'miss',
#   'taylor',
#   'much',
#   'likelihood',
#   'ceasing',
#   'pity',
#   'weeks',
#   'brought',
#   'alleviation',
#   'mr',
#   'woodhouse'],
#  ['compliments',
#   'neighbours',
#   'longer',
#   'teased',
#   'wished',
#   'joy',
#   'sorrowful',
#   'event',
#   'wedding',
#   'cake',
#   'great',
#   'distress',
#   'eat'],
#  ['stomach',
#   'could',
#   'bear',
#   'nothing',
#   'rich',
#   'could',
#   'never',
#   'believe',
#   'people',
#   'different'],
#  ['unwholesome',
#   'regarded',
#   'unfit',
#   'body',
#   'therefore',
#   'earnestly',
#   'tried',
#   'dissuade',
#   'wedding',
#   'cake',
#   'proved',
#   'vain',
#   'earnestly',
#   'tried',
#   'prevent',
#   'body',
#   'eating'],
#  ['pains', 'consulting', 'mr', 'perry', 'apothecary', 'subject'],
#  ['mr',
#   'perry',
#   'intelligent',
#   'gentlemanlike',
#   'man',
#   'whose',
#   'frequent',
#   'visits',
#   'one',
#   'comforts',
#   'mr',
#   'woodhouse',
#   'life',
#   'upon',
#   'applied',
#   'could',
#   'acknowledge',
#   'though',
#   'seemed',
#   'rather',
#   'bias',
#   'inclination',
#   'wedding',
#   'cake',
#   'might',
#   'certainly',
#   'disagree',
#   'many',
#   'perhaps',
#   'people',
#   'unless',
#   'taken',
#   'moderately'],
#  ['opinion',
#   'confirmation',
#   'mr',
#   'woodhouse',
#   'hoped',
#   'influence',
#   'every',
#   'visitor',
#   'newly',
#   'married',
#   'pair',
#   'still',
#   'cake',
#   'eaten',
#   'rest',
#   'benevolent',
#   'nerves',
#   'till',
#   'gone'],
#  ['strange',
#   'rumour',
#   'highbury',
#   'little',
#   'perrys',
#   'seen',
#   'slice',
#   'mrs',
#   'weston',
#   'wedding',
#   'cake',
#   'hands',
#   'mr',
#   'woodhouse',
#   'would',
#   'never',
#   'believe'],
#  ['chapter', 'iii'],
#  ['mr', 'woodhouse', 'fond', 'society', 'way'],
#  ['liked',
#   'much',
#   'friends',
#   'come',
#   'see',
#   'various',
#   'united',
#   'causes',
#   'long',
#   'residence',
#   'hartfield',
#   'good',
#   'nature',
#   'fortune',
#   'house',
#   'daughter',
#   'could',
#   'command',
#   'visits',
#   'little',
#   'circle',
#   'great',
#   'measure',
#   'liked'],
#  ['much',
#   'intercourse',
#   'families',
#   'beyond',
#   'circle',
#   'horror',
#   'late',
#   'hours',
#   'large',
#   'dinner',
#   'parties',
#   'made',
#   'unfit',
#   'acquaintance',
#   'would',
#   'visit',
#   'terms'],
#  ['fortunately',
#   'highbury',
#   'including',
#   'randalls',
#   'parish',
#   'donwell',
#   'abbey',
#   'parish',
#   'adjoining',
#   'seat',
#   'mr',
#   'knightley',
#   'comprehended',
#   'many'],
#  ['unfrequently',
#   'emma',
#   'persuasion',
#   'chosen',
#   'best',
#   'dine',
#   'evening',
#   'parties',
#   'preferred',
#   'unless',
#   'fancied',
#   'time',
#   'unequal',
#   'company',
#   'scarcely',
#   'evening',
#   'week',
#   'emma',
#   'could',
#   'make',
#   'card',
#   'table'],
#  ['real',
#   'long',
#   'standing',
#   'regard',
#   'brought',
#   'westons',
#   'mr',
#   'knightley',
#   'mr',
#   'elton',
#   'young',
#   'man',
#   'living',
#   'alone',
#   'without',
#   'liking',
#   'privilege',
#   'exchanging',
#   'vacant',
#   'evening',
#   'blank',
#   'solitude',
#   'elegancies',
#   'society',
#   'mr',
#   'woodhouse',
#   'drawing',
#   'room',
#   'smiles',
#   'lovely',
#   'daughter',
#   'danger',
#   'thrown',
#   'away'],
#  ['came',
#   'second',
#   'set',
#   'among',
#   'come',
#   'able',
#   'mrs',
#   'miss',
#   'bates',
#   'mrs',
#   'goddard',
#   'three',
#   'ladies',
#   'almost',
#   'always',
#   'service',
#   'invitation',
#   'hartfield',
#   'fetched',
#   'carried',
#   'home',
#   'often',
#   'mr',
#   'woodhouse',
#   'thought',
#   'hardship',
#   'either',
#   'james',
#   'horses'],
#  ['taken', 'place', 'year', 'would', 'grievance'],
#  ['mrs',
#   'bates',
#   'widow',
#   'former',
#   'vicar',
#   'highbury',
#   'old',
#   'lady',
#   'almost',
#   'past',
#   'every',
#   'thing',
#   'tea',
#   'quadrille'],
#  ['lived',
#   'single',
#   'daughter',
#   'small',
#   'way',
#   'considered',
#   'regard',
#   'respect',
#   'harmless',
#   'old',
#   'lady',
#   'untoward',
#   'circumstances',
#   'excite'],
#  ['daughter',
#   'enjoyed',
#   'uncommon',
#   'degree',
#   'popularity',
#   'woman',
#   'neither',
#   'young',
#   'handsome',
#   'rich',
#   'married'],
#  ['miss',
#   'bates',
#   'stood',
#   'worst',
#   'predicament',
#   'world',
#   'much',
#   'public',
#   'favour',
#   'intellectual',
#   'superiority',
#   'make',
#   'atonement',
#   'frighten',
#   'might',
#   'hate',
#   'outward',
#   'respect'],
#  ['never', 'boasted', 'either', 'beauty', 'cleverness'],
#  ['youth',
#   'passed',
#   'without',
#   'distinction',
#   'middle',
#   'life',
#   'devoted',
#   'care',
#   'failing',
#   'mother',
#   'endeavour',
#   'make',
#   'small',
#   'income',
#   'go',
#   'far',
#   'possible'],
#  ['yet', 'happy', 'woman', 'woman', 'one', 'named', 'without', 'good'],
#  ['universal', 'good', 'contented', 'temper', 'worked', 'wonders'],
#  ['loved',
#   'every',
#   'body',
#   'interested',
#   'every',
#   'body',
#   'happiness',
#   'quicksighted',
#   'every',
#   'body',
#   'merits',
#   'thought',
#   'fortunate',
#   'creature',
#   'surrounded',
#   'blessings',
#   'excellent',
#   'mother',
#   'many',
#   'good',
#   'neighbours',
#   'friends',
#   'home',
#   'wanted',
#   'nothing'],
#  ['simplicity',
#   'cheerfulness',
#   'nature',
#   'contented',
#   'grateful',
#   'spirit',
#   'recommendation',
#   'every',
#   'body',
#   'mine',
#   'felicity'],
#  ['great',
#   'talker',
#   'upon',
#   'little',
#   'matters',
#   'exactly',
#   'suited',
#   'mr',
#   'woodhouse',
#   'full',
#   'trivial',
#   'communications',
#   'harmless',
#   'gossip'],
#  ['mrs',
#   'goddard',
#   'mistress',
#   'school',
#   'seminary',
#   'establishment',
#   'thing',
#   'professed',
#   'long',
#   'sentences',
#   'refined',
#   'nonsense',
#   'combine',
#   'liberal',
#   'acquirements',
#   'elegant',
#   'morality',
#   'upon',
#   'new',
#   'principles',
#   'new',
#   'systems',
#   'young',
#   'ladies',
#   'enormous',
#   'pay',
#   'might',
#   'screwed',
#   'health',
#   'vanity',
#   'real',
#   'honest',
#   'old',
#   'fashioned',
#   'boarding',
#   'school',
#   'reasonable',
#   'quantity',
#   'accomplishments',
#   'sold',
#   'reasonable',
#   'price',
#   'girls',
#   'might',
#   'sent',
#   'way',
#   'scramble',
#   'little',
#   'education',
#   'without',
#   'danger',
#   'coming',
#   'back',
#   'prodigies'],
#  ['mrs',
#   'goddard',
#   'school',
#   'high',
#   'repute',
#   'deservedly',
#   'highbury',
#   'reckoned',
#   'particularly',
#   'healthy',
#   'spot',
#   'ample',
#   'house',
#   'garden',
#   'gave',
#   'children',
#   'plenty',
#   'wholesome',
#   'food',
#   'let',
#   'run',
#   'great',
#   'deal',
#   'summer',
#   'winter',
#   'dressed',
#   'chilblains',
#   'hands'],
#  ['wonder', 'train', 'twenty', 'young', 'couple', 'walked', 'church'],
#  ['plain',
#   'motherly',
#   'kind',
#   'woman',
#   'worked',
#   'hard',
#   'youth',
#   'thought',
#   'entitled',
#   'occasional',
#   'holiday',
#   'tea',
#   'visit',
#   'formerly',
#   'owed',
#   'much',
#   'mr',
#   'woodhouse',
#   'kindness',
#   'felt',
#   'particular',
#   'claim',
#   'leave',
#   'neat',
#   'parlour',
#   'hung',
#   'round',
#   'fancy',
#   'work',
#   'whenever',
#   'could',
#   'win',
#   'lose',
#   'sixpences',
#   'fireside'],
#  ['ladies',
#   'emma',
#   'found',
#   'frequently',
#   'able',
#   'collect',
#   'happy',
#   'father',
#   'sake',
#   'power',
#   'though',
#   'far',
#   'concerned',
#   'remedy',
#   'absence',
#   'mrs',
#   'weston'],
#  ['delighted',
#   'see',
#   'father',
#   'look',
#   'comfortable',
#   'much',
#   'pleased',
#   'contriving',
#   'things',
#   'well',
#   'quiet',
#   'prosings',
#   'three',
#   'women',
#   'made',
#   'feel',
#   'every',
#   'evening',
#   'spent',
#   'indeed',
#   'one',
#   'long',
#   'evenings',
#   'fearfully',
#   'anticipated'],
#  ['sat',
#   'one',
#   'morning',
#   'looking',
#   'forward',
#   'exactly',
#   'close',
#   'present',
#   'day',
#   'note',
#   'brought',
#   'mrs',
#   'goddard',
#   'requesting',
#   'respectful',
#   'terms',
#   'allowed',
#   'bring',
#   'miss',
#   'smith',
#   'welcome',
#   'request',
#   'miss',
#   'smith',
#   'girl',
#   'seventeen',
#   'emma',
#   'knew',
#   'well',
#   'sight',
#   'long',
#   'felt',
#   'interest',
#   'account',
#   'beauty'],
#  ['gracious',
#   'invitation',
#   'returned',
#   'evening',
#   'longer',
#   'dreaded',
#   'fair',
#   'mistress',
#   'mansion'],
#  ['harriet', 'smith', 'natural', 'daughter', 'somebody'],
#  ['somebody',
#   'placed',
#   'several',
#   'years',
#   'back',
#   'mrs',
#   'goddard',
#   'school',
#   'somebody',
#   'lately',
#   'raised',
#   'condition',
#   'scholar',
#   'parlour',
#   'boarder'],
#  ['generally', 'known', 'history'],
#  ['visible',
#   'friends',
#   'acquired',
#   'highbury',
#   'returned',
#   'long',
#   'visit',
#   'country',
#   'young',
#   'ladies',
#   'school'],
#  ['pretty',
#   'girl',
#   'beauty',
#   'happened',
#   'sort',
#   'emma',
#   'particularly',
#   'admired'],
#  ['short',
#   'plump',
#   'fair',
#   'fine',
#   'bloom',
#   'blue',
#   'eyes',
#   'light',
#   'hair',
#   'regular',
#   'features',
#   'look',
#   'great',
#   'sweetness',
#   'end',
#   'evening',
#   'emma',
#   'much',
#   'pleased',
#   'manners',
#   'person',
#   'quite',
#   'determined',
#   'continue',
#   'acquaintance'],
#  ['struck',
#   'thing',
#   'remarkably',
#   'clever',
#   'miss',
#   'smith',
#   'conversation',
#   'found',
#   'altogether',
#   'engaging',
#   'inconveniently',
#   'shy',
#   'unwilling',
#   'talk',
#   'yet',
#   'far',
#   'pushing',
#   'shewing',
#   'proper',
#   'becoming',
#   'deference',
#   'seeming',
#   'pleasantly',
#   'grateful',
#   'admitted',
#   'hartfield',
#   'artlessly',
#   'impressed',
#   'appearance',
#   'every',
#   'thing',
#   'superior',
#   'style',
#   'used',
#   'must',
#   'good',
#   'sense',
#   'deserve',
#   'encouragement'],
#  ['encouragement', 'given'],
#  ['soft',
#   'blue',
#   'eyes',
#   'natural',
#   'graces',
#   'wasted',
#   'inferior',
#   'society',
#   'highbury',
#   'connexions'],
#  ['acquaintance', 'already', 'formed', 'unworthy'],
#  ['friends', 'parted', 'though', 'good', 'sort', 'people', 'must', 'harm'],
#  ['family',
#   'name',
#   'martin',
#   'emma',
#   'well',
#   'knew',
#   'character',
#   'renting',
#   'large',
#   'farm',
#   'mr',
#   'knightley',
#   'residing',
#   'parish',
#   'donwell',
#   'creditably',
#   'believed',
#   'knew',
#   'mr',
#   'knightley',
#   'thought',
#   'highly',
#   'must',
#   'coarse',
#   'unpolished',
#   'unfit',
#   'intimates',
#   'girl',
#   'wanted',
#   'little',
#   'knowledge',
#   'elegance',
#   'quite',
#   'perfect'],
#  ['would',
#   'notice',
#   'would',
#   'improve',
#   'would',
#   'detach',
#   'bad',
#   'acquaintance',
#   'introduce',
#   'good',
#   'society',
#   'would',
#   'form',
#   'opinions',
#   'manners'],
#  ['would',
#   'interesting',
#   'certainly',
#   'kind',
#   'undertaking',
#   'highly',
#   'becoming',
#   'situation',
#   'life',
#   'leisure',
#   'powers'],
#  ['busy',
#   'admiring',
#   'soft',
#   'blue',
#   'eyes',
#   'talking',
#   'listening',
#   'forming',
#   'schemes',
#   'betweens',
#   'evening',
#   'flew',
#   'away',
#   'unusual',
#   'rate',
#   'supper',
#   'table',
#   'always',
#   'closed',
#   'parties',
#   'used',
#   'sit',
#   'watch',
#   'due',
#   'time',
#   'set',
#   'ready',
#   'moved',
#   'forwards',
#   'fire',
#   'aware'],
#  ['alacrity',
#   'beyond',
#   'common',
#   'impulse',
#   'spirit',
#   'yet',
#   'never',
#   'indifferent',
#   'credit',
#   'every',
#   'thing',
#   'well',
#   'attentively',
#   'real',
#   'good',
#   'mind',
#   'delighted',
#   'ideas',
#   'honours',
#   'meal',
#   'help',
#   'recommend',
#   'minced',
#   'chicken',
#   'scalloped',
#   'oysters',
#   'urgency',
#   'knew',
#   'would',
#   'acceptable',
#   'early',
#   'hours',
#   'civil',
#   'scruples',
#   'guests'],
#  ['upon',
#   'occasions',
#   'poor',
#   'mr',
#   'woodhouses',
#   'feelings',
#   'sad',
#   'warfare'],
#  ['loved',
#   'cloth',
#   'laid',
#   'fashion',
#   'youth',
#   'conviction',
#   'suppers',
#   'unwholesome',
#   'made',
#   'rather',
#   'sorry',
#   'see',
#   'thing',
#   'put',
#   'hospitality',
#   'would',
#   'welcomed',
#   'visitors',
#   'every',
#   'thing',
#   'care',
#   'health',
#   'made',
#   'grieve',
#   'would',
#   'eat'],
#  ['another',
#   'small',
#   'basin',
#   'thin',
#   'gruel',
#   'could',
#   'thorough',
#   'self',
#   'approbation',
#   'recommend',
#   'though',
#   'might',
#   'constrain',
#   'ladies',
#   'comfortably',
#   'clearing',
#   'nicer',
#   'things',
#   'say'],
#  ['mrs', 'bates', 'let', 'propose', 'venturing', 'one', 'eggs'],
#  ['egg', 'boiled', 'soft', 'unwholesome'],
#  ['serle', 'understands', 'boiling', 'egg', 'better', 'body'],
#  ['would',
#   'recommend',
#   'egg',
#   'boiled',
#   'body',
#   'else',
#   'need',
#   'afraid',
#   'small',
#   'see',
#   'one',
#   'small',
#   'eggs',
#   'hurt'],
#  ['miss',
#   'bates',
#   'let',
#   'emma',
#   'help',
#   'little',
#   'bit',
#   'tart',
#   'little',
#   'bit'],
#  ['apple', 'tarts'],
#  ['need', 'afraid', 'unwholesome', 'preserves'],
#  ['advise', 'custard'],
#  ['mrs', 'goddard', 'say', 'half', 'glass', 'wine'],
#  ['small', 'half', 'glass', 'put', 'tumbler', 'water'],
#  ['think', 'could', 'disagree'],
#  ['emma',
#   'allowed',
#   'father',
#   'talk',
#   'supplied',
#   'visitors',
#   'much',
#   'satisfactory',
#   'style',
#   'present',
#   'evening',
#   'particular',
#   'pleasure',
#   'sending',
#   'away',
#   'happy'],
#  ['happiness', 'miss', 'smith', 'quite', 'equal', 'intentions'],
#  ['miss',
#   'woodhouse',
#   'great',
#   'personage',
#   'highbury',
#   'prospect',
#   'introduction',
#   'given',
#   'much',
#   'panic',
#   'pleasure',
#   'humble',
#   'grateful',
#   'little',
#   'girl',
#   'went',
#   'highly',
#   'gratified',
#   'feelings',
#   'delighted',
#   'affability',
#   'miss',
#   'woodhouse',
#   'treated',
#   'evening',
#   'actually',
#   'shaken',
#   'hands',
#   'last'],
#  ['chapter', 'iv'],
#  ['harriet', 'smith', 'intimacy', 'hartfield', 'soon', 'settled', 'thing'],
#  ['quick',
#   'decided',
#   'ways',
#   'emma',
#   'lost',
#   'time',
#   'inviting',
#   'encouraging',
#   'telling',
#   'come',
#   'often',
#   'acquaintance',
#   'increased',
#   'satisfaction'],
#  ['walking',
#   'companion',
#   'emma',
#   'early',
#   'foreseen',
#   'useful',
#   'might',
#   'find'],
#  ['respect', 'mrs', 'weston', 'loss', 'important'],
#  ['father',
#   'never',
#   'went',
#   'beyond',
#   'shrubbery',
#   'two',
#   'divisions',
#   'ground',
#   'sufficed',
#   'long',
#   'walk',
#   'short',
#   'year',
#   'varied',
#   'since',
#   'mrs',
#   'weston',
#   'marriage',
#   'exercise',
#   'much',
#   'confined'],
#  ['ventured',
#   'alone',
#   'randalls',
#   'pleasant',
#   'harriet',
#   'smith',
#   'therefore',
#   'one',
#   'could',
#   'summon',
#   'time',
#   'walk',
#   'would',
#   'valuable',
#   'addition',
#   'privileges'],
#  ['every', 'respect', 'saw', 'approved', 'confirmed', 'kind', 'designs'],
#  ['harriet',
#   'certainly',
#   'clever',
#   'sweet',
#   'docile',
#   'grateful',
#   'disposition',
#   'totally',
#   'free',
#   'conceit',
#   'desiring',
#   'guided',
#   'one',
#   'looked'],
#  ['early',
#   'attachment',
#   'amiable',
#   'inclination',
#   'good',
#   'company',
#   'power',
#   'appreciating',
#   'elegant',
#   'clever',
#   'shewed',
#   'want',
#   'taste',
#   'though',
#   'strength',
#   'understanding',
#   'must',
#   'expected'],
#  ['altogether',
#   'quite',
#   'convinced',
#   'harriet',
#   'smith',
#   'exactly',
#   'young',
#   'friend',
#   'wanted',
#   'exactly',
#   'something',
#   'home',
#   'required'],
#  ['friend', 'mrs', 'weston', 'question'],
#  ['two', 'could', 'never', 'granted'],
#  ['two', 'want'],
#  ['quite',
#   'different',
#   'sort',
#   'thing',
#   'sentiment',
#   'distinct',
#   'independent'],
#  ['mrs', 'weston', 'object', 'regard', 'basis', 'gratitude', 'esteem'],
#  ['harriet', 'would', 'loved', 'one', 'could', 'useful'],
#  ['mrs', 'weston', 'nothing', 'done', 'harriet', 'every', 'thing'],
#  ['first',
#   'attempts',
#   'usefulness',
#   'endeavour',
#   'find',
#   'parents',
#   'harriet',
#   'could',
#   'tell'],
#  ['ready', 'tell', 'every', 'thing', 'power', 'subject', 'questions', 'vain'],
#  ['emma',
#   'obliged',
#   'fancy',
#   'liked',
#   'could',
#   'never',
#   'believe',
#   'situation',
#   'discovered',
#   'truth'],
#  ['harriet', 'penetration'],
#  ['satisfied',
#   'hear',
#   'believe',
#   'mrs',
#   'goddard',
#   'chose',
#   'tell',
#   'looked',
#   'farther'],
#  ['mrs',
#   'goddard',
#   'teachers',
#   'girls',
#   'affairs',
#   'school',
#   'general',
#   'formed',
#   'naturally',
#   'great',
#   'part',
#   'conversation',
#   'acquaintance',
#   'martins',
#   'abbey',
#   'mill',
#   'farm',
#   'must',
#   'whole'],
#  ['martins',
#   'occupied',
#   'thoughts',
#   'good',
#   'deal',
#   'spent',
#   'two',
#   'happy',
#   'months',
#   'loved',
#   'talk',
#   'pleasures',
#   'visit',
#   'describe',
#   'many',
#   'comforts',
#   'wonders',
#   'place'],
#  ['emma',
#   'encouraged',
#   'talkativeness',
#   'amused',
#   'picture',
#   'another',
#   'set',
#   'beings',
#   'enjoying',
#   'youthful',
#   'simplicity',
#   'could',
#   'speak',
#   'much',
#   'exultation',
#   'mrs',
#   'martin',
#   'two',
#   'parlours',
#   'two',
#   'good',
#   'parlours',
#   'indeed',
#   'one',
#   'quite',
#   'large',
#   'mrs',
#   'goddard',
#   'drawing',
#   'room',
#   'upper',
#   'maid',
#   'lived',
#   'five',
#   'twenty',
#   'years',
#   'eight',
#   'cows',
#   'two',
#   'alderneys',
#   'one',
#   'little',
#   'welch',
#   'cow',
#   'pretty',
#   'little',
#   'welch',
#   'cow',
#   'indeed',
#   'mrs',
#   'martin',
#   'saying',
#   'fond',
#   'called',
#   'cow',
#   'handsome',
#   'summer',
#   'house',
#   'garden',
#   'day',
#   'next',
#   'year',
#   'drink',
#   'tea',
#   'handsome',
#   'summer',
#   'house',
#   'large',
#   'enough',
#   'hold',
#   'dozen',
#   'people'],
#  ['time',
#   'amused',
#   'without',
#   'thinking',
#   'beyond',
#   'immediate',
#   'cause',
#   'came',
#   'understand',
#   'family',
#   'better',
#   'feelings',
#   'arose'],
#  ['taken',
#   'wrong',
#   'idea',
#   'fancying',
#   'mother',
#   'daughter',
#   'son',
#   'son',
#   'wife',
#   'lived',
#   'together',
#   'appeared',
#   'mr',
#   'martin',
#   'bore',
#   'part',
#   'narrative',
#   'always',
#   'mentioned',
#   'approbation',
#   'great',
#   'good',
#   'nature',
#   'something',
#   'single',
#   'man',
#   'young',
#   'mrs',
#   'martin',
#   'wife',
#   'case',
#   'suspect',
#   'danger',
#   'poor',
#   'little',
#   'friend',
#   'hospitality',
#   'kindness',
#   'taken',
#   'care',
#   'might',
#   'required',
#   'sink',
#   'forever'],
#  ['inspiriting',
#   'notion',
#   'questions',
#   'increased',
#   'number',
#   'meaning',
#   'particularly',
#   'led',
#   'harriet',
#   'talk',
#   'mr',
#   'martin',
#   'evidently',
#   'dislike'],
#  ['harriet',
#   'ready',
#   'speak',
#   'share',
#   'moonlight',
#   'walks',
#   'merry',
#   'evening',
#   'games',
#   'dwelt',
#   'good',
#   'deal',
#   'upon',
#   'good',
#   'humoured',
#   'obliging'],
#  ['gone',
#   'three',
#   'miles',
#   'round',
#   'one',
#   'day',
#   'order',
#   'bring',
#   'walnuts',
#   'said',
#   'fond',
#   'every',
#   'thing',
#   'else',
#   'obliging'],
#  ['shepherd', 'son', 'parlour', 'one', 'night', 'purpose', 'sing'],
#  ['fond', 'singing'],
#  ['could', 'sing', 'little'],
#  ['believed', 'clever', 'understood', 'every', 'thing'],
#  ['fine', 'flock', 'bid', 'wool', 'body', 'country'],
#  ['believed', 'every', 'body', 'spoke', 'well'],
#  ['mother', 'sisters', 'fond'],
#  ['mrs',
#   'martin',
#   'told',
#   'one',
#   'day',
#   'blush',
#   'said',
#   'impossible',
#   'body',
#   'better',
#   'son',
#   'therefore',
#   'sure',
#   'whenever',
#   'married',
#   'would',
#   'make',
#   'good',
#   'husband'],
#  ['wanted', 'marry'],
#  ['hurry'],
#  ['well', 'done', 'mrs'],
#  ['martin'],
#  ['thought', 'emma'],
#  ['know'],
#  ['come',
#   'away',
#   'mrs',
#   'martin',
#   'kind',
#   'send',
#   'mrs',
#   'goddard',
#   'beautiful',
#   'goose',
#   'finest',
#   'goose',
#   'mrs',
#   'goddard',
#   'ever',
#   'seen'],
#  ['mrs',
#   'goddard',
#   'dressed',
#   'sunday',
#   'asked',
#   'three',
#   'teachers',
#   'miss',
#   'nash',
#   'miss',
#   'prince',
#   'miss',
#   'richardson',
#   'sup'],
#  ['mr',
#   'martin',
#   'suppose',
#   'man',
#   'information',
#   'beyond',
#   'line',
#   'business'],
#  ['read'],
#  ['oh',
#   'yes',
#   'know',
#   'believe',
#   'read',
#   'good',
#   'deal',
#   'would',
#   'think',
#   'thing'],
#  ['reads',
#   'agricultural',
#   'reports',
#   'books',
#   'lay',
#   'one',
#   'window',
#   'seats',
#   'reads'],
#  ['sometimes',
#   'evening',
#   'went',
#   'cards',
#   'would',
#   'read',
#   'something',
#   'aloud',
#   'elegant',
#   'extracts',
#   'entertaining'],
#  ['know', 'read', 'vicar', 'wakefield'],
#  ['never', 'read', 'romance', 'forest', 'children', 'abbey'],
#  ['never', 'heard', 'books', 'mentioned', 'determined', 'get', 'soon', 'ever'],
#  ['next', 'question'],
#  ['sort', 'looking', 'man', 'mr'],
#  ['handsome', 'handsome'],
#  ['thought', 'plain', 'first', 'think', 'plain'],
#  ['one', 'know', 'time'],
#  ['never', 'see'],
#  ['highbury', 'every', 'sure', 'ride', 'every', 'week', 'way', 'kingston'],
#  ['passed', 'often'],
#  ['may', 'may', 'seen', 'fifty', 'times', 'without', 'idea', 'name'],
#  ['young',
#   'farmer',
#   'whether',
#   'horseback',
#   'foot',
#   'last',
#   'sort',
#   'person',
#   'raise',
#   'curiosity'],
#  ['yeomanry', 'precisely', 'order', 'people', 'feel', 'nothing'],
#  ['degree',
#   'two',
#   'lower',
#   'creditable',
#   'appearance',
#   'might',
#   'interest',
#   'might',
#   'hope',
#   'useful',
#   'families',
#   'way'],
#  ['farmer',
#   'need',
#   'none',
#   'help',
#   'therefore',
#   'one',
#   'sense',
#   'much',
#   'notice',
#   'every'],
#  ['sure'],
#  ['oh', 'yes'],
#  ['likely', 'ever', 'observed', 'knows', 'well', 'indeed', 'mean', 'sight'],
#  ['doubt', 'respectable', 'young', 'man'],
#  ['know', 'indeed', 'wish', 'well'],
#  ['imagine', 'age'],
#  ['four',
#   'twenty',
#   'th',
#   'last',
#   'june',
#   'birthday',
#   'rd',
#   'fortnight',
#   'day',
#   'difference',
#   'odd'],
#  ['four', 'twenty'],
#  ['young', 'settle'],
#  ['mother', 'perfectly', 'right', 'hurry'],
#  ['seem',
#   'comfortable',
#   'take',
#   'pains',
#   'marry',
#   'would',
#   'probably',
#   'repent'],
#  ['six',
#   'years',
#   'hence',
#   'could',
#   'meet',
#   'good',
#   'sort',
#   'young',
#   'woman',
#   'rank',
#   'little',
#   'money',
#   'might',
#   'desirable'],
#  ['six', 'years', 'hence'],
#  ['dear', 'miss', 'woodhouse', 'would', 'thirty', 'years', 'old'],
#  ['well', 'early', 'men', 'afford', 'marry', 'born', 'independence'],
#  ['mr',
#   'martin',
#   'imagine',
#   'fortune',
#   'entirely',
#   'make',
#   'cannot',
#   'beforehand',
#   'world'],
#  ['whatever',
#   'money',
#   'might',
#   'come',
#   'father',
#   'died',
#   'whatever',
#   'share',
#   'family',
#   'property',
#   'dare',
#   'say',
#   'afloat',
#   'employed',
#   'stock',
#   'forth',
#   'though',
#   'diligence',
#   'good',
#   'luck',
#   'may',
#   'rich',
#   'time',
#   'next',
#   'impossible',
#   'realised',
#   'thing',
#   'yet'],
#  ['live', 'comfortably'],
#  ['indoors',
#   'man',
#   'else',
#   'want',
#   'thing',
#   'mrs',
#   'martin',
#   'talks',
#   'taking',
#   'boy',
#   'another',
#   'year'],
#  ['wish',
#   'may',
#   'get',
#   'scrape',
#   'harriet',
#   'whenever',
#   'marry',
#   'mean',
#   'acquainted',
#   'wife',
#   'though',
#   'sisters',
#   'superior',
#   'education',
#   'altogether',
#   'objected',
#   'follow',
#   'might',
#   'marry',
# ...
#   'fact',
#   'given',
#   'formation',
#   'every',
#   'sentence'],
#  ['looking',
#   'letter',
#   'replying',
#   'softening',
#   'tendency',
#   'particularly',
#   'necessary',
#   'brace',
#   'decisive',
#   'expressions',
#   'much',
#   'concerned',
#   'idea',
#   'making',
#   'unhappy',
#   'thought',
#   'much',
#   'mother',
#   'sisters',
#   'would',
#   'think',
#   'say',
#   'anxious',
#   'fancy',
#   'ungrateful',
#   'emma',
#   'believed',
#   'young',
#   'man',
#   'come',
#   'way',
#   'moment',
#   'would',
#   'accepted'],
#  ['letter', 'however', 'written', 'sealed', 'sent'],
#  ['business', 'finished', 'harriet', 'safe'],
#  ['rather',
#   'low',
#   'evening',
#   'emma',
#   'could',
#   'allow',
#   'amiable',
#   'regrets',
#   'sometimes',
#   'relieved',
#   'speaking',
#   'affection',
#   'sometimes',
#   'bringing',
#   'forward',
#   'idea',
#   'mr',
#   'elton'],
#  ['shall',
#   'never',
#   'invited',
#   'abbey',
#   'mill',
#   'said',
#   'rather',
#   'sorrowful',
#   'tone'],
#  ['could', 'ever', 'bear', 'part', 'harriet'],
#  ['great', 'deal', 'necessary', 'hartfield', 'spared', 'abbey', 'mill'],
#  ['sure', 'never', 'want', 'go', 'never', 'happy', 'hartfield'],
#  ['time',
#   'afterwards',
#   'think',
#   'mrs',
#   'goddard',
#   'would',
#   'much',
#   'surprized',
#   'knew',
#   'happened'],
#  ['sure',
#   'miss',
#   'nash',
#   'would',
#   'miss',
#   'nash',
#   'thinks',
#   'sister',
#   'well',
#   'married',
#   'linen',
#   'draper'],
#  ['one',
#   'sorry',
#   'see',
#   'greater',
#   'pride',
#   'refinement',
#   'teacher',
#   'school',
#   'harriet'],
#  ['dare', 'say', 'miss', 'nash', 'would', 'envy', 'opportunity', 'married'],
#  ['even', 'conquest', 'would', 'appear', 'valuable', 'eyes'],
#  ['thing', 'superior', 'suppose', 'quite', 'dark'],
#  ['attentions',
#   'certain',
#   'person',
#   'hardly',
#   'among',
#   'tittle',
#   'tattle',
#   'highbury',
#   'yet'],
#  ['hitherto', 'fancy', 'people', 'looks', 'manners', 'explained'],
#  ['harriet',
#   'blushed',
#   'smiled',
#   'said',
#   'something',
#   'wondering',
#   'people',
#   'like',
#   'much'],
#  ['idea',
#   'mr',
#   'elton',
#   'certainly',
#   'cheering',
#   'still',
#   'time',
#   'tender',
#   'hearted',
#   'towards',
#   'rejected',
#   'mr',
#   'martin'],
#  ['got', 'letter', 'said', 'softly'],
#  ['wonder', 'whether', 'sisters', 'know', 'unhappy', 'unhappy'],
#  ['hope', 'mind', 'much'],
#  ['let',
#   'us',
#   'think',
#   'among',
#   'absent',
#   'friends',
#   'cheerfully',
#   'employed',
#   'cried',
#   'emma'],
#  ['moment',
#   'perhaps',
#   'mr',
#   'elton',
#   'shewing',
#   'picture',
#   'mother',
#   'sisters',
#   'telling',
#   'much',
#   'beautiful',
#   'original',
#   'asked',
#   'five',
#   'six',
#   'times',
#   'allowing',
#   'hear',
#   'name',
#   'dear',
#   'name'],
#  ['picture', 'left', 'picture', 'bond', 'street'],
#  ['know', 'nothing', 'mr', 'elton'],
#  ['dear',
#   'little',
#   'modest',
#   'harriet',
#   'depend',
#   'upon',
#   'picture',
#   'bond',
#   'street',
#   'till',
#   'mounts',
#   'horse',
#   'morrow'],
#  ['companion', 'evening', 'solace', 'delight'],
#  ['opens',
#   'designs',
#   'family',
#   'introduces',
#   'among',
#   'diffuses',
#   'party',
#   'pleasantest',
#   'feelings',
#   'nature',
#   'eager',
#   'curiosity',
#   'warm',
#   'prepossession'],
#  ['cheerful', 'animated', 'suspicious', 'busy', 'imaginations'],
#  ['harriet', 'smiled', 'smiles', 'grew', 'stronger'],
#  ['chapter', 'viii'],
#  ['harriet', 'slept', 'hartfield', 'night'],
#  ['weeks',
#   'past',
#   'spending',
#   'half',
#   'time',
#   'gradually',
#   'getting',
#   'bed',
#   'room',
#   'appropriated',
#   'emma',
#   'judged',
#   'best',
#   'every',
#   'respect',
#   'safest',
#   'kindest',
#   'keep',
#   'much',
#   'possible',
#   'present'],
#  ['obliged',
#   'go',
#   'next',
#   'morning',
#   'hour',
#   'two',
#   'mrs',
#   'goddard',
#   'settled',
#   'return',
#   'hartfield',
#   'make',
#   'regular',
#   'visit',
#   'days'],
#  ['gone',
#   'mr',
#   'knightley',
#   'called',
#   'sat',
#   'time',
#   'mr',
#   'woodhouse',
#   'emma',
#   'till',
#   'mr',
#   'woodhouse',
#   'previously',
#   'made',
#   'mind',
#   'walk',
#   'persuaded',
#   'daughter',
#   'defer',
#   'induced',
#   'entreaties',
#   'though',
#   'scruples',
#   'civility',
#   'leave',
#   'mr',
#   'knightley',
#   'purpose'],
#  ['mr',
#   'knightley',
#   'nothing',
#   'ceremony',
#   'offering',
#   'short',
#   'decided',
#   'answers',
#   'amusing',
#   'contrast',
#   'protracted',
#   'apologies',
#   'civil',
#   'hesitations'],
#  ['well',
#   'believe',
#   'excuse',
#   'mr',
#   'knightley',
#   'consider',
#   'rude',
#   'thing',
#   'shall',
#   'take',
#   'emma',
#   'advice',
#   'go',
#   'quarter',
#   'hour'],
#  ['sun', 'believe', 'better', 'take', 'three', 'turns'],
#  ['treat', 'without', 'ceremony', 'mr', 'knightley'],
#  ['invalids', 'think', 'privileged', 'people'],
#  ['dear', 'sir', 'make', 'stranger'],
#  ['leave', 'excellent', 'substitute', 'daughter'],
#  ['emma', 'happy', 'entertain'],
#  ['therefore',
#   'think',
#   'beg',
#   'excuse',
#   'take',
#   'three',
#   'turns',
#   'winter',
#   'walk'],
#  ['cannot', 'better', 'sir'],
#  ['would',
#   'ask',
#   'pleasure',
#   'company',
#   'mr',
#   'knightley',
#   'slow',
#   'walker',
#   'pace',
#   'would',
#   'tedious',
#   'besides',
#   'another',
#   'long',
#   'walk',
#   'donwell',
#   'abbey'],
#  ['thank',
#   'sir',
#   'thank',
#   'going',
#   'moment',
#   'think',
#   'sooner',
#   'go',
#   'better'],
#  ['fetch', 'greatcoat', 'open', 'garden', 'door'],
#  ['mr',
#   'woodhouse',
#   'last',
#   'mr',
#   'knightley',
#   'instead',
#   'immediately',
#   'likewise',
#   'sat',
#   'seemingly',
#   'inclined',
#   'chat'],
#  ['began',
#   'speaking',
#   'harriet',
#   'speaking',
#   'voluntary',
#   'praise',
#   'emma',
#   'ever',
#   'heard'],
#  ['cannot',
#   'rate',
#   'beauty',
#   'said',
#   'pretty',
#   'little',
#   'creature',
#   'inclined',
#   'think',
#   'well',
#   'disposition'],
#  ['character',
#   'depends',
#   'upon',
#   'good',
#   'hands',
#   'turn',
#   'valuable',
#   'woman'],
#  ['glad', 'think', 'good', 'hands', 'hope', 'may', 'wanting'],
#  ['come', 'said', 'anxious', 'compliment', 'tell', 'improved'],
#  ['cured', 'school', 'girl', 'giggle', 'really', 'credit'],
#  ['mortified',
#   'indeed',
#   'believe',
#   'use',
#   'every',
#   'body',
#   'bestow',
#   'praise',
#   'may'],
#  ['often', 'overpower'],
#  ['expecting', 'say', 'morning'],
#  ['almost', 'every', 'moment'],
#  ['gone', 'longer', 'already', 'intended'],
#  ['something', 'happened', 'delay', 'visitors', 'perhaps'],
#  ['highbury', 'gossips', 'tiresome', 'wretches'],
#  ['harriet', 'may', 'consider', 'every', 'body', 'tiresome', 'would'],
#  ['emma', 'knew', 'true', 'contradiction', 'therefore', 'said', 'nothing'],
#  ['presently', 'added', 'smile'],
#  ['pretend',
#   'fix',
#   'times',
#   'places',
#   'must',
#   'tell',
#   'good',
#   'reason',
#   'believe',
#   'little',
#   'friend',
#   'soon',
#   'hear',
#   'something',
#   'advantage'],
#  [],
#  ['sort'],
#  ['serious', 'sort', 'assure', 'still', 'smiling'],
#  ['serious'],
#  ['think', 'one', 'thing', 'love'],
#  ['makes', 'confidant'],
#  ['emma', 'half', 'hopes', 'mr', 'elton', 'dropt', 'hint'],
#  ['mr',
#   'knightley',
#   'sort',
#   'general',
#   'friend',
#   'adviser',
#   'knew',
#   'mr',
#   'elton',
#   'looked'],
#  ['reason',
#   'think',
#   'replied',
#   'harriet',
#   'smith',
#   'soon',
#   'offer',
#   'marriage',
#   'unexceptionable',
#   'quarter',
#   'robert',
#   'martin',
#   'man'],
#  ['visit', 'abbey', 'mill', 'summer', 'seems', 'done', 'business'],
#  ['desperately', 'love', 'means', 'marry'],
#  ['obliging', 'said', 'emma', 'sure', 'harriet', 'means', 'marry'],
#  ['well', 'well', 'means', 'make', 'offer'],
#  ['came', 'abbey', 'two', 'evenings', 'ago', 'purpose', 'consult'],
#  ['knows',
#   'thorough',
#   'regard',
#   'family',
#   'believe',
#   'considers',
#   'one',
#   'best',
#   'friends'],
#  ['came',
#   'ask',
#   'whether',
#   'thought',
#   'would',
#   'imprudent',
#   'settle',
#   'early',
#   'whether',
#   'thought',
#   'young',
#   'short',
#   'whether',
#   'approved',
#   'choice',
#   'altogether',
#   'apprehension',
#   'perhaps',
#   'considered',
#   'especially',
#   'since',
#   'making',
#   'much',
#   'line',
#   'society'],
#  ['much', 'pleased', 'said'],
#  ['never', 'hear', 'better', 'sense', 'one', 'robert', 'martin'],
#  ['always', 'speaks', 'purpose', 'open', 'straightforward', 'well', 'judging'],
#  ['told',
#   'every',
#   'thing',
#   'circumstances',
#   'plans',
#   'proposed',
#   'event',
#   'marriage'],
#  ['excellent', 'young', 'man', 'son', 'brother'],
#  ['hesitation', 'advising', 'marry'],
#  ['proved', 'could', 'afford', 'case', 'convinced', 'could', 'better'],
#  ['praised', 'fair', 'lady', 'altogether', 'sent', 'away', 'happy'],
#  ['never',
#   'esteemed',
#   'opinion',
#   'would',
#   'thought',
#   'highly',
#   'dare',
#   'say',
#   'left',
#   'house',
#   'thinking',
#   'best',
#   'friend',
#   'counsellor',
#   'man',
#   'ever'],
#  ['happened', 'night', 'last'],
#  ['may',
#   'fairly',
#   'suppose',
#   'would',
#   'allow',
#   'much',
#   'time',
#   'pass',
#   'spoke',
#   'lady',
#   'appear',
#   'spoken',
#   'yesterday',
#   'unlikely',
#   'mrs',
#   'goddard',
#   'day',
#   'may',
#   'detained',
#   'visitor',
#   'without',
#   'thinking',
#   'tiresome',
#   'wretch'],
#  ['pray',
#   'mr',
#   'knightley',
#   'said',
#   'emma',
#   'smiling',
#   'great',
#   'part',
#   'speech',
#   'know',
#   'mr',
#   'martin',
#   'speak',
#   'yesterday'],
#  ['certainly',
#   'replied',
#   'surprized',
#   'absolutely',
#   'know',
#   'may',
#   'inferred'],
#  ['whole', 'day'],
#  ['come', 'said', 'tell', 'something', 'return', 'told'],
#  ['speak', 'yesterday', 'wrote', 'refused'],
#  ['obliged',
#   'repeated',
#   'could',
#   'believed',
#   'mr',
#   'knightley',
#   'actually',
#   'looked',
#   'red',
#   'surprize',
#   'displeasure',
#   'stood',
#   'tall',
#   'indignation',
#   'said'],
#  ['greater', 'simpleton', 'ever', 'believed'],
#  ['foolish', 'girl'],
#  ['sure',
#   'cried',
#   'emma',
#   'always',
#   'incomprehensible',
#   'man',
#   'woman',
#   'ever',
#   'refuse',
#   'offer',
#   'marriage'],
#  ['man', 'always', 'imagines', 'woman', 'ready', 'body', 'asks'],
#  ['nonsense'],
#  ['man', 'imagine', 'thing'],
#  ['meaning'],
#  ['harriet', 'smith', 'refuse', 'robert', 'martin'],
#  ['madness', 'hope', 'mistaken'],
#  ['saw', 'answer', 'nothing', 'could', 'clearer'],
#  ['saw', 'answer', 'wrote', 'answer'],
#  ['emma'],
#  ['persuaded', 'refuse'],
#  ['however', 'far', 'allowing', 'feel', 'done', 'wrong'],
#  ['mr',
#   'martin',
#   'respectable',
#   'young',
#   'man',
#   'cannot',
#   'admit',
#   'harriet',
#   'equal',
#   'rather',
#   'surprized',
#   'indeed',
#   'ventured',
#   'address'],
#  ['account', 'seem', 'scruples'],
#  ['pity', 'ever', 'got'],
#  ['harriet', 'equal'],
#  ['exclaimed',
#   'mr',
#   'knightley',
#   'loudly',
#   'warmly',
#   'calmer',
#   'asperity',
#   'added',
#   'moments',
#   'afterwards',
#   'equal',
#   'indeed',
#   'much',
#   'superior',
#   'sense',
#   'situation'],
#  ['emma', 'infatuation', 'girl', 'blinds'],
#  ['harriet',
#   'smith',
#   'claims',
#   'either',
#   'birth',
#   'nature',
#   'education',
#   'connexion',
#   'higher',
#   'robert',
#   'martin'],
#  ['natural',
#   'daughter',
#   'nobody',
#   'knows',
#   'probably',
#   'settled',
#   'provision',
#   'certainly',
#   'respectable',
#   'relations'],
#  ['known', 'parlour', 'boarder', 'common', 'school'],
#  ['sensible', 'girl', 'girl', 'information'],
#  ['taught', 'nothing', 'useful', 'young', 'simple', 'acquired', 'thing'],
#  ['age', 'experience', 'little', 'wit', 'likely', 'ever', 'avail'],
#  ['pretty', 'good', 'tempered'],
#  ['scruple',
#   'advising',
#   'match',
#   'account',
#   'beneath',
#   'deserts',
#   'bad',
#   'connexion'],
#  ['felt',
#   'fortune',
#   'probability',
#   'might',
#   'much',
#   'better',
#   'rational',
#   'companion',
#   'useful',
#   'helpmate',
#   'could',
#   'worse'],
#  ['could',
#   'reason',
#   'man',
#   'love',
#   'willing',
#   'trust',
#   'harm',
#   'sort',
#   'disposition',
#   'good',
#   'hands',
#   'like',
#   'might',
#   'easily',
#   'led',
#   'aright',
#   'turn',
#   'well'],
#  ['advantage',
#   'match',
#   'felt',
#   'side',
#   'smallest',
#   'doubt',
#   'would',
#   'general',
#   'cry',
#   'upon',
#   'extreme',
#   'good',
#   'luck'],
#  ['even', 'satisfaction', 'made', 'sure'],
#  ['crossed',
#   'mind',
#   'immediately',
#   'would',
#   'regret',
#   'friend',
#   'leaving',
#   'highbury',
#   'sake',
#   'settled',
#   'well'],
#  ['remember',
#   'saying',
#   'even',
#   'emma',
#   'partiality',
#   'harriet',
#   'think',
#   'good',
#   'match'],
#  ['cannot', 'help', 'wondering', 'knowing', 'little', 'emma', 'say', 'thing'],
#  ['think',
#   'farmer',
#   'sense',
#   'merit',
#   'mr',
#   'martin',
#   'nothing',
#   'good',
#   'match',
#   'intimate',
#   'friend'],
#  ['regret',
#   'leaving',
#   'highbury',
#   'sake',
#   'marrying',
#   'man',
#   'could',
#   'never',
#   'admit',
#   'acquaintance'],
#  ['wonder', 'think', 'possible', 'feelings'],
#  ['assure', 'mine', 'different'],
#  ['must', 'think', 'statement', 'means', 'fair'],
#  ['harriet', 'claims'],
#  ['would',
#   'estimated',
#   'differently',
#   'others',
#   'well',
#   'mr',
#   'martin',
#   'may',
#   'richest',
#   'two',
#   'undoubtedly',
#   'inferior',
#   'rank',
#   'society',
#   'sphere',
#   'moves',
#   'much',
#   'would',
#   'degradation'],
#  ['degradation',
#   'illegitimacy',
#   'ignorance',
#   'married',
#   'respectable',
#   'intelligent',
#   'gentleman',
#   'farmer'],
#  ['circumstances',
#   'birth',
#   'though',
#   'legal',
#   'sense',
#   'may',
#   'called',
#   'nobody',
#   'hold',
#   'common',
#   'sense'],
#  ['pay',
#   'offence',
#   'others',
#   'held',
#   'level',
#   'brought',
#   'scarcely',
#   'doubt',
#   'father',
#   'gentleman',
#   'gentleman',
#   'fortune',
#   'allowance',
#   'liberal',
#   'nothing',
#   'ever',
#   'grudged',
#   'improvement',
#   'comfort',
#   'gentleman',
#   'daughter',
#   'indubitable',
#   'associates',
#   'gentlemen',
#   'daughters',
#   'one',
#   'apprehend',
#   'deny',
#   'superior',
#   'mr',
#   'robert',
#   'martin'],
#  ['whoever',
#   'might',
#   'parents',
#   'said',
#   'mr',
#   'knightley',
#   'whoever',
#   'may',
#   'charge',
#   'appear',
#   'part',
#   'plan',
#   'introduce',
#   'would',
#   'call',
#   'good',
#   'society'],
#  ['receiving',
#   'indifferent',
#   'education',
#   'left',
#   'mrs',
#   'goddard',
#   'hands',
#   'shift',
#   'move',
#   'short',
#   'mrs',
#   'goddard',
#   'line',
#   'mrs',
#   'goddard',
#   'acquaintance'],
#  ['friends', 'evidently', 'thought', 'good', 'enough', 'good', 'enough'],
#  ['desired', 'nothing', 'better'],
#  ['till',
#   'chose',
#   'turn',
#   'friend',
#   'mind',
#   'distaste',
#   'set',
#   'ambition',
#   'beyond'],
#  ['happy', 'possible', 'martins', 'summer'],
#  ['sense', 'superiority'],
#  ['given'],
#  ['friend', 'harriet', 'smith', 'emma'],
#  ['robert',
#   'martin',
#   'would',
#   'never',
#   'proceeded',
#   'far',
#   'felt',
#   'persuaded',
#   'disinclined'],
#  ['know', 'well'],
#  ['much',
#   'real',
#   'feeling',
#   'address',
#   'woman',
#   'haphazard',
#   'selfish',
#   'passion'],
#  ['conceit', 'farthest', 'man', 'know'],
#  ['depend', 'upon', 'encouragement'],
#  ['convenient',
#   'emma',
#   'make',
#   'direct',
#   'reply',
#   'assertion',
#   'chose',
#   'rather',
#   'take',
#   'line',
#   'subject'],
#  ['warm', 'friend', 'mr', 'martin', 'said', 'unjust', 'harriet'],
#  ['harriet', 'claims', 'marry', 'well', 'contemptible', 'represent'],
#  ['clever',
#   'girl',
#   'better',
#   'sense',
#   'aware',
#   'deserve',
#   'understanding',
#   'spoken',
#   'slightingly'],
#  ['waiving',
#   'point',
#   'however',
#   'supposing',
#   'describe',
#   'pretty',
#   'good',
#   'natured',
#   'let',
#   'tell',
#   'degree',
#   'possesses',
#   'trivial',
#   'recommendations',
#   'world',
#   'general',
#   'fact',
#   'beautiful',
#   'girl',
#   'must',
#   'thought',
#   'ninety',
#   'nine',
#   'people',
#   'hundred',
#   'till',
#   'appears',
#   'men',
#   'much',
#   'philosophic',
#   'subject',
#   'beauty',
#   'generally',
#   'supposed',
#   'till',
#   'fall',
#   'love',
#   'well',
#   'informed',
#   'minds',
#   'instead',
#   'handsome',
#   'faces',
#   'girl',
#   'loveliness',
#   'harriet',
#   'certainty',
#   'admired',
#   'sought',
#   'power',
#   'chusing',
#   'among',
#   'many',
#   'consequently',
#   'claim',
#   'nice'],
#  ['good',
#   'nature',
#   'slight',
#   'claim',
#   'comprehending',
#   'real',
#   'thorough',
#   'sweetness',
#   'temper',
#   'manner',
#   'humble',
#   'opinion',
#   'great',
#   'readiness',
#   'pleased',
#   'people'],
#  ['much',
#   'mistaken',
#   'sex',
#   'general',
#   'would',
#   'think',
#   'beauty',
#   'temper',
#   'highest',
#   'claims',
#   'woman',
#   'could',
#   'possess'],
#  ['upon',
#   'word',
#   'emma',
#   'hear',
#   'abusing',
#   'reason',
#   'almost',
#   'enough',
#   'make',
#   'think'],
#  ['better', 'without', 'sense', 'misapply'],
#  ['cried', 'playfully'],
#  ['know', 'feeling'],
#  ['know',
#   'girl',
#   'harriet',
#   'exactly',
#   'every',
#   'man',
#   'delights',
#   'bewitches',
#   'senses',
#   'satisfies',
#   'judgment'],
#  ...]

# %%
phrases = Phrases(sent, min_count=30, progress_per=10000)

# %% [markdown]
# The goal of Phraser() is to cut down memory consumption of Phrases(), by discarding model state not strictly needed for the bigram detection task:

# %%
bigram = Phraser(phrases)

# %%
sentences = bigram[sent]

# %%
len(sentences)
# Out:
# 91044

# %%
#She was the youngest of the two daughters of a most affectionate, indulgent father; and had, in consequence of her sister's marriage, been mistress of his house from a very early period.
print(sentences[4])
# Out:
# ['youngest', 'two', 'daughters', 'affectionate', 'indulgent', 'father', 'consequence', 'sister', 'marriage', 'mistress', 'house', 'early', 'period']

# %% [markdown]
# ####  Most Frequent Words:

# %%
word_freq = defaultdict(int)
for sent in sentences:
    for i in sent:
        word_freq[i] += 1
len(word_freq)
# Out:
# 41681

# %%
word_freq
# Out:
# defaultdict(int,
#             {'emma': 860,
#              'jane': 192,
#              'austen': 3,
#              'volume': 32,
#              'chapter': 93,
#              'woodhouse': 8,
#              'handsome': 131,
#              'clever': 76,
#              'rich': 239,
#              'comfortable': 108,
#              'home': 682,
#              'happy': 566,
#              'disposition': 73,
#              'seemed': 1086,
#              'unite': 17,
#              'best': 588,
#              'blessings': 26,
#              'existence': 48,
#              'lived': 263,
#              'nearly': 141,
#              'twenty': 270,
#              'one': 5608,
#              'years': 486,
#              'world': 1285,
#              'little': 2704,
#              'distress': 112,
#              'vex': 25,
#              'youngest': 42,
#              'two': 2088,
#              'daughters': 239,
#              'affectionate': 56,
#              'indulgent': 11,
#              'father': 2000,
#              'consequence': 130,
#              'sister': 606,
#              'marriage': 151,
#              'mistress': 139,
#              'house': 2685,
#              'early': 235,
#              'period': 64,
#              'mother': 1094,
#              'died': 301,
#              'long_ago': 38,
#              'indistinct': 4,
#              'remembrance': 90,
#              'caresses': 7,
#              'place': 1522,
#              'supplied': 36,
#              'excellent': 172,
#              'woman': 901,
#              'governess': 17,
#              'fallen': 208,
#              'short': 400,
#              'affection': 167,
#              'sixteen': 44,
#              'miss_taylor': 49,
#              'mr_woodhouse': 132,
#              'family': 485,
#              'less': 483,
#              'friend': 746,
#              'fond': 156,
#              'particularly': 136,
#              'intimacy': 47,
#              'sisters': 161,
#              'even': 2475,
#              'ceased': 78,
#              'hold': 545,
#              'nominal': 4,
#              'office': 119,
#              'mildness': 16,
#              'temper': 137,
#              'hardly': 307,
#              'allowed': 104,
#              'impose': 14,
#              'restraint': 22,
#              'shadow': 162,
#              'authority': 89,
#              'long': 1722,
#              'passed': 508,
#              'away': 1664,
#              'living': 427,
#              'together': 835,
#              'mutually': 8,
#              'attached': 75,
#              'liked': 100,
#              'highly': 100,
#              'esteeming': 3,
#              'judgment': 377,
#              'directed': 35,
#              'chiefly': 57,
#              'real': 264,
#              'evils': 38,
#              'indeed': 837,
#              'situation': 169,
#              'power': 608,
#              'rather': 809,
#              'much': 2264,
#              'way': 1908,
#              'think': 1672,
#              'well': 2462,
#              'disadvantages': 3,
#              'threatened': 22,
#              'alloy': 7,
#              'many': 1535,
#              'enjoyments': 10,
#              'danger': 145,
#              'however': 673,
#              'present': 605,
#              'unperceived': 6,
#              'means': 288,
#              'rank': 64,
#              'misfortunes': 6,
#              'sorrow': 170,
#              'came': 2867,
#              'gentle': 111,
#              'shape': 161,
#              'disagreeable': 34,
#              'consciousness': 56,
#              'married': 182,
#              'loss': 114,
#              'first': 1861,
#              'brought': 1117,
#              'grief': 67,
#              'wedding': 41,
#              'day': 2869,
#              'beloved': 153,
#              'sat': 563,
#              'mournful': 12,
#              'thought': 1334,
#              'continuance': 17,
#              'bride': 45,
#              'people': 2685,
#              'gone': 698,
#              'left': 1021,
#              'dine': 47,
#              'prospect': 58,
#              'third': 217,
#              'cheer': 35,
#              'evening': 495,
#              'composed': 37,
#              'sleep': 296,
#              'dinner': 203,
#              'usual': 186,
#              'sit': 335,
#              'lost': 354,
#              'event': 92,
#              'every': 1759,
#              'promise': 201,
#              'happiness': 234,
#              'mr_weston': 162,
#              'man': 4763,
#              'unexceptionable': 8,
#              'character': 215,
#              'easy': 169,
#              'fortune': 175,
#              'suitable': 15,
#              'age': 175,
#              'pleasant': 198,
#              'manners': 159,
#              'satisfaction': 106,
#              'considering': 87,
#              'self': 184,
#              'denying': 23,
#              'generous': 62,
#              'friendship': 103,
#              'always': 1008,
#              'wished': 183,
#              'promoted': 12,
#              'match': 92,
#              'black': 467,
#              'morning': 751,
#              'work': 885,
#              'want': 536,
#              'would': 4031,
#              'felt': 607,
#              'hour': 384,
#              'recalled': 21,
#              'past': 325,
#              'kindness': 167,
#              'taught': 177,
#              'played': 66,
#              'five_years': 41,
#              'old': 1626,
#              'devoted': 30,
#              'powers': 114,
#              'attach': 18,
#              'amuse': 18,
#              'health': 161,
#              'nursed': 7,
#              'various': 103,
#              'illnesses': 3,
#              'childhood': 23,
#              'large': 434,
#              'debt': 25,
#              'gratitude': 80,
#              'owing': 35,
#              'intercourse': 32,
#              'last': 1259,
#              'seven_years': 55,
#              'equal': 216,
#              'footing': 10,
#              'perfect': 289,
#              'unreserve': 10,
#              'soon': 1042,
#              'followed': 302,
#              'isabella': 93,
#              'yet': 2231,
#              'dearer': 14,
#              'tenderer': 2,
#              'recollection': 48,
#              'companion': 143,
#              'possessed': 63,
#              'intelligent': 26,
#              'informed': 51,
#              'useful': 62,
#              'knowing': 172,
#              'ways': 307,
#              'interested': 45,
#              'concerns': 29,
#              'peculiarly': 25,
#              'pleasure': 413,
#              'scheme': 69,
#              'could': 3479,
#              'speak': 993,
#              'arose': 210,
#              'never': 1828,
#              'find': 724,
#              'fault': 97,
#              'bear': 461,
#              'change': 272,
#              'true': 511,
#              'going': 779,
#              'half': 804,
#              'mile': 67,
#              'aware': 85,
#              'great': 2678,
#              'must': 2330,
#              'difference': 147,
#              'mrs_weston': 249,
#              'advantages': 37,
#              'natural': 223,
#              'domestic': 47,
#              'suffering': 80,
#              'intellectual': 38,
#              'solitude': 39,
#              'dearly': 23,
#              'loved': 232,
#              'meet': 368,
#              'conversation': 188,
#              'rational': 46,
#              'playful': 9,
#              'evil': 757,
#              'actual': 27,
#              'disparity': 10,
#              'ages': 77,
#              'increased': 112,
#              'constitution': 18,
#              'habits': 50,
#              'valetudinarian': 1,
#              'life': 1439,
#              'without': 1534,
#              'activity': 27,
#              'mind': 763,
#              'body': 613,
#              'older': 37,
#              'though': 1738,
#              'everywhere': 49,
#              'friendliness': 11,
#              'heart': 1381,
#              'amiable': 76,
#              'talents': 73,
#              'recommended': 30,
#              'time': 2703,
#              'comparatively': 36,
#              'removed': 157,
#              'matrimony': 11,
#              'settled': 152,
#              'london': 172,
#              'miles': 128,
#              'beyond': 356,
#              'daily': 129,
#              'reach': 118,
#              'october': 11,
#              'november': 21,
#              'struggled': 14,
#              'hartfield': 160,
#              'christmas': 54,
#              'next': 392,
#              'visit': 274,
#              'husband': 318,
#              'children': 1426,
#              'fill': 180,
#              'give': 1816,
#              'society': 151,
#              'highbury': 125,
#              'populous': 21,
#              'village': 131,
#              'almost': 765,
#              'amounting': 4,
#              'town': 273,
#              'spite': 135,
#              'separate': 108,
#              'lawn': 30,
#              'shrubberies': 7,
#              'name': 1316,
#              'really': 668,
#              'belong': 77,
#              'afforded': 25,
#              'equals': 14,
#              'woodhouses': 4,
#              'looked': 982,
#              'acquaintance': 217,
#              'universally': 15,
#              'civil': 58,
#              'among': 1215,
#              'accepted': 71,
#              'lieu': 3,
#              'melancholy': 67,
#              'sigh': 84,
#              'wish': 495,
#              'impossible': 171,
#              'things': 1973,
#              'till': 1016,
#              'awoke': 20,
#              'made': 2739,
#              'necessary': 150,
#              'cheerful': 97,
#              'spirits': 330,
#              'required': 78,
#              'support': 57,
#              'nervous': 40,
#              'easily': 134,
#              'depressed': 11,
#              'every_body': 148,
#              'used': 313,
#              'hating': 9,
#              'part': 816,
#              'kind': 472,
#              'origin': 20,
#              'reconciled': 28,
#              'daughter': 568,
#              'marrying': 51,
#              'ever': 1569,
#              'compassion': 88,
#              'entirely': 189,
#              'obliged': 180,
#              'selfishness': 20,
#              'able': 399,
#              'suppose': 362,
#              'feel': 425,
#              'differently': 30,
#              'disposed': 84,
#              'done': 1216,
#              'sad': 150,
#              'thing': 1712,
#              'great_deal': 182,
#              'happier': 49,
#              'spent': 129,
#              'rest': 709,
#              'smiled': 99,
#              'chatted': 2,
#              'cheerfully': 27,
#              'keep': 668,
#              'thoughts': 323,
#              'tea': 88,
#              'say': 2165,
#              'exactly': 223,
#              'said': 7084,
#              'poor': 859,
#              'pity': 150,
#              'cannot': 815,
#              'agree': 55,
#              'papa': 94,
#              'know': 3016,
#              'good': 2685,
#              'humoured': 35,
#              'thoroughly': 56,
#              'deserves': 22,
#              'wife': 734,
#              'live': 547,
#              'us': 2400,
#              'odd': 90,
#              'humours': 9,
#              'might': 1959,
#              'advantage': 116,
#              'three_times': 29,
#              'dear': 710,
#              'often': 423,
#              'shall': 11459,
#              'see': 2852,
#              'coming': 516,
#              'meeting': 156,
#              'begin': 172,
#              'go': 2712,
#              'pay': 212,
#              'get': 733,
#              'far': 944,
#              'randalls': 90,
#              'distance': 162,
#              'walk': 504,
#              'nobody': 222,
#              'walking': 227,
#              'carriage': 194,
#              'sure': 901,
#              'james': 106,
#              'like': 3455,
#              'put': 1501,
#              'horses': 246,
#              'paying': 34,
#              'stable': 39,
#              'already': 310,
#              'talked': 223,
#              'last_night': 70,
#              'may': 2551,
#              'housemaid': 4,
#              'doubt': 354,
#              'whether': 602,
#              'take': 1549,
#              'anywhere': 72,
#              'else': 503,
#              'got': 489,
#              'hannah': 15,
#              'mentioned': 105,
#              'glad': 364,
#              'lucky': 65,
#              'slighted': 16,
#              'upon': 4456,
#              'account': 257,
#              'make': 2147,
#              'servant': 425,
#              'pretty': 291,
#              'spoken': 349,
#              'girl': 231,
#              'opinion': 219,
#              'whenever': 112,
#              'curtseys': 1,
#              'asks': 10,
#              'manner': 509,
#              'needlework': 10,
#              'observe': 137,
#              'turns': 95,
#              'lock': 42,
#              'door': 705,
#              'right': 877,
#              'bangs': 1,
#              'comfort': 260,
#              'somebody': 82,
#              'goes': 188,
#              'hearing': 172,
#              'tell': 1138,
#              'spared': 39,
#              'exertions': 20,
#              'maintain': 24,
#              'flow': 61,
#              'ideas': 55,
#              'hoped': 107,
#              'help': 352,
#              'backgammon': 3,
#              'tolerably': 35,
#              'attacked': 14,
#              'regrets': 16,
#              'table': 394,
#              'placed': 132,
#              'visitor': 22,
#              'immediately': 343,
#              'afterwards': 196,
#              'walked': 367,
#              'unnecessary': 37,
#              'mr_knightley': 276,
#              'sensible': 96,
#              'seven': 316,
#              'eight': 171,
#              'thirty': 201,
#              'intimate': 40,
#              'connected': 53,
#              'elder': 52,
#              'brother': 802,
#              'frequent': 44,
#              'welcome': 155,
#              'directly': 170,
#              'mutual': 45,
#              'connexions': 18,
#              'returned': 409,
#              'late': 249,
#              'days': 1064,
#              'absence': 68,
#              'brunswick': 11,
#              'square': 139,
#              'circumstance': 118,
#              'animated': 27,
#              'inquiries': 34,
#              'answered': 571,
#              'satisfactorily': 3,
#              'gratefully': 16,
#              'observed': 146,
#              'come': 3439,
#              'call': 653,
#              'afraid': 495,
#              'shocking': 33,
#              'sir': 707,
#              'beautiful': 265,
#              'moonlight': 36,
#              'night': 1092,
#              'mild': 71,
#              'draw': 181,
#              'back': 1068,
#              'fire': 888,
#              'found': 1260,
#              'damp': 31,
#              'dirty': 37,
#              'catch': 135,
#              'cold': 281,
#              'look': 1156,
#              'shoes': 80,
#              'speck': 4,
#              'quite': 1070,
#              'surprising': 18,
#              'vast': 182,
#              'deal': 96,
#              'rain': 198,
#              'rained': 17,
#              'dreadfully': 25,
#              'hard': 342,
#              'half_hour': 73,
#              'breakfast': 130,
#              'wanted': 276,
#              'bye': 14,
#              'joy': 435,
#              'sort': 592,
#              'feeling': 207,
#              'hurry': 124,
#              'congratulations': 9,
#              'hope': 676,
#              'went': 2210,
#              'behave': 24,
#              'cried': 1065,
#              'ah': 128,
#              'tis': 196,
#              'business': 372,
#              'mr': 1139,
#              'miss_woodhouse': 172,
#              'please': 312,
#              'possibly': 53,
#              'regard': 184,
#              'comes': 304,
#              'question': 259,
#              'dependence': 24,
#              'independence': 28,
#              'rate': 93,
#              'better': 873,
#              'especially': 169,
#              'fanciful': 14,
#              'troublesome': 22,
#              'creature': 187,
#              'playfully': 6,
#              'head': 1440,
#              'certainly': 399,
#              'believe': 651,
#              'sometimes': 286,
#              'dearest': 54,
#              'mean': 522,
#              'horrible': 75,
#              'idea': 295,
#              'oh': 773,
#              'meant': 203,
#              'loves': 49,
#              'joke': 38,
#              'one_another': 211,
#              'fact': 228,
#              'faults': 39,
#              'told': 780,
#              'agreeable': 120,
#              'knew': 745,
#              'suspect': 65,
#              'knows': 181,
#              'flatter': 21,
#              'reflection': 61,
#              'persons': 148,
#              'chances': 22,
#              'gainer': 3,
#              'willing': 94,
#              'let': 2254,
#              'pass': 460,
#              'hear': 1215,
#              'behaved': 41,
#              'charmingly': 5,
#              'punctual': 10,
#              'looks': 195,
#              'tear': 53,
#              'face': 1272,
#              'seen': 927,
#              'apart': 61,
#              'bears': 27,
#              'every_thing': 258,
#              'sorry': 209,
#              'lose': 117,
#              'miss': 498,
#              'thinks': 91,
#              'turned': 669,
#              'divided': 119,
#              'tears': 181,
#              'smiles': 62,
#              'acceptable': 39,
#              'important': 113,
#              'secure': 100,
#              'provision': 22,
#              'therefore': 1554,
#              'allow': 119,
#              'pain': 199,
#              'happily': 47,
#              'forgotten': 154,
#              'matter': 482,
#              'considerable': 98,
#              'four': 494,
#              'years_ago': 40,
#              'proved': 99,
#              'marry': 169,
#              'shook': 103,
#              'fondly': 15,
#              'replied': 479,
#              'matches': 11,
#              'foretell': 5,
#              'whatever': 227,
#              'pray': 346,
#              'none': 684,
#              'greatest': 148,
#              'amusement': 54,
#              'success': 72,
#              'widower': 6,
#              'perfectly': 242,
#              'constantly': 38,
#              'occupied': 57,
#              'either': 380,
#              'friends': 482,
#              'wherever': 60,
#              'need': 279,
#              'spend': 77,
#              'single': 135,
#              'year': 550,
#              'alone': 499,
#              'deathbed': 2,
#              'others': 516,
#              'son': 2688,
#              'uncle': 113,
#              'letting': 26,
#              'solemn': 109,
#              'nonsense': 63,
#              'subject': 267,
#              'believed': 246,
#              'ever_since': 69,
#              'met': 241,
#              'broadway': 10,
#              'lane': 60,
#              'began': 706,
#              'drizzle': 1,
#              'darted': 49,
#              'gallantry': 22,
#              'borrowed': 18,
#              'umbrellas': 4,
#              'farmer': 113,
#              'mitchell': 1,
#              'planned': 10,
#              'blessed': 349,
#              'instance': 66,
#              'leave': 511,
#              'making': 337,
#              'understand': 417,
#              'supposes': 5,
#              'endeavour': 28,
#              'properly': 56,
#              'delicately': 8,
#              'endeavouring': 20,
#              'bring': 887,
#              'worthy': 156,
#              'employment': 37,
#              'young_lady': 73,
#              'imagine': 127,
#              'planning': 8,
#              'saying': 1671,
#              'idle': 79,
#              'talk': 346,
#              'merit': 52,
#              'proud': 183,
#              'guess': 115,
#              'known': 615,
#              'triumph': 71,
#              'cleverer': 5,
#              'depend_upon': 46,
#              'merely': 171,
#              'luck': 78,
#              'talent': 26,
#              'word': 1026,
#              'quarrel': 56,
#              'claim': 50,
#              'drawn': 138,
#              'pictures': 46,
#              'something': 942,
#              'nothing': 1411,
#              'visits': 39,
#              'given': 731,
#              'encouragements': 2,
#              'smoothed': 6,
#              'matters': 89,
#              'enough': 805,
#              'comprehend': 53,
#              'straightforward': 4,
#              'open': 568,
#              'hearted': 57,
#              'weston': 25,
#              'unaffected': 14,
#              'safely': 86,
#              'manage': 31,
#              'likely': 153,
#              'harm': 90,
#              'interference': 19,
#              'rejoined': 12,
#              'understanding': 242,
#              'silly': 65,
#              'break': 262,
#              'circle': 90,
#              'grievously': 8,
#              'mr_elton': 213,
#              'whole': 938,
#              'fitted': 38,
#              'comfortably': 31,
#              'shame': 205,
#              'longer': 311,
#              'joining': 17,
#              'hands': 1002,
#              'service': 225,
#              'young_man': 268,
#              'shew': 317,
#              'attention': 200,
#              'ask': 433,
#              'dare_say': 116,
#              'laughing': 178,
#              'invite': 27,
#              'fish': 331,
#              'chicken': 8,
#              'chuse': 31,
#              'six': 299,
#              'take_care': 73,
#              'ii': 25,
#              'native': 66,
#              'born': 300,
#              'respectable': 60,
#              'two_three': 98,
#              'generations': 138,
#              'rising': 187,
#              'gentility': 9,
#              'property': 58,
#              'received': 364,
#              'education': 56,
#              'succeeding': 19,
#              'small': 569,
#              'become': 322,
#              'indisposed': 8,
#              'homely': 10,
#              'pursuits': 17,
#              'brothers': 71,
#              'engaged': 142,
#              'satisfied': 198,
#              'active': 52,
#              'social': 44,
#              'entering': 90,
#              'militia': 7,
#              'county': 21,
#              'embodied': 5,
#              'captain': 467,
#              'general': 296,
#              'favourite': 105,
#              'military': 29,
#              'introduced': 46,
#              'churchill': 80,
#              'yorkshire': 10,
#              'fell': 538,
#              'love': 1112,
#              'surprized': 33,
#              'except': 291,
#              'full': 817,
#              'pride': 172,
#              'importance': 68,
#              'connexion': 41,
#              'offend': 54,
#              'command': 254,
#              'bore': 76,
#              'proportion': 29,
#              'estate': 66,
#              'dissuaded': 1,
#              'took': 1242,
#              'infinite': 64,
#              'mortification': 22,
#              'mrs_churchill': 59,
#              'threw': 110,
#              'due': 149,
#              'decorum': 10,
#              'unsuitable': 5,
#              'produce': 56,
#              'ought': 386,
#              'whose': 756,
#              'warm': 139,
#              'sweet': 365,
#              'return': 558,
#              'goodness': 110,
#              'spirit': 742,
#              'resolution': 87,
#              'pursue': 50,
#              'refrain': 25,
#              'unreasonable': 23,
#              'anger': 308,
#              'missing': 33,
#              'luxuries': 4,
#              'former': 174,
#              'income': 42,
#              'still': 1350,
#              'comparison': 47,
#              'enscombe': 36,
#              'cease': 120,
#              'considered': 127,
#              'churchills': 15,
#              'amazing': 12,
#              'worst': 89,
#              'bargain': 20,
#              'three_years': 73,
#              'poorer': 5,
#              'child': 545,
#              'expense': 37,
#              'relieved': 30,
#              'boy': 490,
#              'additional': 30,
#              'softening': 5,
#              'lingering': 27,
#              'illness': 33,
#              'reconciliation': 21,
#              'young': 569,
#              'kindred': 38,
#              'care': 222,
#              'offered': 222,
#              'charge': 211,
#              'frank': 74,
#              'decease': 8,
#              'scruples': 21,
#              'reluctance': 10,
#              'supposed': 139,
#              'overcome': 72,
#              'considerations': 10,
#              'wealth': 84,
#              'seek': 345,
#              'improve': 23,
#              'complete': 117,
#              'became': 284,
#              'desirable': 44,
#              'quitted': 41,
#              'trade': 51,
#              'established': 108,
#              'favourable': 34,
#              'opening': 110,
#              'concern': 74,
#              'leisure': 49,
#              'occupation': 24,
#              'pleasures': 41,
#              'eighteen': 47,
#              'twenty_years': 63,
#              'realised': 11,
#              'competence': 4,
#              'purchase': 34,
#              'adjoining': 17,
#              'longed': 37,
#              'portionless': 1,
#              'according': 818,
#              'wishes': 77,
#              'friendly': 83,
#              'since': 472,
#              'begun': 102,
#              'influence': 99,
#              'schemes': 20,
#              'tyrannic': 2,
#              'youth': 208,
#              'shaken': 53,
#              'determination': 20,
#              'settling': 25,
#              'sale': 17,
#              'forward': 309,
#              'steadily': 70,
#              'objects': 65,
#              'view': 172,
#              'accomplished': 52,
#              'bought': 97,
#              'obtained': 57,
#              'beginning': 278,
#              'new': 789,
#              'probability': 39,
#              'greater': 235,
#              'unhappy': 67,
#              'secured': 46,
#              'second': 457,
#              'delightful': 88,
#              'judging': 31,
#              'truly': 124,
#              'pleasantest': 7,
#              'proof': 97,
#              'choose': 134,
#              'chosen': 165,
#              'excite': 22,
#              'choice': 103,
#              'tacitly': 3,
#              'heir': 48,
#              'avowed': 2,
#              'adoption': 9,
#              'assume': 31,
#              'unlikely': 10,
#              'assistance': 55,
#              'apprehension': 22,
#              'aunt': 92,
#              'capricious': 11,
#              'governed': 17,
#              'nature': 407,
#              'caprice': 10,
#              'strong': 611,
#              'affect': 25,
#              'deservedly': 3,
#              'saw': 1632,
#              'report': 88,
#              'fine': 355,
#              'sufficiently': 42,
#              'belonging': 39,
#              'merits': 34,
#              'prospects': 19,
#              'common': 302,
#              'mr_frank': 50,
#              'boasts': 2,
#              'lively': 58,
#              'curiosity': 140,
#              'prevailed': 65,
#              'compliment': 48,
#              'achieved': 18,
#              'generally': 113,
#              'proposed': 39,
#              'proper': 170,
#              'dissentient': 1,
#              'voice': 1097,
#              'mrs': 519,
#              'perry': 46,
#              'drank': 39,
#              'miss_bates': 113,
#              'strengthened': 48,
#              'understood': 153,
#              'written': 310,
#              'occasion': 130,
#              'included': 25,
#              'mention': 97,
#              'letter': 331,
#              'heard': 1531,
#              'says': 214,
#              'prized': 3,
#              'course': 421,
#              'formed': 133,
#              'pleasing': 70,
#              'irresistible': 23,
#              'sense': 309,
#              'addition': 35,
#              'source': 30,
#              'expression': 84,
#              'congratulation': 4,
#              'fortunate': 40,
#              'regret': 67,
#              'partial': 25,
#              'separation': 47,
#              'cooled': 9,
#              'ill': 307,
#              'times': 402,
#              'missed': 33,
#              'losing': 23,
#              'ennui': 5,
#              'companionableness': 2,
#              'feeble': 39,
#              'girls': 90,
#              'energy': 40,
#              'difficulties': 57,
#              'privations': 6,
#              'convenient': 38,
#              'solitary': 65,
#              'female': 76,
#              'circumstances': 131,
#              'approaching': 43,
#              'season': 120,
#              'hindrance': 4,
#              'spending': 21,
#              'evenings': 17,
#              'week': 159,
#              'altogether': 140,
#              'hours': 219,
#              'moments': 93,
#              'enjoyment': 65,
#              'apparent': 37,
#              'taken': 570,
#              'surprize': 38,
#              'centre': 63,
#              'attended': 54,
#              'giving': 218,
#              ...})

# %% [markdown]
# #### Gensim Word2Vec Implementation

# %%
import multiprocessing
import gensim
from gensim.models import Word2Vec

# %%
cores = multiprocessing.cpu_count() # Count the number of cores in a computer
cores
# Out:
# 8

# %%
# The parameters:
# min_count = int - Ignores all words with total absolute frequency lower than this - (2, 100)
# window = int - The maximum distance between the current and predicted word within a sentence. E.g. window words on the left and window words on the left of our target - (2, 10)
# size = int - Dimensionality of the feature vectors. - (50, 300)
# sample = float - The threshold for configuring which higher-frequency words are randomly downsampled. Highly influencial. - (0, 1e-5)
# alpha = float - The initial learning rate - (0.01, 0.05)
# min_alpha = float - Learning rate will linearly drop to min_alpha as training progresses. To set it: alpha - (min_alpha * epochs) ~ 0.00
# negative = int - If > 0, negative sampling will be used, the int for negative specifies how many "noise words" should be drown. If set to 0, no negative sampling is used. - (5, 20)
# workers = int - Use these many worker threads to train the model (=faster training with multicore machines)



w2v_model = Word2Vec(min_count=20,
                     window=2,
                     size=300,
                     sample=6e-5, 
                     alpha=0.03, 
                     min_alpha=0.0007, 
                     negative=20,
                     workers=cores-1)

# %% [markdown]
# #### Building the Vocabulary Table

# %%
t = time()

w2v_model.build_vocab(sentences, progress_per=10000)

print('Time to build vocab: {} mins'.format(round((time() - t) / 60, 2)))
# Out:
# Time to build vocab: 0.05 mins

# %%
len(w2v_model.wv.vocab)
# Out:
# 6421

# %%
from itertools import islice
list(islice(w2v_model.wv.vocab, 3000, 3020))
# Out:
# ['guilt',
#  'dwelling',
#  'en',
#  'hated',
#  'abundant',
#  'despise',
#  'questioned',
#  'boast',
#  'across',
#  'distinguish',
#  'soul',
#  'thoughtful',
#  'humanity',
#  'consent',
#  'amazed',
#  'mad',
#  'sheep',
#  'louder',
#  'drown',
#  'sign']

# %% [markdown]
# #### Training of the model
#
# > 10.000 words , each word is a array of 300

# %% [markdown]
# <img src="word2vec1.jpg" alt="drawing" width="700"/>

# %% [markdown]
# <img src="word2vec_weight_matrix_lookup_table.png" alt="drawing" width="400"/>

# %%
# text = "I love you so much".  
# {(i,you),love},{(love,so),you},{(you,much),so}


t = time()
# sg ({0, 1}, optional) – Training algorithm: 1 for skip-gram; otherwise CBOW.
w2v_model.train(sentences, total_examples=w2v_model.corpus_count, epochs=30, report_delay=1)

print('Time to train the model: {} mins'.format(round((time() - t) / 60, 2)))
# Out:
# Time to train the model: 2.01 mins

# %%
# save model
w2v_model.save("word2vec.model")
# model = Word2Vec.load("word2vec.model")

# %%
# Precompute L2-normalized vectors.
w2v_model.init_sims(replace=True)

# %%
# The two datasets must be the same size
max_dataset_size = len(w2v_model.wv.syn0norm )
max_dataset_size
# Out:
# c:\python\python37\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: Call to deprecated `syn0norm` (Attribute will be removed in 4.0.0, use self.vectors_norm instead).
# 6421

# %%
a= w2v_model.wv.__getitem__(['blessings'])

# %%
len(a[0])
# Out:
# 300

# %%
# b= w2v_model.wv.__getitem__(['woodhouse'])
# KeyError: "word 'woodhouse' not in vocabulary"

# %% [markdown]
# ### Wierd ??? woodhouse is list of words "sentences"  but not in the vocabulary why it shows KeyError: "word 'woodhouse' not in vocabulary"   -> because min_count is 20

# %% [markdown]
# #### Exploring the model word2vec
# #### Most similar to:

# %%
# w2v_model.wv.most_similar(positive=['woman', 'king'], negative=['man'])
w2v_model.wv.most_similar(positive=['blessings'])
# Out:
# [('abundant', 0.6536396741867065),
#  ('abound', 0.6505493521690369),
#  ('perfection', 0.640018105506897),
#  ('bliss', 0.6337653398513794),
#  ('justly', 0.6226894855499268),
#  ('fellowship', 0.612240731716156),
#  ('ruined', 0.6122108697891235),
#  ('evermore', 0.6118630170822144),
#  ('begotten', 0.6008416414260864),
#  ('excellence', 0.5990576148033142)]

# %%
#  our model to give us the word that does not belong to the list!
w2v_model.wv.doesnt_match(['happy', 'woman', 'social'])
# Out:
# c:\python\python37\lib\site-packages\gensim\models\keyedvectors.py:877: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   vectors = vstack(self.word_vec(word, use_norm=True) for word in used_words).astype(REAL)
# 'woman'

# %% [markdown]
# #### t-SNE visualizations

# %%
# Our goal in this section is to plot our 300 dimensions vectors into 2 dimensional graphs, and see if we can spot interesting patterns.
# For that we are going to use t-SNE implementation from scikit-learn.

def tsnescatterplot(model, word, list_names):
    """ Plot in seaborn the results from the t-SNE dimensionality reduction algorithm of the vectors of a query word,
    its list of most similar words, and a list of words.
    """
    arrays = np.empty((0, 300), dtype='f')
    word_labels = [word]
    color_list  = ['red']

    # adds the vector of the query word
    arrays = np.append(arrays, model.wv.__getitem__([word]), axis=0)
    
    # gets list of most similar words
    close_words = model.wv.most_similar([word])
    
    # adds the vector for each of the closest words to the array
    for wrd_score in close_words:
        wrd_vector = model.wv.__getitem__([wrd_score[0]])
        word_labels.append(wrd_score[0])
        color_list.append('blue')
        arrays = np.append(arrays, wrd_vector, axis=0)
    
    # adds the vector for each of the words from list_names to the array
    for wrd in list_names:
        wrd_vector = model.wv.__getitem__([wrd])
        word_labels.append(wrd)
        color_list.append('green')
        arrays = np.append(arrays, wrd_vector, axis=0)
        
    # Reduces the dimensionality from 300 to 50 dimensions with PCA
    reduc = PCA(n_components=19).fit_transform(arrays)
    
    # Finds t-SNE coordinates for 2 dimensions
    np.set_printoptions(suppress=True)
    
    Y = TSNE(n_components=2, random_state=0, perplexity=15).fit_transform(reduc)
    
    # Sets everything up to plot
    df = pd.DataFrame({'x': [x for x in Y[:, 0]],
                       'y': [y for y in Y[:, 1]],
                       'words': word_labels,
                       'color': color_list})
    
    fig, _ = plt.subplots()
    fig.set_size_inches(9, 9)
    
    # Basic plot
    p1 = sns.regplot(data=df,
                     x="x",
                     y="y",
                     fit_reg=False,
                     marker="o",
                     scatter_kws={'s': 40,
                                  'facecolors': df['color']
                                 }
                    )
    
    # Adds annotations one by one with a loop
    for line in range(0, df.shape[0]):
         p1.text(df["x"][line],
                 df['y'][line],
                 '  ' + df["words"][line].title(),
                 horizontalalignment='left',
                 verticalalignment='bottom', size='medium',
                 color=df['color'][line],
                 weight='normal'
                ).set_size(15)

    
    plt.xlim(Y[:, 0].min()-50, Y[:, 0].max()+50)
    plt.ylim(Y[:, 1].min()-50, Y[:, 1].max()+50)
            
    plt.title('t-SNE visualization for {}'.format(word.title()))

# %%
tsnescatterplot(w2v_model, 'friend', ['handsome', 'home', 'happy', 'rich', 'age', 'man', 'lost', 'poor'])

# %%
# BOW based approaches that includes averaging, summation, weighted addition. 
# The common way is to average the two word vectors. Therefore, we will follow the most common way.

def word_averaging(wv, words):
    all_words, mean = set(), []
    
    for word in words:
        if isinstance(word, np.ndarray):
            mean.append(word)
        elif word in wv.vocab:
            mean.append(wv.syn0norm[wv.vocab[word].index])
            all_words.add(wv.vocab[word].index)

    if not mean:
        logging.warning("cannot compute similarity with no input %s", words)
        # FIXME: remove these examples in pre-processing
        return np.zeros(wv.vector_size,)

    mean = gensim.matutils.unitvec(np.array(mean).mean(axis=0)).astype(np.float32)
    return mean

def  word_averaging_list(wv, text_list):
    return np.vstack([word_averaging(wv, post) for post in text_list ])

# %%
#  Split senctences into array
def w2v_tokenize_text(text):
    tokens = []
    for sent in nltk.sent_tokenize(text, language='english'):
        for word in nltk.word_tokenize(sent, language='english'):
            if len(word) < 2:
                continue
            tokens.append(word)
    return tokens

# %%
# train, test = train_test_split(df_clean, test_size=0.3, random_state = 42)

# test_tokenized = test.apply(lambda r: w2v_tokenize_text(r['clean']), axis=1).values
# train_tokenized = train.apply(lambda r: w2v_tokenize_text(r['clean']), axis=1).values

# X_train_word_average = word_averaging_list(wv,train_tokenized)
# X_test_word_average = word_averaging_list(wv,test_tokenized)

# %%
X_train_w2v, X_test_w2v, y_train_w2v, y_test_w2v = train_test_split(sentences, df_clean['author_id'],test_size=0.25,random_state=123)

# %%
X_train_w2v[4]
# Out:
# ['lord', 'high', 'nations', 'glory', 'heavens']

# %%
X_train_w2v_average = word_averaging_list(w2v_model.wv,X_train_w2v)
X_test_w2v_average = word_averaging_list(w2v_model.wv,X_test_w2v)
# Out:
# WARNING:root:cannot compute similarity with no input ['rubbish', 'offall']
# c:\python\python37\lib\site-packages\ipykernel_launcher.py:11: DeprecationWarning: Call to deprecated `syn0norm` (Attribute will be removed in 4.0.0, use self.vectors_norm instead).
#   # This is added back by InteractiveShellApp.init_path()
# WARNING:root:cannot compute similarity with no input ['astonish']
# WARNING:root:cannot compute similarity with no input ['prejudiced']
# WARNING:root:cannot compute similarity with no input ['tastes', 'chocolate']
# WARNING:root:cannot compute similarity with no input ['aleak']
# WARNING:root:cannot compute similarity with no input ['lucian']
# WARNING:root:cannot compute similarity with no input ['cinna']
# WARNING:root:cannot compute similarity with no input ['virginian']
# WARNING:root:cannot compute similarity with no input ['magnet']
# WARNING:root:cannot compute similarity with no input ['norman']
# WARNING:root:cannot compute similarity with no input ['honiton']
# WARNING:root:cannot compute similarity with no input ['chambermaid']
# WARNING:root:cannot compute similarity with no input ['perfections']
# WARNING:root:cannot compute similarity with no input ['soothe']
# WARNING:root:cannot compute similarity with no input ['actus', 'secundus']
# WARNING:root:cannot compute similarity with no input ['faintly']
# WARNING:root:cannot compute similarity with no input ['shindy', 'kicking']
# WARNING:root:cannot compute similarity with no input ['tut']
# WARNING:root:cannot compute similarity with no input ['defrauded']
# WARNING:root:cannot compute similarity with no input ['insulted']
# WARNING:root:cannot compute similarity with no input ['bulwark']
# WARNING:root:cannot compute similarity with no input ['quiddits']
# WARNING:root:cannot compute similarity with no input ['physique']
# WARNING:root:cannot compute similarity with no input ['brandy']
# WARNING:root:cannot compute similarity with no input ['caw', 'caw', 'caw']
# WARNING:root:cannot compute similarity with no input ['presto']
# WARNING:root:cannot compute similarity with no input ['oct', 'stirre', 'vntill', 'signall']
# WARNING:root:cannot compute similarity with no input ['descartian', 'vortices', 'hover']
# WARNING:root:cannot compute similarity with no input ['deceiued']
# WARNING:root:cannot compute similarity with no input ['um']
# WARNING:root:cannot compute similarity with no input ['jubilate']
# WARNING:root:cannot compute similarity with no input ['misinformed']
# WARNING:root:cannot compute similarity with no input ['len']
# WARNING:root:cannot compute similarity with no input ['tumble']
# WARNING:root:cannot compute similarity with no input ['poisoned']
# WARNING:root:cannot compute similarity with no input ['phil']
# WARNING:root:cannot compute similarity with no input ['afflatus', 'surging', 'surging', 'current', 'index']
# WARNING:root:cannot compute similarity with no input ['metempsychosis']
# WARNING:root:cannot compute similarity with no input ['trigonometry']
# WARNING:root:cannot compute similarity with no input ['loveliness']
# WARNING:root:cannot compute similarity with no input ['schoolboy']
# WARNING:root:cannot compute similarity with no input ['broadway', 'pageant']
# WARNING:root:cannot compute similarity with no input ['breefely']
# WARNING:root:cannot compute similarity with no input ['scena', 'sexta']
# WARNING:root:cannot compute similarity with no input ['calno', 'carchemish']
# WARNING:root:cannot compute similarity with no input ['ting']
# WARNING:root:cannot compute similarity with no input ['asse']
# WARNING:root:cannot compute similarity with no input ['macd']
# WARNING:root:cannot compute similarity with no input ['trecherie']
# WARNING:root:cannot compute similarity with no input ['exeunt', 'omnes']
# WARNING:root:cannot compute similarity with no input ['loued']
# WARNING:root:cannot compute similarity with no input ['metel']
# WARNING:root:cannot compute similarity with no input ['sphynx']
# WARNING:root:cannot compute similarity with no input ['titin']
# WARNING:root:cannot compute similarity with no input ['uniforms']
# WARNING:root:cannot compute similarity with no input ['xii']
# WARNING:root:cannot compute similarity with no input ['stinglesse']
# WARNING:root:cannot compute similarity with no input ['diversion']
# WARNING:root:cannot compute similarity with no input ['mermaid']
# WARNING:root:cannot compute similarity with no input ['um', 'um', 'um']
# WARNING:root:cannot compute similarity with no input ['clit']
# WARNING:root:cannot compute similarity with no input ['bapt']
# WARNING:root:cannot compute similarity with no input ['oppidan']
# WARNING:root:cannot compute similarity with no input ['burs']
# WARNING:root:cannot compute similarity with no input ['roofs']
# WARNING:root:cannot compute similarity with no input ['scena', 'prima']
# WARNING:root:cannot compute similarity with no input ['dirtiest', 'dishonest']
# WARNING:root:cannot compute similarity with no input ['miserably', 'behindhand']
# WARNING:root:cannot compute similarity with no input ['disposal']
# WARNING:root:cannot compute similarity with no input ['lobe']
# WARNING:root:cannot compute similarity with no input ['ancestor']
# WARNING:root:cannot compute similarity with no input ['longings', 'irrepressible']
# WARNING:root:cannot compute similarity with no input ['chartres']
# WARNING:root:cannot compute similarity with no input ['neighbor', 'danube']
# WARNING:root:cannot compute similarity with no input ['cluck']
# WARNING:root:cannot compute similarity with no input ['instigator']
# WARNING:root:cannot compute similarity with no input ['hymen']
# WARNING:root:cannot compute similarity with no input ['cruell']
# WARNING:root:cannot compute similarity with no input ['halloa']
# WARNING:root:cannot compute similarity with no input ['selah']
# WARNING:root:cannot compute similarity with no input ['mexican', 'breez']
# WARNING:root:cannot compute similarity with no input ['sey']
# WARNING:root:cannot compute similarity with no input ['mal']
# WARNING:root:cannot compute similarity with no input ['fanciful']
# WARNING:root:cannot compute similarity with no input ['dane']
# WARNING:root:cannot compute similarity with no input ['atheists']
# WARNING:root:cannot compute similarity with no input ['pennant']
# WARNING:root:cannot compute similarity with no input ['twinkling']
# WARNING:root:cannot compute similarity with no input ['graces']
# WARNING:root:cannot compute similarity with no input ['resina']
# WARNING:root:cannot compute similarity with no input ['enterprize', 'popillius']
# WARNING:root:cannot compute similarity with no input ['conquerors']
# WARNING:root:cannot compute similarity with no input ['pat']
# WARNING:root:cannot compute similarity with no input ['holland', 'pliny']
# WARNING:root:cannot compute similarity with no input ['champions', 'papists']
# WARNING:root:cannot compute similarity with no input ['formules']
# WARNING:root:cannot compute similarity with no input ['seyw']
# WARNING:root:cannot compute similarity with no input ['speck']
# WARNING:root:cannot compute similarity with no input ['rig']
# WARNING:root:cannot compute similarity with no input ['bountiful']
# WARNING:root:cannot compute similarity with no input ['hussey']
# WARNING:root:cannot compute similarity with no input ['accouchez']
# WARNING:root:cannot compute similarity with no input ['octavo']
# WARNING:root:cannot compute similarity with no input ['kosmos']
# WARNING:root:cannot compute similarity with no input ['condemneth']
# WARNING:root:cannot compute similarity with no input ['marcell']
# WARNING:root:cannot compute similarity with no input ['infirmity']
# WARNING:root:cannot compute similarity with no input ['partners']
# WARNING:root:cannot compute similarity with no input ['talb']
# WARNING:root:cannot compute similarity with no input ['reckless', 'despairing', 'carols']
# WARNING:root:cannot compute similarity with no input ['stunsails']
# WARNING:root:cannot compute similarity with no input ['ambergris']
# WARNING:root:cannot compute similarity with no input ['polonius']
# WARNING:root:cannot compute similarity with no input ['wheelbarrow']
# WARNING:root:cannot compute similarity with no input ['parent', 'assistant', 'maria', 'edgeworth']
# WARNING:root:cannot compute similarity with no input ['hullo']
# WARNING:root:cannot compute similarity with no input ['chef', 'oeuvres', 'engineering', 'forts', 'armaments']
# WARNING:root:cannot compute similarity with no input ['lobsters']
# WARNING:root:cannot compute similarity with no input ['stupidity']
# WARNING:root:cannot compute similarity with no input ['oblivion']
# WARNING:root:cannot compute similarity with no input ['u', 'ex']
# WARNING:root:cannot compute similarity with no input ['unconsciously', 'chirography', 'expands', 'placard', 'capitals']
# WARNING:root:cannot compute similarity with no input ['contradict']
# WARNING:root:cannot compute similarity with no input ['flatterers']
# WARNING:root:cannot compute similarity with no input ['undrape']
# WARNING:root:cannot compute similarity with no input ['packthread', 'cracked']
# WARNING:root:cannot compute similarity with no input ['assassin']
# WARNING:root:cannot compute similarity with no input ['crosse', 'exigent']
# WARNING:root:cannot compute similarity with no input ['poisoned']
# WARNING:root:cannot compute similarity with no input ['rabelais']
# WARNING:root:cannot compute similarity with no input ['neptune']
# WARNING:root:cannot compute similarity with no input ['cassi']
# WARNING:root:cannot compute similarity with no input ['problem']
# WARNING:root:cannot compute similarity with no input ['heroic', 'martyrdoms']
# WARNING:root:cannot compute similarity with no input ['schoolmasters', 'tyrants']
# WARNING:root:cannot compute similarity with no input ['cheever']
# WARNING:root:cannot compute similarity with no input ['hurts']
# WARNING:root:cannot compute similarity with no input ['musket']
# WARNING:root:cannot compute similarity with no input ['pinch']
# WARNING:root:cannot compute similarity with no input ['appendix']
# WARNING:root:cannot compute similarity with no input ['kneel']
# WARNING:root:cannot compute similarity with no input ['interrupting']
# WARNING:root:cannot compute similarity with no input ['omnes']
# WARNING:root:cannot compute similarity with no input ['santa', 'maria']
# WARNING:root:cannot compute similarity with no input ['tartar', 'tartary']
# WARNING:root:cannot compute similarity with no input ['americanos']
# WARNING:root:cannot compute similarity with no input ['blake']
# WARNING:root:cannot compute similarity with no input ['sogger']
# WARNING:root:cannot compute similarity with no input ['newest', 'griefe']
# WARNING:root:cannot compute similarity with no input ['pun']
# WARNING:root:cannot compute similarity with no input ['odious', 'stigma', 'originate']
# WARNING:root:cannot compute similarity with no input ['caius', 'ligarius']
# WARNING:root:cannot compute similarity with no input ['higgaion']
# WARNING:root:cannot compute similarity with no input ['webster', 'dictionary']
# WARNING:root:cannot compute similarity with no input ['themes', 'equalities']
# WARNING:root:cannot compute similarity with no input ['dame', 'dames']
# WARNING:root:cannot compute similarity with no input ['strathspey']
# WARNING:root:cannot compute similarity with no input ['exists']
# WARNING:root:cannot compute similarity with no input ['mac']
# WARNING:root:cannot compute similarity with no input ['befooled', 'befooled']
# WARNING:root:cannot compute similarity with no input ['clam', 'cod']
# WARNING:root:cannot compute similarity with no input ['viii']
# WARNING:root:cannot compute similarity with no input ['ego', 'non', 'baptizo', 'te', 'nomine', 'patris', 'sed', 'nomine', 'diaboli']
# WARNING:root:cannot compute similarity with no input ['xiii']
# WARNING:root:cannot compute similarity with no input ['mockery']
# WARNING:root:cannot compute similarity with no input ['palmer']
# WARNING:root:cannot compute similarity with no input ['anvil']
# WARNING:root:cannot compute similarity with no input ['bru']
# WARNING:root:cannot compute similarity with no input ['lobster', 'quadrille']
# WARNING:root:cannot compute similarity with no input ['compost']
# WARNING:root:cannot compute similarity with no input ['phil']
# WARNING:root:cannot compute similarity with no input ['stra']
# WARNING:root:cannot compute similarity with no input ['benighted', 'roamer', 'amazonia']
# WARNING:root:cannot compute similarity with no input ['mediums']
# WARNING:root:cannot compute similarity with no input ['osceola']
# WARNING:root:cannot compute similarity with no input ['rubbish']
# WARNING:root:cannot compute similarity with no input ['telephone']
# WARNING:root:cannot compute similarity with no input ['ginger', 'jub']
# WARNING:root:cannot compute similarity with no input ['phoo']
# WARNING:root:cannot compute similarity with no input ['dalliance', 'eagles']
# WARNING:root:cannot compute similarity with no input ['lombard']
# WARNING:root:cannot compute similarity with no input ['philippi']
# WARNING:root:cannot compute similarity with no input ['cull', 'holyday']
# WARNING:root:cannot compute similarity with no input ['formal', 'salutation', 'exchanged']
# WARNING:root:cannot compute similarity with no input ['whiff']
# WARNING:root:cannot compute similarity with no input ['xii']
# WARNING:root:cannot compute similarity with no input ['seruant']
# WARNING:root:cannot compute similarity with no input ['etymology']
# WARNING:root:cannot compute similarity with no input ['soales', 'shoo']
# WARNING:root:cannot compute similarity with no input ['debts']
# WARNING:root:cannot compute similarity with no input ['dodge']
# WARNING:root:cannot compute similarity with no input ['lookt', 'frowningly']
# WARNING:root:cannot compute similarity with no input ['calp']
# WARNING:root:cannot compute similarity with no input ['quizzed', 'quizzed']
# WARNING:root:cannot compute similarity with no input ['vol']
# WARNING:root:cannot compute similarity with no input ['swerve']
# WARNING:root:cannot compute similarity with no input ['chicha']
# WARNING:root:cannot compute similarity with no input ['ple']
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input ['cicero']
# WARNING:root:cannot compute similarity with no input ['huh']
# WARNING:root:cannot compute similarity with no input ['pitchpoling']
# WARNING:root:cannot compute similarity with no input ['hecuba']
# WARNING:root:cannot compute similarity with no input ['whistled']
# WARNING:root:cannot compute similarity with no input ['gilder']
# WARNING:root:cannot compute similarity with no input ['ix']
# WARNING:root:cannot compute similarity with no input ['joe']
# WARNING:root:cannot compute similarity with no input ['clapper']
# WARNING:root:cannot compute similarity with no input ['writes']
# WARNING:root:cannot compute similarity with no input ['droll']
# WARNING:root:cannot compute similarity with no input ['custome']
# WARNING:root:cannot compute similarity with no input ['actus', 'primus']
# WARNING:root:cannot compute similarity with no input ['var']
# WARNING:root:cannot compute similarity with no input ['needing', 'chicken']
# WARNING:root:cannot compute similarity with no input ['marshal']
# WARNING:root:cannot compute similarity with no input ['iv']
# WARNING:root:cannot compute similarity with no input ['antonio']
# WARNING:root:cannot compute similarity with no input ['pallid', 'wreath']
# WARNING:root:cannot compute similarity with no input ['disguises', 'disguise', 'reveal']
# WARNING:root:cannot compute similarity with no input ['inquisition', 'spain']
# WARNING:root:cannot compute similarity with no input ['excluded']
# WARNING:root:cannot compute similarity with no input ['breake']
# WARNING:root:cannot compute similarity with no input ['smallridge']
# WARNING:root:cannot compute similarity with no input ['dardanius']
# WARNING:root:cannot compute similarity with no input ['observant']
# WARNING:root:cannot compute similarity with no input ['goldsmith', 'johnson']
# WARNING:root:cannot compute similarity with no input ['heyday']
# WARNING:root:cannot compute similarity with no input ['irritated']
# WARNING:root:cannot compute similarity with no input ['pall', 'mall']
# WARNING:root:cannot compute similarity with no input ['volum']
# WARNING:root:cannot compute similarity with no input ['epaulets']
# WARNING:root:cannot compute similarity with no input ['io']
# WARNING:root:cannot compute similarity with no input ['octa']
# WARNING:root:cannot compute similarity with no input ['sneezed']
# WARNING:root:cannot compute similarity with no input ['unwell']
# WARNING:root:cannot compute similarity with no input ['breakes', 'pate', 'crosse']
# WARNING:root:cannot compute similarity with no input ['inconsistent']
# WARNING:root:cannot compute similarity with no input ['hayle']
# WARNING:root:cannot compute similarity with no input ['powres', 'poyson', 'eares']
# WARNING:root:cannot compute similarity with no input ['hollo']
# WARNING:root:cannot compute similarity with no input ['worry']
# WARNING:root:cannot compute similarity with no input ['drinkes']
# WARNING:root:cannot compute similarity with no input ['bout']
# WARNING:root:cannot compute similarity with no input ['v']
# WARNING:root:cannot compute similarity with no input ['thel', 'motto']
# WARNING:root:cannot compute similarity with no input ['beau', 'ty']
# WARNING:root:cannot compute similarity with no input ['durand']
# WARNING:root:cannot compute similarity with no input ['brahma']
# WARNING:root:cannot compute similarity with no input ['huh']
# WARNING:root:cannot compute similarity with no input ['flauius']
# WARNING:root:cannot compute similarity with no input ['drugger', 'davis']
# WARNING:root:cannot compute similarity with no input ['vii']
# WARNING:root:cannot compute similarity with no input ['loomings']
# WARNING:root:cannot compute similarity with no input ['begone']
# WARNING:root:cannot compute similarity with no input ['gertrude']
# WARNING:root:cannot compute similarity with no input ['recorder']
# WARNING:root:cannot compute similarity with no input ['bribe']
# WARNING:root:cannot compute similarity with no input ['cinna', 'conspirator']
# WARNING:root:cannot compute similarity with no input ['osr']
# WARNING:root:cannot compute similarity with no input ['scrubs']
# WARNING:root:cannot compute similarity with no input ['clo']
# WARNING:root:cannot compute similarity with no input ['pub']
# WARNING:root:cannot compute similarity with no input ['hah']
# WARNING:root:cannot compute similarity with no input ['apparitions']
# WARNING:root:cannot compute similarity with no input ['bavarian']
# WARNING:root:cannot compute similarity with no input ['declares']
# WARNING:root:cannot compute similarity with no input ['xxi']
# WARNING:root:cannot compute similarity with no input ['internationally', 'universally', 'applicable']
# WARNING:root:cannot compute similarity with no input ['extasie']
# WARNING:root:cannot compute similarity with no input ['undone', 'parcels']
# WARNING:root:cannot compute similarity with no input ['apoplexy']
# WARNING:root:cannot compute similarity with no input ['gout', 'decrepitude']
# WARNING:root:cannot compute similarity with no input ['waggish', 'leering', 'lurks', 'horribles']
# WARNING:root:cannot compute similarity with no input ['bap']
# WARNING:root:cannot compute similarity with no input ['abuse']
# WARNING:root:cannot compute similarity with no input ['gathereth', 'scattereth']
# WARNING:root:cannot compute similarity with no input ['adios', 'senor']
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input ['nightgown']
# WARNING:root:cannot compute similarity with no input ['huzza']
# WARNING:root:cannot compute similarity with no input ['natures', 'coppie', 'eterne']
# WARNING:root:cannot compute similarity with no input ['hammering']
# WARNING:root:cannot compute similarity with no input ['boundless', 'aggregate']
# WARNING:root:cannot compute similarity with no input ['torches']
# WARNING:root:cannot compute similarity with no input ['thankes', 'paines']
# WARNING:root:cannot compute similarity with no input ['portuguese']
# WARNING:root:cannot compute similarity with no input ['pugh']
# WARNING:root:cannot compute similarity with no input ['carols']
# WARNING:root:cannot compute similarity with no input ['elton']
# WARNING:root:cannot compute similarity with no input ['hish']
# WARNING:root:cannot compute similarity with no input ['underfed', 'underexercised', 'asphyxiated']
# WARNING:root:cannot compute similarity with no input ['calphurnia', 'dreame', 'signified']
# WARNING:root:cannot compute similarity with no input ['xix']
# WARNING:root:cannot compute similarity with no input ['explains']
# WARNING:root:cannot compute similarity with no input ['hottentot', 'clicking', 'palate']
# WARNING:root:cannot compute similarity with no input ['oneself']
# WARNING:root:cannot compute similarity with no input ['lenox']
# WARNING:root:cannot compute similarity with no input ['errant']
# WARNING:root:cannot compute similarity with no input ['philosophical', 'transactions', 'vol']
# WARNING:root:cannot compute similarity with no input ['shabbiness']
# WARNING:root:cannot compute similarity with no input ['pooh']
# WARNING:root:cannot compute similarity with no input ['ix']
# WARNING:root:cannot compute similarity with no input ['escorted']
# WARNING:root:cannot compute similarity with no input ['goney']
# WARNING:root:cannot compute similarity with no input ['trans']
# WARNING:root:cannot compute similarity with no input ['cur', 'ous']
# WARNING:root:cannot compute similarity with no input ['sirius']
# WARNING:root:cannot compute similarity with no input ['spotted', 'hawk', 'swoops', 'accuses', 'complains', 'gab', 'loitering']
# WARNING:root:cannot compute similarity with no input ['holla', 'barnardo']
# WARNING:root:cannot compute similarity with no input ['knocke']
# WARNING:root:cannot compute similarity with no input ['tutte', 'le', 'volpi', 'si', 'trovano', 'pellicera']
# WARNING:root:cannot compute similarity with no input ['victoria']
# WARNING:root:cannot compute similarity with no input ['tests']
# WARNING:root:cannot compute similarity with no input ['revolution']
# WARNING:root:cannot compute similarity with no input ['gent']
# WARNING:root:cannot compute similarity with no input ['thel']
# WARNING:root:cannot compute similarity with no input ['banq']
# WARNING:root:cannot compute similarity with no input ['omen']
# WARNING:root:cannot compute similarity with no input ['extracts']
# WARNING:root:cannot compute similarity with no input ['advocate']
# WARNING:root:cannot compute similarity with no input ['cass']
# WARNING:root:cannot compute similarity with no input ['xix']
# WARNING:root:cannot compute similarity with no input ['bookxxxv']
# WARNING:root:cannot compute similarity with no input ['rallied']
# WARNING:root:cannot compute similarity with no input ['spine']
# WARNING:root:cannot compute similarity with no input ['boaster']
# WARNING:root:cannot compute similarity with no input ['leade']
# WARNING:root:cannot compute similarity with no input ['ant']
# WARNING:root:cannot compute similarity with no input ['ahoy']
# WARNING:root:cannot compute similarity with no input ['fairies']
# WARNING:root:cannot compute similarity with no input ['macb']
# WARNING:root:cannot compute similarity with no input ['tipped']
# WARNING:root:cannot compute similarity with no input ['hoboyes']
# WARNING:root:cannot compute similarity with no input ['ger']
# WARNING:root:cannot compute similarity with no input ['xv']
# WARNING:root:cannot compute similarity with no input ['plebeians']
# WARNING:root:cannot compute similarity with no input ['irons']
# WARNING:root:cannot compute similarity with no input ['alarums']
# WARNING:root:cannot compute similarity with no input ['deceiver', 'antichrist']
# WARNING:root:cannot compute similarity with no input ['reynol']
# WARNING:root:cannot compute similarity with no input ['panel']
# WARNING:root:cannot compute similarity with no input ['cai']
# WARNING:root:cannot compute similarity with no input ['growled', 'whined', 'squealed']
# WARNING:root:cannot compute similarity with no input ['oho']
# WARNING:root:cannot compute similarity with no input ['kickshaws']
# WARNING:root:cannot compute similarity with no input ['cannibals']
# WARNING:root:cannot compute similarity with no input ['ban']
# WARNING:root:cannot compute similarity with no input ['undoes', 'stratagems', 'envelopes']
# WARNING:root:cannot compute similarity with no input ['edwin', 'morcar', 'earls', 'mercia', 'northumbria']
# WARNING:root:cannot compute similarity with no input ['zay', 'nod', 'ide']
# WARNING:root:cannot compute similarity with no input ['wailed']
# WARNING:root:cannot compute similarity with no input ['guildensterne']
# WARNING:root:cannot compute similarity with no input ['xviii']
# WARNING:root:cannot compute similarity with no input ['funeral']
# WARNING:root:cannot compute similarity with no input ['capting']
# WARNING:root:cannot compute similarity with no input ['hec']
# WARNING:root:cannot compute similarity with no input ['presse', 'calles']
# WARNING:root:cannot compute similarity with no input ['certaine']
# WARNING:root:cannot compute similarity with no input ['calles', 'villaine']
# WARNING:root:cannot compute similarity with no input ['monotonous', 'maddening']
# WARNING:root:cannot compute similarity with no input ['quarried']
# WARNING:root:cannot compute similarity with no input ['patties']
# WARNING:root:cannot compute similarity with no input ['transpositions']
# WARNING:root:cannot compute similarity with no input ['impropriety']
# WARNING:root:cannot compute similarity with no input ['shouts']
# WARNING:root:cannot compute similarity with no input ['showt']
# WARNING:root:cannot compute similarity with no input ['sermon']
# WARNING:root:cannot compute similarity with no input ['grandees']
# WARNING:root:cannot compute similarity with no input ['historian']
# WARNING:root:cannot compute similarity with no input ['cyn']
# WARNING:root:cannot compute similarity with no input ['unbar', 'shutters']
# WARNING:root:cannot compute similarity with no input ['al']
# WARNING:root:cannot compute similarity with no input ['ginger']
# WARNING:root:cannot compute similarity with no input ['defer']
# WARNING:root:cannot compute similarity with no input ['gipsies']
# WARNING:root:cannot compute similarity with no input ['cetology']
# WARNING:root:cannot compute similarity with no input ['cradle', 'endlessly', 'rocking']
# WARNING:root:cannot compute similarity with no input ['hatchway']
# WARNING:root:cannot compute similarity with no input ['lirra', 'skirra']
# WARNING:root:cannot compute similarity with no input ['mcculloch', 'commercial', 'dictionary']
# WARNING:root:cannot compute similarity with no input ['xvi']
# WARNING:root:cannot compute similarity with no input ['lowd', 'alarum']
# WARNING:root:cannot compute similarity with no input ['ungrateful']
# WARNING:root:cannot compute similarity with no input ['saloon', 'steamer']
# WARNING:root:cannot compute similarity with no input ['coughing']
# WARNING:root:cannot compute similarity with no input ['hun']
# WARNING:root:cannot compute similarity with no input ['v', 'peacemaker']
# WARNING:root:cannot compute similarity with no input ['porter']
# WARNING:root:cannot compute similarity with no input ['switzers']
# WARNING:root:cannot compute similarity with no input ['allons']
# WARNING:root:cannot compute similarity with no input ['fleance']
# WARNING:root:cannot compute similarity with no input ['ezza']
# WARNING:root:cannot compute similarity with no input ['commonplace']
# WARNING:root:cannot compute similarity with no input ['squat', 'stifle']
# WARNING:root:cannot compute similarity with no input ['pupil']
# WARNING:root:cannot compute similarity with no input ['preface', 'gondibert']
# WARNING:root:cannot compute similarity with no input ['reclining']
# WARNING:root:cannot compute similarity with no input ['catholics', 'agnostics']
# WARNING:root:cannot compute similarity with no input ['baron', 'cuvier']
# WARNING:root:cannot compute similarity with no input ['lbs']
# WARNING:root:cannot compute similarity with no input ['neapolitan']
# WARNING:root:cannot compute similarity with no input ['bohemian']
# WARNING:root:cannot compute similarity with no input ['puh']
# WARNING:root:cannot compute similarity with no input ['xxii']
# WARNING:root:cannot compute similarity with no input ['epilogue']
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input ['scena', 'secunda']
# WARNING:root:cannot compute similarity with no input ['accounting', 'tastes']
# WARNING:root:cannot compute similarity with no input ['salut', 'au', 'monde']
# WARNING:root:cannot compute similarity with no input ['hwal', 'swedish']
# WARNING:root:cannot compute similarity with no input ['dryden']
# WARNING:root:cannot compute similarity with no input ['clod', 'pebble']
# WARNING:root:cannot compute similarity with no input ['scoena', 'prima']
# WARNING:root:cannot compute similarity with no input ['madame']
# WARNING:root:cannot compute similarity with no input ['quillets']
# WARNING:root:cannot compute similarity with no input ['psalms']
# WARNING:root:cannot compute similarity with no input ['clitus']
# WARNING:root:cannot compute similarity with no input ['aske']
# WARNING:root:cannot compute similarity with no input ['boston', 'ballad']
# WARNING:root:cannot compute similarity with no input ['jenny']
# WARNING:root:cannot compute similarity with no input ['brut']
# WARNING:root:cannot compute similarity with no input ['friesland', 'pork']
# WARNING:root:cannot compute similarity with no input ['combe', 'magna']
# WARNING:root:cannot compute similarity with no input ['disposal']
# WARNING:root:cannot compute similarity with no input ['hysterical']
# WARNING:root:cannot compute similarity with no input ['nuzzinks']
# WARNING:root:cannot compute similarity with no input ['gr', 'r', 'r', 'r']
# WARNING:root:cannot compute similarity with no input ['enviest']
# WARNING:root:cannot compute similarity with no input ['hi']
# WARNING:root:cannot compute similarity with no input ['tooke', 'lucian']
# WARNING:root:cannot compute similarity with no input ['cowper']
# WARNING:root:cannot compute similarity with no input ['sullenly']
# WARNING:root:cannot compute similarity with no input ['cas']
# WARNING:root:cannot compute similarity with no input ['elves', 'shoemaker']
# WARNING:root:cannot compute similarity with no input ['pescar', 'col', 'hamo', 'argento']
# WARNING:root:cannot compute similarity with no input ['malc']
# WARNING:root:cannot compute similarity with no input ['myth']
# WARNING:root:cannot compute similarity with no input ['postscript']
# WARNING:root:cannot compute similarity with no input ['trow']
# WARNING:root:cannot compute similarity with no input ['doted']
# WARNING:root:cannot compute similarity with no input ['respectability']
# WARNING:root:cannot compute similarity with no input ['rag']
# WARNING:root:cannot compute similarity with no input ['finishes']
# WARNING:root:cannot compute similarity with no input ['malachi']
# WARNING:root:cannot compute similarity with no input ['bulkington']
# WARNING:root:cannot compute similarity with no input ['xv']
# WARNING:root:cannot compute similarity with no input ['exposure']
# WARNING:root:cannot compute similarity with no input ['aha']
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input ['groaned']
# WARNING:root:cannot compute similarity with no input ['ophe']
# WARNING:root:cannot compute similarity with no input ['affectionately']
# WARNING:root:cannot compute similarity with no input ['mockers']
# WARNING:root:cannot compute similarity with no input ['whew']
# WARNING:root:cannot compute similarity with no input ['huzza']
# WARNING:root:cannot compute similarity with no input ['fastidious', 'affectation']
# WARNING:root:cannot compute similarity with no input ['shakspere', 'bacon', 'cipher']
# WARNING:root:cannot compute similarity with no input ['chasticement']
# WARNING:root:cannot compute similarity with no input ['woo', 'weepe']
# WARNING:root:cannot compute similarity with no input ['adopt', 'educate']
# WARNING:root:cannot compute similarity with no input ['fatiguing']
# WARNING:root:cannot compute similarity with no input ['mimic']
# WARNING:root:cannot compute similarity with no input ['affects', 'ungenerous']
# WARNING:root:cannot compute similarity with no input ['yarman']
# WARNING:root:cannot compute similarity with no input ['reversals']
# WARNING:root:cannot compute similarity with no input ['atheism', 'nightmare']
# WARNING:root:cannot compute similarity with no input ['lithe', 'matador', 'arena', 'seville']
# WARNING:root:cannot compute similarity with no input ['servitors']
# WARNING:root:cannot compute similarity with no input ['terzah']
# WARNING:root:cannot compute similarity with no input ['contradict']
# WARNING:root:cannot compute similarity with no input ['fastidious']
# WARNING:root:cannot compute similarity with no input ['xiv']
# WARNING:root:cannot compute similarity with no input ['ophel']
# WARNING:root:cannot compute similarity with no input ['saxon']
# WARNING:root:cannot compute similarity with no input ['habakkuk']
# WARNING:root:cannot compute similarity with no input ['tut', 'tut']
# WARNING:root:cannot compute similarity with no input ['mimic']
# WARNING:root:cannot compute similarity with no input ['beginners']
# WARNING:root:cannot compute similarity with no input ['mess']
# WARNING:root:cannot compute similarity with no input ['ding', 'dong', 'ding']
# WARNING:root:cannot compute similarity with no input ['xx']
# WARNING:root:cannot compute similarity with no input ['architect', 'builder']
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input ['slaine']
# WARNING:root:cannot compute similarity with no input ['ellisons']
# WARNING:root:cannot compute similarity with no input ['donkey']
# WARNING:root:cannot compute similarity with no input ['verie', 'verie', 'paiocke']
# WARNING:root:cannot compute similarity with no input ['hurrah']
# WARNING:root:cannot compute similarity with no input ['cob']
# WARNING:root:cannot compute similarity with no input ['converted']
# WARNING:root:cannot compute similarity with no input ['treacherie', 'seeke']
# WARNING:root:cannot compute similarity with no input ['tit']
# WARNING:root:cannot compute similarity with no input ['sennet']
# WARNING:root:cannot compute similarity with no input ['mar']
# WARNING:root:cannot compute similarity with no input ['pindarus']
# WARNING:root:cannot compute similarity with no input ['kindest', 'regards']
# WARNING:root:cannot compute similarity with no input ['beau', 'ootiful', 'soo', 'oop']
# WARNING:root:cannot compute similarity with no input ['zso']
# WARNING:root:cannot compute similarity with no input ['barrowful']
# WARNING:root:cannot compute similarity with no input ['cant', 'cant']
# WARNING:root:cannot compute similarity with no input ['fra']
# WARNING:root:cannot compute similarity with no input ['ahem']
# WARNING:root:cannot compute similarity with no input ['rosse']
# WARNING:root:cannot compute similarity with no input ['bucket']
# WARNING:root:cannot compute similarity with no input ['gho']
# WARNING:root:cannot compute similarity with no input ['omen', 'dictionary']
# WARNING:root:cannot compute similarity with no input ['hip']
# WARNING:root:cannot compute similarity with no input ['larks', 'cornfield']
# WARNING:root:cannot compute similarity with no input ['hallo']
# WARNING:root:cannot compute similarity with no input ['woo', 'hoo']
# WARNING:root:cannot compute similarity with no input ['ao']
# WARNING:root:cannot compute similarity with no input ['ramadan']
# WARNING:root:cannot compute similarity with no input ['killes', 'polonius']
# WARNING:root:cannot compute similarity with no input ['vii']
# WARNING:root:cannot compute similarity with no input ['haggai']
# WARNING:root:cannot compute similarity with no input ['legacy']
# WARNING:root:cannot compute similarity with no input ['actus', 'quintus']
# WARNING:root:cannot compute similarity with no input ['volt']
# WARNING:root:cannot compute similarity with no input ['confide']
# WARNING:root:cannot compute similarity with no input ['unfeeling']
# WARNING:root:cannot compute similarity with no input ['rosin']
# WARNING:root:cannot compute similarity with no input ['xxiii']
# WARNING:root:cannot compute similarity with no input ['biscuit']
# WARNING:root:cannot compute similarity with no input ['subtilize']
# WARNING:root:cannot compute similarity with no input ['poland', 'czar']
# WARNING:root:cannot compute similarity with no input ['xi']
# WARNING:root:cannot compute similarity with no input ['mes']
# WARNING:root:cannot compute similarity with no input ['yonnondio']
# WARNING:root:cannot compute similarity with no input ['cal']
# WARNING:root:cannot compute similarity with no input ['chapel']
# WARNING:root:cannot compute similarity with no input ['omnes']
# WARNING:root:cannot compute similarity with no input ['x']
# WARNING:root:cannot compute similarity with no input ['motto', 'varies']
# WARNING:root:cannot compute similarity with no input ['idiot']
# WARNING:root:cannot compute similarity with no input ['fatti', 'sono', 'maschii', 'le', 'parole', 'femmine']
# WARNING:root:cannot compute similarity with no input ['wheugh']
# WARNING:root:cannot compute similarity with no input ['wormwood', 'wormwood']
# WARNING:root:cannot compute similarity with no input ['sibbald', 'fife', 'kinross']
# WARNING:root:cannot compute similarity with no input ['fie']
# WARNING:root:cannot compute similarity with no input ['luff']
# WARNING:root:cannot compute similarity with no input ['seyton']
# WARNING:root:cannot compute similarity with no input ['cask']
# WARNING:root:cannot compute similarity with no input ['playhouse', 'barring']
# WARNING:root:cannot compute similarity with no input ['prussian']
# WARNING:root:cannot compute similarity with no input ['nightmare']
# WARNING:root:cannot compute similarity with no input ['cly']
# WARNING:root:cannot compute similarity with no input ['windsor', 'july']
# WARNING:root:cannot compute similarity with no input ['peece']
# WARNING:root:cannot compute similarity with no input ['dy']
# WARNING:root:cannot compute similarity with no input ['lily']
# WARNING:root:cannot compute similarity with no input ['bravo', 'bravo']
# WARNING:root:cannot compute similarity with no input ['wisedom']
# WARNING:root:cannot compute similarity with no input ['puzzling']
# WARNING:root:cannot compute similarity with no input ['splash']
# WARNING:root:cannot compute similarity with no input ['assurances']
# WARNING:root:cannot compute similarity with no input ['sweetener']
# WARNING:root:cannot compute similarity with no input ['hora']
# WARNING:root:cannot compute similarity with no input ['surmises']
# WARNING:root:cannot compute similarity with no input ['abuse']
# WARNING:root:cannot compute similarity with no input ['nahum']
# WARNING:root:cannot compute similarity with no input ['flip']
# WARNING:root:cannot compute similarity with no input ['egge']
# WARNING:root:cannot compute similarity with no input ['bounder']
# WARNING:root:cannot compute similarity with no input ['unlucky']
# WARNING:root:cannot compute similarity with no input ['castaway']
# WARNING:root:cannot compute similarity with no input ['outlines']
# WARNING:root:cannot compute similarity with no input ['marlborough']
# WARNING:root:cannot compute similarity with no input ['nabbed']
# WARNING:root:cannot compute similarity with no input ['scaena', 'quarta']
# WARNING:root:cannot compute similarity with no input ['finis']
# WARNING:root:cannot compute similarity with no input ['composers']
# WARNING:root:cannot compute similarity with no input ['modesty']
# WARNING:root:cannot compute similarity with no input ['hoa']
# WARNING:root:cannot compute similarity with no input ['sag', 'harbor']
# WARNING:root:cannot compute similarity with no input ['date']
# WARNING:root:cannot compute similarity with no input ['octavoes']
# WARNING:root:cannot compute similarity with no input ['popil']
# WARNING:root:cannot compute similarity with no input ['affidavit']
# WARNING:root:cannot compute similarity with no input ['smiting', 'clenched', 'fist']
# WARNING:root:cannot compute similarity with no input ['fastidious']
# WARNING:root:cannot compute similarity with no input ['runner']
# WARNING:root:cannot compute similarity with no input ['eckermann', 'conversations', 'goethe']
# WARNING:root:cannot compute similarity with no input ['ser']
# WARNING:root:cannot compute similarity with no input ['commoners']
# WARNING:root:cannot compute similarity with no input ['pinch']
# WARNING:root:cannot compute similarity with no input ['agh']
# WARNING:root:cannot compute similarity with no input ['scaena', 'tertia']
# WARNING:root:cannot compute similarity with no input ['scar']
# WARNING:root:cannot compute similarity with no input ['morquan']
# WARNING:root:cannot compute similarity with no input ['rat', 'tat']
# WARNING:root:cannot compute similarity with no input ['gulls']
# WARNING:root:cannot compute similarity with no input ['scoresby']
# WARNING:root:cannot compute similarity with no input ['roadside']
# WARNING:root:cannot compute similarity with no input ['oversailed']
# WARNING:root:cannot compute similarity with no input ['torture']
# WARNING:root:cannot compute similarity with no input ['bumper', 'squire', 'jones']
# WARNING:root:cannot compute similarity with no input ['debasement']
# WARNING:root:cannot compute similarity with no input ['dard']
# WARNING:root:cannot compute similarity with no input ['destroyer']
# WARNING:root:cannot compute similarity with no input ['mur']
# WARNING:root:cannot compute similarity with no input ['empties', 'decanter']
# WARNING:root:cannot compute similarity with no input ['pah']
# WARNING:root:cannot compute similarity with no input ['kin']
# WARNING:root:cannot compute similarity with no input ['vttermost', 'faile']
# WARNING:root:cannot compute similarity with no input ['rains']
# WARNING:root:cannot compute similarity with no input ['accuser']
# WARNING:root:cannot compute similarity with no input ['hullo', 'hullo']
# WARNING:root:cannot compute similarity with no input ['thump']
# WARNING:root:cannot compute similarity with no input ['richardson', 'dictionary']
# WARNING:root:cannot compute similarity with no input ['receiver']
# WARNING:root:cannot compute similarity with no input ['seyt']
# WARNING:root:cannot compute similarity with no input ['cheap', 'nobility']
# WARNING:root:cannot compute similarity with no input ['pagens', 'ont', 'tort', 'et', 'chretiens', 'ont', 'droit']
# WARNING:root:cannot compute similarity with no input ['lyar', 'slaue']
# WARNING:root:cannot compute similarity with no input ['betweene']
# WARNING:root:cannot compute similarity with no input ['pooh']
# WARNING:root:cannot compute similarity with no input ['jerk', 'haul', 'cowards']
# WARNING:root:cannot compute similarity with no input ['faile']
# WARNING:root:cannot compute similarity with no input ['murdered']
# WARNING:root:cannot compute similarity with no input ['roughs']
# WARNING:root:cannot compute similarity with no input ['sped', 'fleeting', 'customs', 'popularities']
# WARNING:root:cannot compute similarity with no input ['hosea']
# WARNING:root:cannot compute similarity with no input ['bashful', 'feminine']
# WARNING:root:cannot compute similarity with no input ['mannahatta']
# WARNING:root:cannot compute similarity with no input ['proprietor']
# WARNING:root:cannot compute similarity with no input ['cherries']
# WARNING:root:cannot compute similarity with no input ['greece', 'turk']
# WARNING:root:cannot compute similarity with no input ['scena', 'septima']
# WARNING:root:cannot compute similarity with no input ['sleepes']
# WARNING:root:cannot compute similarity with no input ['whoel', 'anglo', 'saxon']
# WARNING:root:cannot compute similarity with no input ['sally', 'chambermaid']
# WARNING:root:cannot compute similarity with no input ['montaigne']
# WARNING:root:cannot compute similarity with no input ['provisions']
# WARNING:root:cannot compute similarity with no input ['knights', 'squires']
# WARNING:root:cannot compute similarity with no input ['pooh']
# WARNING:root:cannot compute similarity with no input ['brigands']
# WARNING:root:cannot compute similarity with no input ['hyena']
# WARNING:root:cannot compute similarity with no input ['saddle']
# WARNING:root:cannot compute similarity with no input ['ix']
# WARNING:root:cannot compute similarity with no input ['spain']
# WARNING:root:cannot compute similarity with no input ['barnardo']
# WARNING:root:cannot compute similarity with no input ['dicotyledonous']
# WARNING:root:cannot compute similarity with no input ['outrageous']
# WARNING:root:cannot compute similarity with no input ['horat']
# WARNING:root:cannot compute similarity with no input ['advertisement']
# WARNING:root:cannot compute similarity with no input ['deci']
# WARNING:root:cannot compute similarity with no input ['haul']
# WARNING:root:cannot compute similarity with no input ['swabian']
# WARNING:root:cannot compute similarity with no input ['pouf']
# WARNING:root:cannot compute similarity with no input ['caw']
# WARNING:root:cannot compute similarity with no input ['seizings']
# WARNING:root:cannot compute similarity with no input ['scaena', 'sexta']
# WARNING:root:cannot compute similarity with no input ['paley', 'theology']
# WARNING:root:cannot compute similarity with no input ['cistern', 'buckets']
# WARNING:root:cannot compute similarity with no input ['clown']
# WARNING:root:cannot compute similarity with no input ['haul', 'haul', 'tahitian']
# WARNING:root:cannot compute similarity with no input ['itching', 'palme']
# WARNING:root:cannot compute similarity with no input ['jollies']
# WARNING:root:cannot compute similarity with no input ['curiouser', 'curiouser']
# WARNING:root:cannot compute similarity with no input ['partnership']
# WARNING:root:cannot compute similarity with no input ['hercules', 'load']
# WARNING:root:cannot compute similarity with no input ['traitor']
# WARNING:root:cannot compute similarity with no input ['savantism']
# WARNING:root:cannot compute similarity with no input ['specksynder']
# WARNING:root:cannot compute similarity with no input ['wallachian']
# WARNING:root:cannot compute similarity with no input ['doo']
# WARNING:root:cannot compute similarity with no input ['fearefull']
# WARNING:root:cannot compute similarity with no input ['scena', 'quinta']
# WARNING:root:cannot compute similarity with no input ['halloa', 'smut']
# WARNING:root:cannot compute similarity with no input ['trident']
# WARNING:root:cannot compute similarity with no input ['swede']
# WARNING:root:cannot compute similarity with no input ['nursery', 'rhyme']
# WARNING:root:cannot compute similarity with no input ['dancer']
# WARNING:root:cannot compute similarity with no input ['laer']
# WARNING:root:cannot compute similarity with no input ['omnes']
# WARNING:root:cannot compute similarity with no input ['amos']
# WARNING:root:cannot compute similarity with no input ['sooth']
# WARNING:root:cannot compute similarity with no input ['zephaniah']
# WARNING:root:cannot compute similarity with no input ['borrowed']
# WARNING:root:cannot compute similarity with no input ['sally']
# WARNING:root:cannot compute similarity with no input ['jabbering', 'shipmate']
# WARNING:root:cannot compute similarity with no input ['ruinationed']
# WARNING:root:cannot compute similarity with no input ['opposites']
# WARNING:root:cannot compute similarity with no input ['japanese']
# WARNING:root:cannot compute similarity with no input ['instigated']
# WARNING:root:cannot compute similarity with no input ['encore']
# WARNING:root:cannot compute similarity with no input ['actus', 'quartus']
# WARNING:root:cannot compute similarity with no input ['gis', 'aint']
# WARNING:root:cannot compute similarity with no input ['spontaneous']
# WARNING:root:cannot compute similarity with no input ['rev']
# WARNING:root:cannot compute similarity with no input ['tish']
# WARNING:root:cannot compute similarity with no input ['imperiously']
# WARNING:root:cannot compute similarity with no input ['cassock']
# WARNING:root:cannot compute similarity with no input ['breaks']
# WARNING:root:cannot compute similarity with no input ['flummery']
# WARNING:root:cannot compute similarity with no input ['vi']
# WARNING:root:cannot compute similarity with no input ['treb']
# WARNING:root:cannot compute similarity with no input ['kinde', 'goodnight']
# WARNING:root:cannot compute similarity with no input ['dispatch']
# WARNING:root:cannot compute similarity with no input ['quarrelled']
# ...
# WARNING:root:cannot compute similarity with no input ['wow']
# WARNING:root:cannot compute similarity with no input ['shoo']
# WARNING:root:cannot compute similarity with no input ['geraniums', 'barking']
# WARNING:root:cannot compute similarity with no input ['vista']
# WARNING:root:cannot compute similarity with no input ['hurrah']
# WARNING:root:cannot compute similarity with no input ['crosse']
# WARNING:root:cannot compute similarity with no input ['ang']
# WARNING:root:cannot compute similarity with no input ['moues', 'highnesse']
# WARNING:root:cannot compute similarity with no input ['reclining', 'interrogating']
# WARNING:root:cannot compute similarity with no input ['patroling', 'barnegat']
# WARNING:root:cannot compute similarity with no input ['sweare']
# WARNING:root:cannot compute similarity with no input ['ro']
# WARNING:root:cannot compute similarity with no input ['airy']
# WARNING:root:cannot compute similarity with no input ['shirr']
# WARNING:root:cannot compute similarity with no input ['winthrop']
# WARNING:root:cannot compute similarity with no input ['bloodshed', 'physical', 'incident']
# WARNING:root:cannot compute similarity with no input ['ankers', 'geneva']
# WARNING:root:cannot compute similarity with no input ['forged']
# WARNING:root:cannot compute similarity with no input ['harasses']
# WARNING:root:cannot compute similarity with no input ['luc']
# WARNING:root:cannot compute similarity with no input ['womanly', 'housework']
# WARNING:root:cannot compute similarity with no input ['vol']
# WARNING:root:cannot compute similarity with no input ['soup']
# WARNING:root:cannot compute similarity with no input ['unlucky']
# WARNING:root:cannot compute similarity with no input ['norwegian']
# WARNING:root:cannot compute similarity with no input ['fortin']
# WARNING:root:cannot compute similarity with no input ['committees', 'parsons', 'petitions']
# WARNING:root:cannot compute similarity with no input ['sirius', 'jupiter']
# WARNING:root:cannot compute similarity with no input ['strooke']
# WARNING:root:cannot compute similarity with no input ['answere']
# WARNING:root:cannot compute similarity with no input ['unkind']
# WARNING:root:cannot compute similarity with no input ['prophesie']
# WARNING:root:cannot compute similarity with no input ['quohog']
# WARNING:root:cannot compute similarity with no input ['alarum']
# WARNING:root:cannot compute similarity with no input ['luke']
# WARNING:root:cannot compute similarity with no input ['humph']
# WARNING:root:cannot compute similarity with no input ['xvii']
# WARNING:root:cannot compute similarity with no input ['publius']
# WARNING:root:cannot compute similarity with no input ['ferries']
# WARNING:root:cannot compute similarity with no input ['squid']
# WARNING:root:cannot compute similarity with no input ['extras']
# WARNING:root:cannot compute similarity with no input ['vial']
# WARNING:root:cannot compute similarity with no input ['grinned']
# WARNING:root:cannot compute similarity with no input ['hoa', 'guildensterne']
# WARNING:root:cannot compute similarity with no input ['testament']
# WARNING:root:cannot compute similarity with no input ['beauteous', 'maiesty', 'denmark']
# WARNING:root:cannot compute similarity with no input ['lucil']
# WARNING:root:cannot compute similarity with no input ['germs']
# WARNING:root:cannot compute similarity with no input ['sh']
# WARNING:root:cannot compute similarity with no input ['hor']
# WARNING:root:cannot compute similarity with no input ['alacke', 'noyse']
# WARNING:root:cannot compute similarity with no input ['decius']
# WARNING:root:cannot compute similarity with no input ['suppress']
# WARNING:root:cannot compute similarity with no input ['holloa']
# WARNING:root:cannot compute similarity with no input ['hackluyt']
# WARNING:root:cannot compute similarity with no input ['russ', 'russia']
# WARNING:root:cannot compute similarity with no input ['maisters']
# WARNING:root:cannot compute similarity with no input ['pol']
# WARNING:root:cannot compute similarity with no input ['hoboyes', 'torches']
# WARNING:root:cannot compute similarity with no input ['scena', 'tertia']
# WARNING:root:cannot compute similarity with no input ['reads']
# WARNING:root:cannot compute similarity with no input ['ensign']
# WARNING:root:cannot compute similarity with no input ['imperturbe']
# WARNING:root:cannot compute similarity with no input ['saddled']
# WARNING:root:cannot compute similarity with no input ['cath']
# WARNING:root:cannot compute similarity with no input ['holland', 'plutarch', 'morals']
# WARNING:root:cannot compute similarity with no input ['ugh']
# WARNING:root:cannot compute similarity with no input ['hop']
# WARNING:root:cannot compute similarity with no input ['clue']
# WARNING:root:cannot compute similarity with no input ['peasant']
# WARNING:root:cannot compute similarity with no input ['slaue']
# WARNING:root:cannot compute similarity with no input ['wold', 'faine', 'proue']
# WARNING:root:cannot compute similarity with no input ['advertise']
# WARNING:root:cannot compute similarity with no input ['rallies']
# WARNING:root:cannot compute similarity with no input ['drowsing']
# WARNING:root:cannot compute similarity with no input ['chairing']
# WARNING:root:cannot compute similarity with no input ['br']
# WARNING:root:cannot compute similarity with no input ['feminine']
# WARNING:root:cannot compute similarity with no input ['mutter']
# WARNING:root:cannot compute similarity with no input ['iudgement']
# WARNING:root:cannot compute similarity with no input ['pays', 'reg', 'lar', 'rejoinder']
# WARNING:root:cannot compute similarity with no input ['barnfloor', 'winepress']
# WARNING:root:cannot compute similarity with no input ['louis', 'xvi']
# WARNING:root:cannot compute similarity with no input ['peste']
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input ['hem']
# WARNING:root:cannot compute similarity with no input ['zooks']
# WARNING:root:cannot compute similarity with no input ['donalbaine']
# WARNING:root:cannot compute similarity with no input ['duodecimo']
# WARNING:root:cannot compute similarity with no input ['trans']
# WARNING:root:cannot compute similarity with no input ['sardinian']
# WARNING:root:cannot compute similarity with no input ['spaniard', 'spain']
# WARNING:root:cannot compute similarity with no input ['daisy']
# WARNING:root:cannot compute similarity with no input ['culpable']
# WARNING:root:cannot compute similarity with no input ['sinkes', 'caldron']
# WARNING:root:cannot compute similarity with no input ['pratt']
# WARNING:root:cannot compute similarity with no input ['ardently']
# WARNING:root:cannot compute similarity with no input ['corpusants']
# WARNING:root:cannot compute similarity with no input ['denounce']
# WARNING:root:cannot compute similarity with no input ['mar']
# WARNING:root:cannot compute similarity with no input ['rests']
# WARNING:root:cannot compute similarity with no input ['hecuba', 'hecuba', 'weepe']
# WARNING:root:cannot compute similarity with no input ['derived']
# WARNING:root:cannot compute similarity with no input ['qu']
# WARNING:root:cannot compute similarity with no input ['heaviness']
# WARNING:root:cannot compute similarity with no input ['antecedents']
# WARNING:root:cannot compute similarity with no input ['lep']
# WARNING:root:cannot compute similarity with no input ['undergraduate']
# WARNING:root:cannot compute similarity with no input ['wormes', 'flyes']
# WARNING:root:cannot compute similarity with no input ['cobl']
# WARNING:root:cannot compute similarity with no input ['definite', 'hindrance']
# WARNING:root:cannot compute similarity with no input ['xviii']
# WARNING:root:cannot compute similarity with no input ['doct']
# WARNING:root:cannot compute similarity with no input ['foil', 'european', 'revolutionaire']
# WARNING:root:cannot compute similarity with no input ['squeeze']
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input ['xi']
# WARNING:root:cannot compute similarity with no input ['canallers']
# WARNING:root:cannot compute similarity with no input ['guil']
# WARNING:root:cannot compute similarity with no input ['gilbert']
# WARNING:root:cannot compute similarity with no input ['chi', 'di', 'gallina', 'nasce', 'convien', 'che', 'rozole']
# WARNING:root:cannot compute similarity with no input ['hic', 'vbique']
# WARNING:root:cannot compute similarity with no input ['forgetful']
# WARNING:root:cannot compute similarity with no input ['jibes']
# WARNING:root:cannot compute similarity with no input ['realist']
# WARNING:root:cannot compute similarity with no input ['perishing', 'pendragons']
# WARNING:root:cannot compute similarity with no input ['ecclesiastes']
# WARNING:root:cannot compute similarity with no input ['rev']
# WARNING:root:cannot compute similarity with no input ['pekee', 'nuee', 'nuee', 'erromangoan']
# WARNING:root:cannot compute similarity with no input ['violet']
# WARNING:root:cannot compute similarity with no input ['avast']
# WARNING:root:cannot compute similarity with no input ['damages']
# WARNING:root:cannot compute similarity with no input ['iv']
# WARNING:root:cannot compute similarity with no input ['duffey']
# WARNING:root:cannot compute similarity with no input ['blazes']
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input ['thankes', 'maiesty']
# WARNING:root:cannot compute similarity with no input []
# WARNING:root:cannot compute similarity with no input ['concealments']
# WARNING:root:cannot compute similarity with no input ['um']
# WARNING:root:cannot compute similarity with no input ['bulgarian']
# WARNING:root:cannot compute similarity with no input ['amb']
# WARNING:root:cannot compute similarity with no input ['adieu']
# WARNING:root:cannot compute similarity with no input ['phiz']
# WARNING:root:cannot compute similarity with no input ['h']
# WARNING:root:cannot compute similarity with no input ['frenchmen']
# WARNING:root:cannot compute similarity with no input ['sirra', 'newes']
# WARNING:root:cannot compute similarity with no input ['dogma']
# WARNING:root:cannot compute similarity with no input ['despatch']
# WARNING:root:cannot compute similarity with no input ['dwarf', 'kamtschatkan', 'greenlander', 'lapp']
# WARNING:root:cannot compute similarity with no input ['boasting']
# WARNING:root:cannot compute similarity with no input ['chemistry']
# WARNING:root:cannot compute similarity with no input ['scullion']
# WARNING:root:cannot compute similarity with no input ['vocalism']
# WARNING:root:cannot compute similarity with no input ['interpret']
# WARNING:root:cannot compute similarity with no input ['marcellus']
# WARNING:root:cannot compute similarity with no input ['hearses']
# WARNING:root:cannot compute similarity with no input ['aha']
# WARNING:root:cannot compute similarity with no input ['murth']
# WARNING:root:cannot compute similarity with no input ['statement', 'disclaims', 'liability']
# WARNING:root:cannot compute similarity with no input ['pennsylvanian']
# WARNING:root:cannot compute similarity with no input ['xvii']
# WARNING:root:cannot compute similarity with no input ['scone']
# WARNING:root:cannot compute similarity with no input ['curves', 'angles', 'dots']
# WARNING:root:cannot compute similarity with no input ['continuities']
# WARNING:root:cannot compute similarity with no input ['signifies', 'mouthing', 'persuading', 'convincing']
# WARNING:root:cannot compute similarity with no input ['hoot']
# WARNING:root:cannot compute similarity with no input ['fortify']
# WARNING:root:cannot compute similarity with no input ['retreating']
# WARNING:root:cannot compute similarity with no input ['gambals']
# WARNING:root:cannot compute similarity with no input ['snatch']
# WARNING:root:cannot compute similarity with no input ['excelsior']
# WARNING:root:cannot compute similarity with no input ['amisse']
# WARNING:root:cannot compute similarity with no input ['obstinate', 'blockhead']
# WARNING:root:cannot compute similarity with no input ['hurrah', 'tambourine']
# WARNING:root:cannot compute similarity with no input ['huh']
# WARNING:root:cannot compute similarity with no input ['hvalt', 'danish']
# WARNING:root:cannot compute similarity with no input ['hop', 'hop']
# WARNING:root:cannot compute similarity with no input ['arctic', 'braced']
# WARNING:root:cannot compute similarity with no input ['aboue']
# WARNING:root:cannot compute similarity with no input ['miguel']
# WARNING:root:cannot compute similarity with no input ['osricke']
# WARNING:root:cannot compute similarity with no input ['hello']
# WARNING:root:cannot compute similarity with no input ['fred']
# WARNING:root:cannot compute similarity with no input ['crotch']
# WARNING:root:cannot compute similarity with no input ['xiii']
# WARNING:root:cannot compute similarity with no input ['goldsmith', 'nat']
# WARNING:root:cannot compute similarity with no input ['magnanimity']
# WARNING:root:cannot compute similarity with no input ['varieties', 'literature', 'vol']
# WARNING:root:cannot compute similarity with no input ['confine']
# WARNING:root:cannot compute similarity with no input ['bet']
# WARNING:root:cannot compute similarity with no input ['nut']
# WARNING:root:cannot compute similarity with no input ['bravissimo']
# WARNING:root:cannot compute similarity with no input ['phoo', 'phoo']
# WARNING:root:cannot compute similarity with no input ['calles']
# WARNING:root:cannot compute similarity with no input ['listener']
# WARNING:root:cannot compute similarity with no input ['leaks', 'leaks']
# WARNING:root:cannot compute similarity with no input ['vi']
# WARNING:root:cannot compute similarity with no input ['cobwebs']
# WARNING:root:cannot compute similarity with no input ['chicago', 'kanada', 'arkansas']
# WARNING:root:cannot compute similarity with no input ['marches', 'humanitarian']
# WARNING:root:cannot compute similarity with no input ['accouche']
# WARNING:root:cannot compute similarity with no input ['walt', 'whitman']
# WARNING:root:cannot compute similarity with no input ['somerville']
# WARNING:root:cannot compute similarity with no input ['idiot']
# WARNING:root:cannot compute similarity with no input ['bracelets']
# WARNING:root:cannot compute similarity with no input ['cin']
# WARNING:root:cannot compute similarity with no input ['proverbs']
# WARNING:root:cannot compute similarity with no input ['apostate']
# WARNING:root:cannot compute similarity with no input ['flaw']
# WARNING:root:cannot compute similarity with no input ['polon']
# WARNING:root:cannot compute similarity with no input ['por']
# WARNING:root:cannot compute similarity with no input ['enact']
# WARNING:root:cannot compute similarity with no input ['pshaw']
# WARNING:root:cannot compute similarity with no input ['carbuncle']
# WARNING:root:cannot compute similarity with no input ['phoo']
# WARNING:root:cannot compute similarity with no input ['hello']
# WARNING:root:cannot compute similarity with no input ['donal']
# WARNING:root:cannot compute similarity with no input ['fran']
# WARNING:root:cannot compute similarity with no input ['newes']
# WARNING:root:cannot compute similarity with no input ['koo', 'loo']
# WARNING:root:cannot compute similarity with no input ['varrus', 'claudio']
# WARNING:root:cannot compute similarity with no input ['romane']
# WARNING:root:cannot compute similarity with no input ['falconer', 'shipwreck']
# WARNING:root:cannot compute similarity with no input ['implore']
# WARNING:root:cannot compute similarity with no input ['feminine', 'curves']
# WARNING:root:cannot compute similarity with no input ['chug', 'rum']
# WARNING:root:cannot compute similarity with no input ['dyes']
# WARNING:root:cannot compute similarity with no input ['rosemary', 'remembraunce']
# WARNING:root:cannot compute similarity with no input ['orthodoxy']
# WARNING:root:cannot compute similarity with no input ['goddard']
# WARNING:root:cannot compute similarity with no input ['visor']
# WARNING:root:cannot compute similarity with no input ['equivocations']
# WARNING:root:cannot compute similarity with no input ['eclaircise', 'myths', 'asiatic', 'primitive', 'fables']
# WARNING:root:cannot compute similarity with no input ['xx']

# %%
#  Check if the word is in vocabulary -> count =5 -> not in vocab
word_freq ['prejudiced']
# Out:
# 5

# %%
len(X_train_w2v_average[4])
# Out:
# 300

# %%
# len(X_train_w2v_average)

# %% [markdown]
# #### Apply Naive Bayes model

# %%
# naive_w2v = MultinomialNB()
# classifier_w2v = naive_w2v.fit(X_train_w2v_average,y_train_w2v)
# predict_w2v = classifier_w2v.predict(X_test_w2v_average)

# %% [markdown]
# #### Apply LogisticRegression model

# %%
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression(n_jobs=1, C=1e5)
logreg = logreg.fit(X_train_w2v_average,y_train_w2v)
predict_w2v = logreg.predict(X_test_w2v_average)
print('accuracy %s' % accuracy_score(predict_w2v,y_test_w2v))
print(classification_report(y_test_w2v, predict_w2v))
# Out:
# c:\python\python37\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# c:\python\python37\lib\site-packages\sklearn\linear_model\logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# accuracy 0.7584464654452792
#               precision    recall  f1-score   support
#
#            0       0.74      0.82      0.78      3930
#            1       0.90      0.96      0.93      7381
#            2       0.49      0.26      0.34        95
#            3       0.59      0.36      0.45       683
#            4       0.74      0.59      0.66       230
#            5       0.75      0.42      0.54       380
#            6       0.66      0.68      0.67      2900
#            7       0.64      0.57      0.61      2230
#            8       0.69      0.63      0.66      2339
#            9       0.74      0.58      0.65       443
#           10       0.69      0.77      0.73      1120
#           11       0.60      0.52      0.56      1030
#
#     accuracy                           0.76     22761
#    macro avg       0.69      0.60      0.63     22761
# weighted avg       0.75      0.76      0.75     22761

# %%
docs_new_w2v = ['Even before Miss Taylor had ceased to hold the nominal office of governess',
                'Piping down the valleys wild',
                   'How sweet is the Shepherd sweet lot!',
                 'From the morn to the evening he stays',
                  "The sun does arise, And make happy the skies;  The merry bells ring To welcome the Spring;The skylark and thrush"
               ]
sent_test = [row.split() for row in docs_new_w2v ]
phrases_test = Phrases(sent_test, min_count=30, progress_per=10000)
bigram_test = Phraser(phrases_test)



# predicted = classifier_tfidf.predict(X_new_w2v)
# predicted

# %%
sentences_test = bigram_test[sent_test]

# %%
sentences_test[0]
# Out:
# ['Even',
#  'before',
#  'Miss',
#  'Taylor',
#  'had',
#  'ceased',
#  'to',
#  'hold',
#  'the',
#  'nominal',
#  'office',
#  'of',
#  'governess']

# %%
test_model_w2v_average = word_averaging_list(w2v_model.wv,sentences_test)
# Out:
# c:\python\python37\lib\site-packages\ipykernel_launcher.py:11: DeprecationWarning: Call to deprecated `syn0norm` (Attribute will be removed in 4.0.0, use self.vectors_norm instead).
#   # This is added back by InteractiveShellApp.init_path()

# %%
# len(test_model_w2v_average[0])

# %%
predict_w2v_test = logreg.predict(test_model_w2v_average)

# %%
predict_w2v_test
# Out:
# array([1, 2, 2, 2, 2], dtype=int64)

# %%
counter  = 0
for doc, category in zip(docs_new_w2v, predict_w2v_test):
    print('%r => %s' % (doc, id_to_author_name[category]))
    if(counter == 10):
        break
    counter += 1
# Out:
# 'Even before Miss Taylor had ceased to hold the nominal office of governess' => bible
# 'Piping down the valleys wild' => blake
# 'How sweet is the Shepherd sweet lot!' => blake
# 'From the morn to the evening he stays' => blake
# 'The sun does arise, And make happy the skies;  The merry bells ring To welcome the Spring;The skylark and thrush' => blake

# %% [markdown]
# <img src="2019-12-21_2219.png" alt="drawing" width="400"/>

# %% [markdown]
# ### Conclusion
#
# > Awesome , the model classify right for all test cases
#
# > Not sure if  LogisticRegression is fitted to this data then Naive Bayes  or Vord2vec is better than TF-IDF and Bags of Word

# %% [markdown]
# # 8. Using LSA
#
#  > We will use tfidf from the previous step

# %%
# tfidf_transformer = TfidfTransformer()
# X_tfidf = tfidf_transformer.fit_transform(train_data_features_bow)
# X_tfidf.shape

# %%
X_tfidf.shape
# Out:
# (98552, 6054)

# %%
from sklearn.decomposition import TruncatedSVD
from sklearn.metrics.pairwise import cosine_similarity
#   nên in matra  V để  tuning n
# , n_iter=7, random_state=42
#  For LSA, a value of 100 is recommended.
svd = TruncatedSVD(n_components = 800, n_iter=7, random_state=42)
X_lsa = svd.fit_transform(X_tfidf)

# print (X_lsa)

# %%
var_explained = svd.explained_variance_ratio_.sum()
var_explained
# Out:
# 0.5434469647833647

# %%
U = X_lsa / svd.singular_values_
Sigma_matrix = np.diag(svd.singular_values_)
VT = svd.components_

# %%
U.shape
# Out:
# (98552, 800)

# %%
Sigma_matrix.shape
# Out:
# (800, 800)

# %%
# print( Sigma_matrix )

# %%
X_lsa.shape
# Out:
# (98552, 800)

# %%
VT.shape
# Out:
# (800, 6054)

# %%
X_train_lsa, X_test_lsa, y_train_lsa, y_test_lsa = train_test_split(X_lsa, data['author_id'],test_size=0.25,random_state=123)

# %% [markdown]
# #### Print 10 words for each topic

# %%
terms = vectorizer.get_feature_names()

for i, comp in enumerate(svd.components_):
    terms_comp = zip(terms, comp)
    sorted_terms = sorted(terms_comp, key= lambda x:x[1], reverse=True)[:10]
    print("Topic "+str(i)+": ")
    top_ten_words = ""
    for t in sorted_terms:
        top_ten_words = top_ten_words + " " + str(t[0])
    print(top_ten_words + " " )
# Out:
# Topic 0:
#  shall lord said unto thou thy thee god ye man
# Topic 1:
#  said oh would little king well unto mr could know
# Topic 2:
#  shall ye said oh one know see would man come
# Topic 3:
#  oh thou thy thee would know shalt one could hast
# Topic 4:
#  lord oh ye unto god israel king saith moses hath
# Topic 5:
#  said shall oh thou unto thee thy shalt hast thine
# Topic 6:
#  ye unto king say son god came come israel men
# Topic 7:
#  ham king shall lord sons noah said came canaan upon
# Topic 8:
#  king son came shall israel went house man david judah
# Topic 9:
#  know king ye thou well lord see would thy think
# Topic 10:
#  chapter know king ye thou ii iii iv lord well
# Topic 11:
#  man know thou god old king son ye hast every
# Topic 12:
#  know unto thee come god let us man thy hath
# Topic 13:
#  thy god thee ye man let king said hath see
# Topic 14:
#  come man let us see thou go king lord old
# Topic 15:
#  one come god know thou us upon another two said
# Topic 16:
#  god us well good say thou hath would let shall
# Topic 17:
#  say one would come king god thy man good thee
# Topic 18:
#  well come one ye thy good another man think every
# Topic 19:
#  one let us say go see well another may king
# Topic 20:
#  go would let us think good ye must give shall
# Topic 21:
#  thee good one would see unto king man god think
# Topic 22:
#  good thy mr must evil day may came son sir
# Topic 23:
#  thee like upon little came ye great cried time say
# Topic 24:
#  like thy unto good would well come look king whale
# Topic 25:
#  mr could unto think us thy must king mrs cried
# Topic 26:
#  go must god come thy way little house unto may
# Topic 27:
#  son like father mr think must go thee one sons
# Topic 28:
#  think little could old must father nothing children son us
# Topic 29:
#  little father cried could son unto boy mother joe thought
# Topic 30:
#  must hath us father upon done things thing time tell
# Topic 31:
#  could never nothing let hath thing go done son every
# Topic 32:
#  cried upon think go son hand sir father unto head
# Topic 33:
#  cried children israel sir could must land men hundred people
# Topic 34:
#  upon little let mr children son unto hand hath must
# Topic 35:
#  let day must sir came thing went house every hear
# Topic 36:
#  hath thing never done children cried every father go made
# Topic 37:
#  father mother brown sir house children yes asked men israel
# Topic 38:
#  sir yes time never nothing old us son dear may
# Topic 39:
#  never upon thing must went thought heard let father saw
# Topic 40:
#  day father children upon never israel every night time us
# Topic 41:
#  thing sir came every hath little land israel done yes
# Topic 42:
#  thing went every men time house yes may way us
# Topic 43:
#  time came thing children tell israel yes father pass first
# Topic 44:
#  people went land time great much may yes hand way
# Topic 45:
#  yes people great indeed much may came nothing things men
# Topic 46:
#  nothing upon people tell went land name children done father
# Topic 47:
#  yes nothing indeed hand went children right done way away
# Topic 48:
#  bru hand may stand friend right together fast caesars least
# Topic 49:
#  hand may men right sir father things give thing mean
# Topic 50:
#  old hand land house nothing away years thing right take
# Topic 51:
#  house may much things tell mrs children israel made way
# Topic 52:
#  tell old things mean went done name mr asked great
# Topic 53:
#  great children indeed way much went things whale done land
# Topic 54:
#  great house hand yes nothing time made tell right things
# Topic 55:
#  mean things great may land yes look made way children
# Topic 56:
#  indeed mean people done hand time name house much things
# Topic 57:
#  land indeed tell house men may never egypt time mr
# Topic 58:
#  done may things indeed old mr could make look people
# Topic 59:
#  much look made way yet mr things men people thought
# Topic 60:
#  sons things done much two enter land yes people three
# Topic 61:
#  done much old men house enter mean great upon yes
# Topic 62:
#  enter two lady look land asked people mrs three macbeth
# Topic 63:
#  look mrs land done away miss men take things dear
# Topic 64:
#  look great may sons way hath done people enter father
# Topic 65:
#  asked sons name hand done mrs may syme way land
# Topic 66:
#  asked away take name much syme done house turnbull may
# Topic 67:
#  macb name mother yet though called look ever mr whale
# Topic 68:
#  name mother look called much mr ever hand also yet
# Topic 69:
#  way done yet name whale ever give house mrs take
# Topic 70:
#  make two done made way name great tell hundred thought
# Topic 71:
#  way make sons things old men enter name give day
# Topic 72:
#  made thought sons done enter away men may yet israel
# Topic 73:
#  thought make yet heard first saw hear voice alice house
# Topic 74:
#  thought made things give way name may take two alice
# Topic 75:
#  yet mrs asked people dear thought hath never came every
# Topic 76:
#  give take ever yet dear life went love done sure
# Topic 77:
#  take heard thing mrs whale day yet made first things
# Topic 78:
#  sure yet away quite thing way dear two day another
# Topic 79:
#  whale sure ever dear quite right head things white miss
# Topic 80:
#  ever mrs away give thing make saw earth world things
# Topic 81:
#  sure yet ever every mrs name look came father asked
# Topic 82:
#  hear ever dear yet made thought away way whale asked
# Topic 83:
#  give whale away hear right make thought word head white
# Topic 84:
#  hear even also word take world speak heart love long
# Topic 85:
#  quite saw first looked face things miss last hath every
# Topic 86:
#  even also ever word miss quite speak saying jesus yet
# Topic 87:
#  quite mother right ever heard love heart life answered long
# Topic 88:
#  mother first speak last lady put word book might life
# Topic 89:
#  love life first speak world long quite last name word
# Topic 90:
#  even first mother last book lady something heard shalt earth
# Topic 91:
#  heart eyes head thine mine name israel put david speak
# Topic 92:
#  miss long head hear put life love even death name
# Topic 93:
#  long speak lady world word even miss thus cannot saith
# Topic 94:
#  also miss love lady children heart last earth world first
# Topic 95:
#  miss lady life whale saith earth woodhouse heart thus saw
# Topic 96:
#  love lady jesus answered saw might christ dear head two
# Topic 97:
#  speak life saw right lady even earth shalt death looked
# Topic 98:
#  head quite put earth life world death saith also thus
# Topic 99:
#  lady long dear also life young book right russell david
# Topic 100:
#  love israel long saith book thus behold saw another also
# Topic 101:
#  world saw quite word hand whale something heard many dear
# Topic 102:
#  ah world book right israel david two put head love
# Topic 103:
#  ah saith thus first poor speak children lady therefore behold
# Topic 104:
#  cassi world last love saith lady right thus night speak
# Topic 105:
#  might ah word earth book poor something another better long
# Topic 106:
#  might saith right poor book children thus something better jesus
# Topic 107:
#  place put shalt long heart might david whale world without
# Topic 108:
#  word last night place right another life saying still better
# Topic 109:
#  head three years days right many might hundred david thousand
# Topic 110:
#  last saw speak night shalt jesus three heart poor book
# Topic 111:
#  word poor long put saw heart head first earth jesus
# Topic 112:
#  poor david better israel something answered two first always shalt
# Topic 113:
#  poor shalt book face many three word days place eyes
# Topic 114:
#  place poor david hast book behold eyes mine children brought
# Topic 115:
#  better something book get word hast want put place three
# Topic 116:
#  place israel something speak hast saw head poor love answered
# Topic 117:
#  put better another israel hast still many death cannot years
# Topic 118:
#  another head going place still life answered heart book emma
# Topic 119:
#  something another face put hast always jesus poor going found
# Topic 120:
#  ha another put still something matter david israel going first
# Topic 121:
#  face jesus better christ david heart dead back called always
# Topic 122:
#  many eyes still believe without mine something always cannot earth
# Topic 123:
#  going many without want get face back brought hast thus
# Topic 124:
#  still emma cannot without always believe david soon three found
# Topic 125:
#  without want jesus voice another christ dead get saying israel
# Topic 126:
#  going eyes jesus night get christ word mine back israel
# Topic 127:
#  want voice believe cannot really still place get many book
# Topic 128:
#  hor voice many emma cannot want believe saying place mount
# Topic 129:
#  cannot believe heard face want without going last really hear
# Topic 130:
#  emma going voice looked jesus harriet last friend without whale
# Topic 131:
#  want emma still heard get eyes david friend mine enough
# Topic 132:
#  always voice want face enough saying syme mine eyes without
# Topic 133:
#  cannot therefore wife night dead face behold among eat mine
# Topic 134:
#  looked behold wife saying believe eat moses took want told
# Topic 135:
#  wife captain believe therefore ahab found gone mine eyes brother
# Topic 136:
#  wife looked still always going therefore without word want put
# Topic 137:
#  still behold face going saying told therefore called words moses
# Topic 138:
#  therefore night believe gone matter voice looked without another emma
# Topic 139:
#  night believe wife face thus better saith morning woman sea
# Topic 140:
#  captain ahab sea cannot looked behold ship wentworth friend therefore
# Topic 141:
#  get saying behold gone told wife night put place art
# Topic 142:
#  gone behold back woman stand better soon want dead bring
# Topic 143:
#  get believe wife behold woman still syme brought speak sea
# Topic 144:
#  syme found soon gone eyes elinor voice marianne therefore replied
# Topic 145:
#  words syme stand back sea want wife therefore dead art
# Topic 146:
#  words turnbull gone eyes behold brought thine took cannot forth
# Topic 147:
#  found sea among woman turnbull three soul side dead macian
# Topic 148:
#  woman words gone called get mine looked eat young days
# Topic 149:
#  called days back night captain three woman thine seen hast
# Topic 150:
#  matter found words friend brought night behold stand captain get
# Topic 151:
#  matter called art enough sea turnbull really eyes side three
# Topic 152:
#  matter eat gone hast days captain seen ahab emma dead
# Topic 153:
#  woman back matter thousand sea therefore hundred side soon words
# Topic 154:
#  friend mine sea called side city hast matter seen wife
# Topic 155:
#  turnbull dead syme back friend called art captain replied years
# Topic 156:
#  enough dead behold eat soul words soon back days word
# Topic 157:
#  dead friend sea stand death eyes bring offering replied pray
# Topic 158:
#  friend turnbull syme stand woman really hands took told name
# Topic 159:
#  enough called among soul gone syme true wife thousand voice
# Topic 160:
#  eat found boy called thousand friend eyes matter stand hundred
# Topic 161:
#  stand replied dead called mine syme told seen turnbull hast
# Topic 162:
#  among eyes art marianne stand behold elinor david soon friend
# Topic 163:
#  hands dead among enough work called friend hast saying call
# Topic 164:
#  boy afraid told seen brown bear farmer buster really wife
# Topic 165:
#  hands offering soon wife three david burnt work many fire
# Topic 166:
#  soon really began true years stand city jerusalem bring syme
# Topic 167:
#  soul hands really brother replied sea elinor marianne pray call
# Topic 168:
#  really true eat behold dead mine replied elinor offering marianne
# Topic 169:
#  death brother told seen hands city among took law really
# Topic 170:
#  three really took soul brought hope dead israel death shalt
# Topic 171:
#  brother soon eat turnbull death sea syme brought call saith
# Topic 172:
#  told sea dead days saith really call found put life
# Topic 173:
#  exeunt louisa talbot told call took sea days soon wheeler
# Topic 174:
#  hope told bring eat round city forth together set thereof
# Topic 175:
#  pray true seen call bring wife eat told forth three
# Topic 176:
#  hope death days pray call true took replied haue sea
# Topic 177:
#  pray brother hope took soul bring life true seen city
# Topic 178:
#  took replied told three alice soon began sea years boy
# Topic 179:
#  seen really art hope three replied together city words alice
# Topic 180:
#  call marianne bring elinor answer though took morning young offering
# Topic 181:
#  pray afraid really neither alice evil though death end fear
# Topic 182:
#  city bring afraid sea neither elinor soon evil thousand three
# Topic 183:
#  true seen afraid hope three alice years began evil neither
# Topic 184:
#  call answer afraid alice side none evil got days half
# Topic 185:
#  together afraid bring wish morning young set death knew days
# Topic 186:
#  side young marianne elinor brought soon hands offering peace seen
# Topic 187:
#  though set young days call heaven took afraid answer thousand
# Topic 188:
#  together law marianne gathered moses saith elinor took door night
# Topic 189:
#  young set call wish afraid marianne law knew moses elinor
# Topic 190:
#  wish knew bring side end set answer took evil seen
# Topic 191:
#  end alice seemed door set got brother woman moment true
# Topic 192:
#  wish knew city call together though whole half happy brother
# Topic 193:
#  answer knew haue sent brought offering round fire woman set
# Topic 194:
#  alice answer young sent city got knew law rather saith
# Topic 195:
#  end sent morning together thine answer knew thereof neither find
# Topic 196:
#  evil round sent call sight ahab seemed find light rather
# Topic 197:
#  though alice sent side morning whole round afraid bring saith
# Topic 198:
#  left round thine neither sent though call none heaven replied
# Topic 199:
#  sent left wish law end whole seemed afraid haue macian
# Topic 200:
#  alice side wish set thine neither evil offering whole saying
# Topic 201:
#  haue got round thine law none half knew keep hold
# Topic 202:
#  knew alice haue whole moment keep body find seemed hands
# Topic 203:
#  find thine wish left rather body haue door selah saith
# Topic 204:
#  thine heaven find knew half sent far high got mind
# Topic 205:
#  selah half heaven understand work mind answer neither sent far
# Topic 206:
#  got knew though left eyes work find alice call side
# Topic 207:
#  whole half left knew macian thine keep evil ship replied
# Topic 208:
#  got thine door sent keep far moment evil thus heaven
# Topic 209:
#  understand macian neither got replied saith find law anne saying
# Topic 210:
#  neither haue evil moses door alice work whole sent body
# Topic 211:
#  rather neither seemed got earth round thine help anne moses
# Topic 212:
#  macian light got whole body law turned round began knew
# Topic 213:
#  macian moment help thine rather half none work law though
# Topic 214:
#  neither seemed ahab none moment got replied ship fear work
# Topic 215:
#  help whole neither keep heaven none work door boy marianne
# Topic 216:
#  understand ahab macian keep work began boy thine haue moses
# Topic 217:
#  keep neither bear rather heaven jerusalem buster macian body mind
# Topic 218:
#  heaven got none saith replied moses evil light whole haue
# Topic 219:
#  rather half light ahab law fear door haue neither white
# Topic 220:
#  work moment light gold mind understand spirit law thine door
# Topic 221:
#  fear moment heaven peace find round left boy hold anne
# Topic 222:
#  body ship spirit mind rather fear heaven help saith else
# Topic 223:
#  bear buster ship keep years understand heaven work help mouth
# Topic 224:
#  far light keep mind years saith work however full boy
# Topic 225:
#  ship seemed haue evil fire boy neither law full sight
# Topic 226:
#  help body fear light far moses bear understand jerusalem hold
# Topic 227:
#  fear spirit happy seemed work keep high stood far priest
# Topic 228:
#  mind happy neither ahab help door perhaps ship high whole
# Topic 229:
#  moment light fire mind help thereof find happy forth spirit
# Topic 230:
#  ship peace far gave none hold rather jerusalem judah door
# Topic 231:
#  happy peace light hold thereof body seemed half forth child
# Topic 232:
#  mind none seemed ship thereof light began eat half fear
# Topic 233:
#  fear happy bear haue light ship gave offering buster law
# Topic 234:
#  gave perhaps new seemed spirit fire keep years louisa child
# Topic 235:
#  began perhaps gave louisa new forth light stood water high
# Topic 236:
#  perhaps high light priest child years understand none fear else
# Topic 237:
#  perhaps forth fire body far mouth child moment thereof else
# Topic 238:
#  child gave stood high priest body turned rest louisa years
# Topic 239:
#  perhaps thereof stood began however ahab spirit louisa far according
# Topic 240:
#  child began ask however fear new water high blood louisa
# Topic 241:
#  mouth gave high thereof elinor began however priest back harriet
# Topic 242:
#  louisa high priest ahab leave marianne till hold thereof fire
# Topic 243:
#  new thereof full praise years elinor louisa sing according sight
# Topic 244:
#  turned marianne gave thereof gold far priest ask began high
# Topic 245:
#  turned however elinor mouth aside full wicked blood certainly perhaps
# Topic 246:
#  however pass new fire marianne leave years high forth sort
# Topic 247:
#  ask forth leave rest mouth ahab according offering full room
# Topic 248:
#  qu mad laertes fin turned de louisa duke praise elinor
# Topic 249:
#  ask blood water leave white whether door forth captain peace
# Topic 250:
#  part stood blood mouth however wicked best leave water rest
# Topic 251:
#  anne however marianne blood home stood pass elliot full ahab
# Topic 252:
#  full pass harriet gold marianne louisa moses got given praise
# Topic 253:
#  ask stood else louisa anything new hold rory whether spirit
# Topic 254:
#  blood harriet forth however according gave marianne priest sight heaven
# Topic 255:
#  pass blood wicked best thereof ship peace light gave leave
# Topic 256:
#  part louisa light forth known work anne pass ask sort
# Topic 257:
#  harriet pass blood light ask hold till leave new thereof
# Topic 258:
#  rory john pass talbot laer anne song knightley leave else
# Topic 259:
#  full hold room wilt best high gave till whale st
# Topic 260:
#  best water certainly laer praise friends art anne reason evil
# Topic 261:
#  laer wicked part white new exit harriet louisa sort sword
# Topic 262:
#  else anything truth full talk certainly peace fire sight leave
# Topic 263:
#  best part else harriet moses fire anne blood gold white
# Topic 264:
#  sort according certainly wicked white home looking full given rest
# Topic 265:
#  certainly white leave home pass mouth part till remember according
# Topic 266:
#  certainly sort suppose sight truth blood fire art gold praise
# Topic 267:
#  hold mouth room white sight suppose best remember according leave
# Topic 268:
#  truth room leave peace remember servant water known suppose rory
# Topic 269:
#  sort suppose wilt thereof mouth st thou harriet gold anne
# Topic 270:
#  certainly wicked hold given anne righteous else forth water leave
# Topic 271:
#  amen sword peace art forth room mouth shalt hast certainly
# Topic 272:
#  amen suppose pass according truth praise glory till white hold
# Topic 273:
#  sort truth looking room best till fellow almost gold known
# Topic 274:
#  praise according sort sing live fire leave room bring glory
# Topic 275:
#  rest almost sight remember gold within felt sister certainly till
# Topic 276:
#  macd till suppose hold wicked forth known sin truth else
# Topic 277:
#  given run truth blood servant wilt master money sort praise
# Topic 278:
#  remember servant gold talk sight home turn master wicked whose
# Topic 279:
#  room praise almost remember suppose till certainly sing turn read
# Topic 280:
#  almost home remember rest hold friends whose run year known
# Topic 281:
#  remember talk till sort full white friends wheel evil rest
# Topic 282:
#  sight wicked whose servant almost thereof joy sister white daughter
# Topic 283:
#  turn aside rest sword live sight thereof known die white
# Topic 284:
#  turn almost given aside according leave live best servant power
# Topic 285:
#  sword run sight fall till elinor truth fellow anne die
# Topic 286:
#  servant master praise whose evil family sing blood rest whether
# Topic 287:
#  friends whose known john joy family caesar coming whether given
# Topic 288:
#  sister within run wheel sword praise john year according remember
# Topic 289:
#  run known friends joy wheel sight rory brown fight servant
# Topic 290:
#  ophe live given die known looking room wheel turned year
# Topic 291:
#  wheel live known given die room home looking year whether
# Topic 292:
#  wheel read please friends caesar letter sight thank brutus servant
# Topic 293:
#  wheel john talk whose knightley almost glory run aside turn
# Topic 294:
#  friends sister talk live please money run high die caesar
# Topic 295:
#  live run within money holy die brethren priest truth else
# Topic 296:
#  talk within read caesar sight friends john priest praise sword
# Topic 297:
#  sword friends priest please brown talk daughter sister felt jerusalem
# Topic 298:
#  read sister run live caesar letter die servant rest full
# Topic 299:
#  please known talk money john live fellow run room priest
# Topic 300:
#  looking year fellow brethren felt second wonder money whether almost
# Topic 301:
#  wonder brown looking run john praise servant whether full high
# Topic 302:
#  whose read brown daughter whether live wonder please caesar doubt
# Topic 303:
#  year joy second whether family read brown master john wonder
# Topic 304:
#  joy looking money glad read within high daughter business talk
# Topic 305:
#  fellow brown joy money glad feet friends thank anything kind
# Topic 306:
#  daughter money whether family doubt saul praise remember business boy
# Topic 307:
#  fellow glory power wherefore brown daughter christ honour caesar high
# Topic 308:
#  alone weston priest fellow looking daughter thank felt reason joy
# Topic 309:
#  family felt read thank coming reason money priest taken brown
# Topic 310:
#  fellow thank wonder caesar alone doubt whether felt reason weston
# Topic 311:
#  brethren daughter reason coming felt servants silence egypt knightley pharaoh
# Topic 312:
#  caesar brethren within joy wonder strong elton whose brutus family
# Topic 313:
#  caesar reason money coming silence next brutus live brown holy
# Topic 314:
#  family feet silence cast holy caesar year fell felt saul
# Topic 315:
#  alone wherefore felt family daughter wonder brethren thank saul read
# Topic 316:
#  next wonder reason stay business coming family almost fellow lucy
# Topic 317:
#  felt wonder next glory play power money silence elton read
# Topic 318:
#  sat alone brethren silence master glory power money cast brown
# Topic 319:
#  thank weston stay next business john glory looking doubt harriet
# Topic 320:
#  play coming family turn money looking master power holy fight
# Topic 321:
#  play silence holy stay wherefore felt brown master saul year
# Topic 322:
#  talb thank sat feet lucy aside daughter looking priest seven
# Topic 323:
#  stay lucy aside business glad master coming fellow brown four
# Topic 324:
#  cut coming wherefore else aside lucy cast aye glory priest
# Topic 325:
#  talb four silence coming fight business cut anything strong bad
# Topic 326:
#  wherefore stay next four talb cry saul taken joy servants
# Topic 327:
#  cast next felt lucy talb power fellow year doubt weston
# Topic 328:
#  four thank elton stay else power strong jane course coming
# Topic 329:
#  play four wonder business lucy glory taken anything wherefore reason
# Topic 330:
#  business cast elton priest fight turn strong reason feet wherefore
# Topic 331:
#  anything lucy elton aside cut thank fight money course power
# Topic 332:
#  stay aye second cast cut anything felt elton glad master
# Topic 333:
#  business sat wherefore next anything seven doubt kind family glad
# Topic 334:
#  master alone glory cut servants coming turn kind christ elton
# Topic 335:
#  wherefore master servants thank wonder coming die sat cast saul
# Topic 336:
#  taken next second lucy fight course holy fathers near aye
# Topic 337:
#  kind servants cut fight fathers whether glad wonder reason lucy
# Topic 338:
#  kind power servants strong aye jerusalem comes present colonel wherefore
# Topic 339:
#  taken sat saul servants whether turn stay holy ought near
# Topic 340:
#  aye lucy doubt kind saul cast fight return colonel glory
# Topic 341:
#  lucy power feet servants cut turn doubt fathers second play
# Topic 342:
#  aye whether wherefore master mad lucy fathers ought strange fall
# Topic 343:
#  cut aye joy sat reason doubt business stay daughter aside
# Topic 344:
#  master seven lucy second fight strong cry next hundred feet
# Topic 345:
#  mad second saul reason course cut present lucy thousand live
# Topic 346:
#  sat judah strong master lucy mad near garden tree wonder
# Topic 347:
#  aye servants glad strong wise christ aside judah sin whether
# Topic 348:
#  mad power seven fight taken strange small doubt hundred elton
# Topic 349:
#  taken cut glad kind sat jane strong mad lucy fairfax
# Topic 350:
#  die kind cry saul cut glad sing power four song
# Topic 351:
#  pol rome actor small strong praise taken jane wonder glad
# Topic 352:
#  sing seven strange song coming servants fathers family four saul
# Topic 353:
#  ant mad strong stay servants seven fathers wise feet ought
# Topic 354:
#  power taken live colonel ant master judah saul glad strange
# Topic 355:
#  colonel cry strong ought saul mad honour next seven priests
# Topic 356:
#  colonel cry mad jane sing judah christ cast brandon near
# Topic 357:
#  jane comes die fairfax ought seven churchill judah frank second
# Topic 358:
#  ought bad taken christ doubt present feel wrong flesh open
# Topic 359:
#  comes susan colonel strong glad taken strange die present small
# Topic 360:
#  servants near open course tree sing jesus song jane air
# Topic 361:
#  near strange course cast comes feel judah reason second ought
# Topic 362:
#  strange tree jerusalem die wise saul strong five family st
# Topic 363:
#  susan return kind taken hundred garden five second mad judah
# Topic 364:
#  cry comes wise saul christ fathers feel others course died
# Topic 365:
#  course die present seven lost susan priests fall kind chief
# Topic 366:
#  strange bad fast fish gods cry praise certain wrong susan
# Topic 367:
#  return lost strong strange egypt cause sin sing open colonel
# Topic 368:
#  bad sin wise present feel near spake saul egypt comes
# Topic 369:
#  small lost near priests christ certain chief feel ought de
# Topic 370:
#  wise small ought fool susan jane wisdom stubb eye sing
# Topic 371:
#  lost fast fall fish taken wise landlord open judah comes
# Topic 372:
#  fast return fish faith christ course spoken present seven ought
# Topic 373:
#  present cause others strange wise return second flesh spoken fool
# Topic 374:
#  present course garden sword faith hundred honour least lost certain
# Topic 375:
#  honour de grey open faith fall comes country st dr
# Topic 376:
#  course return bad garden certain cause feel christ family comes
# Topic 377:
#  landlord course stop strong sin exit de honour grey talbot
# Topic 378:
#  landlord exit open egypt lost return flesh talbot near jacob
# Topic 379:
#  spoken lost bad follow least wise seven near present egypt
# Topic 380:
#  least honour lay landlord seven bed feel thousand tree sing
# Topic 381:
#  small fall faith course certain spoken blessed follow five landlord
# Topic 382:
#  faith passed cecilia priests exclaimed certain spoken feel manner chief
# Topic 383:
#  lay faith wilt open present return knightley ought sun tree
# Topic 384:
#  honour fall cause knightley bless walk fast flesh seven ought
# Topic 385:
#  lost faith tree blessed fell return landlord feel priests sin
# Topic 386:
#  certain st air feel flesh lay wise knightley churchill open
# Topic 387:
#  lay others feel st ready cecilia wrong fall sun mary
# Topic 388:
#  feel fall least faith idea blessed dr jacob grey de
# Topic 389:
#  honour feel air flesh st small die christ open power
# Topic 390:
#  bless least country sun returned idea ought blessed fall evening
# Topic 391:
#  least others blessed eye mercy manner fell five sun air
# Topic 392:
#  flesh walk blessed ready spoken others garden follow bless stubb
# Topic 393:
#  bless certain spoken fell wilt stop wrong mary sun tree
# Topic 394:
#  cause grey de manner walk country blessed fine judgment knightley
# Topic 395:
#  st cecilia blessed open exclaimed mary stop dr return leonora
# Topic 396:
#  others ready woe walk egypt wilt behind dr hundred passed
# Topic 397:
#  bless others mary st feet eye letter egypt fish red
# Topic 398:
#  spake lay blessed letter manner flesh honour fall country jacob
# Topic 399:
#  wrong dr bull bless nay exit st returned gods black
# Topic 400:
#  cause flesh mary others egypt dr priests st faith stop
# Topic 401:
#  exit stubb fathers faith churchill talbot country frank nay letter
# Topic 402:
#  tree wrong flesh feet cecilia blessed stop saul mercy egypt
# Topic 403:
#  exit fell bless wrong blessed garden egypt wilt bread spake
# Topic 404:
#  ready bless five fell faith exit ground tree manner flesh
# Topic 405:
#  exit sun cecilia evening spake manner passed exclaimed fall mary
# Topic 406:
#  manner stop five spake walk exit honour follow gentleman dr
# Topic 407:
#  spake evening stop garden others churchill wrong nay frank cecilia
# Topic 408:
#  mercy mary stop country others follow exit dr garden fast
# Topic 409:
#  follow sun bless flesh nay walk song least fell spake
# Topic 410:
#  mary nay evening wrong often manner woe tree spake follow
# Topic 411:
#  gods wrong letter air garden blessed gentleman manner flesh mighty
# Topic 412:
#  gods stubb returned spake spoken exit walk mercy white open
# Topic 413:
#  bless evening manner hundred mercy stop cause follow exit morrow
# Topic 414:
#  ready spake gods eye country stop knightley brutus feet manner
# Topic 415:
#  stop passed mary cause eye woe blessed ready flesh sun
# Topic 416:
#  rosin others gentleman knightley wrong care weston return read died
# Topic 417:
#  letter follow evening stop burs ready written returned spake tree
# Topic 418:
#  burs wrong manner died passed bed ready bless sun return
# Topic 419:
#  burs pretty gods often eye five cecilia red girl read
# Topic 420:
#  pretty walk passed often girl behind sit pleasure gods spake
# Topic 421:
#  pretty manner stubb woe blessed sun gods ready commanded garden
# Topic 422:
#  fine churchill bless mercy manner country woe frank sit strength
# Topic 423:
#  pretty often letter sorry bed pleasure bread written stop sun
# Topic 424:
#  woe walk spake wrong evening departed pretty red faith mercy
# Topic 425:
#  churchill frank eye manner wrong returned pretty fool ran walk
# Topic 426:
#  nay yea returned gentleman departed idea hour died air ready
# Topic 427:
#  sorry pleasure strength mary save walk died black certain wisdom
# Topic 428:
#  sorry nay fine mercy walk send bless stubb says wise
# Topic 429:
#  sorry bed pretty jacob drink commanded nay spake red black
# Topic 430:
#  air care send strength eye letter hard nay five ground
# Topic 431:
#  fine idea air stubb eye judgment departed walk passed white
# Topic 432:
#  bread bed country idea black ran nay manner boat kept
# Topic 433:
#  care bed returned bread fine fell blessed cecilia song manner
# Topic 434:
#  bed need air passed woe sorry send save cities congregation
# Topic 435:
#  care often jacob ran woe returned meet behind mary pleasure
# Topic 436:
#  sorry send often sit air need churchill frank flesh kept
# Topic 437:
#  pleasure died often departed hard cities brutus red gods fish
# Topic 438:
#  behind died fine song talbot idea blessed drink often professor
# Topic 439:
#  departed judgment gentleman judge sit sorry fine ran bread talbot
# Topic 440:
#  send save gentleman often idea care sun bread try fell
# Topic 441:
#  behind care sorry hard bread evening gods sing churchill air
# Topic 442:
#  need judgment pleasure judge fell departed priests judah black righteousness
# Topic 443:
#  rosse died often cities need jacob red bread walk says
# Topic 444:
#  rosse departed send song sit blessed fine ran drink morrow
# Topic 445:
#  hard talbot case fish idea jane returned ground black mercy
# Topic 446:
#  need pleasure rosse gentleman strength mighty departed red war idea
# Topic 447:
#  idea boat ran pretty care song sorry need blessed case
# Topic 448:
#  jacob strength fell song send morrow try abraham gentleman five
# Topic 449:
#  gentleman song air ran talbot bed become country along rosse
# Topic 450:
#  mar hard fish case forward returned red country eye song
# Topic 451:
#  idea pleasure red sit send judgment rosse jacob care behind
# Topic 452:
#  hour ground ran pretty died idea meet devil black along
# Topic 453:
#  song knightley hard pleasure cities bread red become least ground
# Topic 454:
#  brutus song save bread black sit jacob rosse hour died
# Topic 455:
#  hard red save mighty says congregation song written jacob tabernacle
# Topic 456:
#  returned send boat try red bread works along meet elliot
# Topic 457:
#  boat sit fool save departed caesar follow pleasure least fish
# Topic 458:
#  brutus wisdom queen boat drink kings devil professor written least
# Topic 459:
#  hour professor devil gentleman since hard boat queen silent says
# Topic 460:
#  queen fine stubb hard save send fast returned women girl
# Topic 461:
#  drink air sit wine pleasure black congregation tabernacle pretty yea
# Topic 462:
#  morrow try strength since devil says ground red save continued
# Topic 463:
#  person try devil professor morrow silent says become ran story
# Topic 464:
#  silent queen fool mighty song nature sweet judge letter judah
# Topic 465:
#  professor talbot strength hour boat morrow queen repeated war country
# Topic 466:
#  since drink party person written devil story waters kings repeated
# Topic 467:
#  devil strength says hamlet sit case gods continued story send
# Topic 468:
#  boat case continued silent become girl fast try brutus ground
# Topic 469:
#  kept professor devil talbot says continued war knightley sit send
# Topic 470:
#  case ground meet professor morrow mighty angel song cecilia person
# Topic 471:
#  hamlet meet case tis become kings written since kept boat
# Topic 472:
#  party talbot short wisdom continued cecilia fish queen devil silent
# Topic 473:
#  continued spoke waters hamlet yea gate person tis toward cecilia
# Topic 474:
#  exclaimed queen war kept says gate toward archer boat returned
# Topic 475:
#  silent morrow meet hard war girl fish story brutus yea
# Topic 476:
#  party yea silent person meet repeated talbot fast surely shew
# Topic 477:
#  continued yea suddenly since morrow spoke judge professor begat story
# Topic 478:
#  case kept professor girl suddenly wisdom story waters party happened
# Topic 479:
#  queen continued case hour fish arm walked meet along table
# Topic 480:
#  story hamlet girl says sweet angel talbot beautiful party judge
# Topic 481:
#  cask written party wait professor war silent fool judgment nay
# Topic 482:
#  cask hamlet mighty suddenly kept tis queen yea red says
# Topic 483:
#  cask meet dark yea become case wisdom shew green fish
# Topic 484:
#  happened short less war spoke fool dwell kept exclaimed means
# Topic 485:
#  meet continued hard surely story kept drink point la elliot
# Topic 486:
#  judge toward become cecilia suddenly ground happened elliot gate professor
# Topic 487:
#  become fool spoke story surely devil wanted wait short fast
# Topic 488:
#  become continued person morrow angel suddenly green spoke wait hamlet
# Topic 489:
#  happened begat says walked spoke silent meet wind wise landlady
# Topic 490:
#  fool angel along green arm tis judgment meet stubb walked
# Topic 491:
#  suddenly angel happened beautiful fool girl women judgment try says
# Topic 492:
#  begat continued la beautiful women kept person five fool party
# Topic 493:
#  become says landlady party repeated immediately field kingdom story followed
# Topic 494:
#  tis wise party green morrow queequeg used kill queen destroy
# Topic 495:
#  spoke beautiful meet suddenly devil la happened fool kingdom tis
# Topic 496:
#  happened surely devil green wait field tis queen beautiful queequeg
# Topic 497:
#  surely la arm shew dwell says judge means beautiful short
# Topic 498:
#  la become queen story case exclaimed tis less manner walked
# Topic 499:
#  tis angel shew landlady ground girl field kingdom wait followed
# Topic 500:
#  tis dwell field judge story queen person wait party green
# Topic 501:
#  angel queequeg kill story dark landlady strength nobody repeated kept
# Topic 502:
#  sleep beautiful walked women sweet says kingdom rose war surely
# Topic 503:
#  used kingdom wait story field repeated judge angel twenty free
# Topic 504:
#  wanted means field dwell war begat judgment repeated used times
# Topic 505:
#  short girl table surely kill queequeg followed angel waters arm
# Topic 506:
#  landlady repeated wanted living judge girl dark kill five means
# Topic 507:
#  shame arm table seek spoke pity times landlady dark repeated
# Topic 508:
#  landlady story sleep sweet short nobody everything means queen wanted
# Topic 509:
#  queequeg green wait angel suddenly kill gate field drink means
# Topic 510:
#  landlady less women free beautiful field dwell wait party nature
# Topic 511:
#  shew less begat table war field sake suddenly green times
# Topic 512:
#  dark wanted dwell free born point arm wait queequeg shame
# Topic 513:
#  girl repeated sweet dwell free sleep question talking devil born
# Topic 514:
#  walked war used suddenly rose five meet bed green followed
# Topic 515:
#  polon arm sweet free living try queequeg short sleep meet
# Topic 516:
#  polon used surely sleep along question arm five shame party
# Topic 517:
#  polon table nobody queequeg point beautiful wait possible struck repeated
# Topic 518:
#  polon landlady rose walked twenty wanted devil field dark living
# Topic 519:
#  point field less surely angel five walked mount along moses
# Topic 520:
#  arm dark repeated short field wanted waters landlady departed judgment
# Topic 521:
#  dark queequeg used twenty kill field ways iniquity written possible
# Topic 522:
#  means waters born along less queequeg shew shame nature women
# Topic 523:
#  rose living begat table yea free waters war twenty dark
# Topic 524:
#  point rose field question immediately sleep waters story mighty beautiful
# Topic 525:
#  wanted sake free surely question person short sweet table along
# Topic 526:
#  possible rose repeated along table beautiful shew sake mount worse
# Topic 527:
#  possible free nobody means shame meet broken wilt rose along
# Topic 528:
#  shame twenty girl field nobody short question pity point written
# Topic 529:
#  brut point shew arm girl kingdom commanded doth living question
# Topic 530:
#  worse broken talking question seek possible sleep opened along lo
# Topic 531:
#  means question possible kingdom arm doth living destroy green girl
# Topic 532:
#  used seek husband nobody commanded ran mighty question five table
# Topic 533:
#  nobody times wanted husband everything arm kingdom talking green wilt
# Topic 534:
#  added dark used living smile followed forget table field women
# Topic 535:
#  times nobody point promise talking seems beautiful short sweet free
# Topic 536:
#  nobody born seek twenty women along question sweet destroy kill
# Topic 537:
#  sleep women talking seek living free forward tis husband table
# Topic 538:
#  talking twenty means table added destroy wilt rose forget philistines
# Topic 539:
#  nobody seek queequeg means commanded lo less thoughts works starbuck
# Topic 540:
#  worse vain nature thoughts followed added times cities women seek
# Topic 541:
#  talking worse wind doth rose commanded queequeg surely dark try
# Topic 542:
#  noise possible question talking philistines sake laid shew try righteousness
# Topic 543:
#  philistines worse women nobody queequeg wanted sake noise cities sleep
# Topic 544:
#  husband laid worse kill point iniquity women ways sake waters
# Topic 545:
#  doth lo question broken iniquity wanted anger destroy born works
# Topic 546:
#  talking kill thinking nature wilderness waters immediately solomon possible archer
# Topic 547:
#  trust talking elliot nature wilt wind deliver opened sake born
# Topic 548:
#  sake doth promise lo try destroy dwell nobody added worse
# Topic 549:
#  noise free doth husband kingdom kill nature mount worse nobody
# Topic 550:
#  laid nobody archer doth sleep beautiful iniquity vain stone ten
# Topic 551:
#  nature women wilt seek sake queequeg loved use try dwell
# Topic 552:
#  doth works added possible seek queequeg forward waters immediately smile
# Topic 553:
#  thinking thoughts forget wilt noise born ways immediately nobody possible
# Topic 554:
#  noise archer works husband anger broken elliot trust sound nature
# Topic 555:
#  husband vain trouble elliot opened wilt smile sweet horse seek
# Topic 556:
#  trust husband worse promise works abraham solomon seek archer ashamed
# Topic 557:
#  forward noise laid anger opened starbuck doth times less loved
# Topic 558:
#  opened sake archer forget window doth wind kill rose women
# Topic 559:
#  lo archer thinking noise born mount tribe forward thoughts vain
# Topic 560:
#  forget lo either disciples dwell works waters free seek forgive
# Topic 561:
#  ill archer starbuck born either horse use change late opened
# Topic 562:
#  forget husband nature born ill towards worse wilderness horse forward
# Topic 563:
#  lo elliot opened destroy promise either thinking forward prophet large
# Topic 564:
#  ill vain noise thoughts ten promise shame starbuck change smile
# Topic 565:
#  use lo thinking works noise cities prophet change iniquity added
# Topic 566:
#  thinking trust forget broken husband late believed paul kings secret
# Topic 567:
#  forward horse lion philistines works received kings wilt towards worse
# Topic 568:
#  nature destroy lo prophet born loved means surely philistines woodhouse
# Topic 569:
#  ways lo pioneers alas forget disciples wilderness nations kings archer
# Topic 570:
#  forward either thoughts lo immediately change trouble broken forget towards
# Topic 571:
#  late six elliot solomon use forget low thoughts destroy loved
# Topic 572:
#  starbuck paul lo promise chief immediately philistines believed top large
# Topic 573:
#  starbuck change trust late prophet alas followed deal used towards
# Topic 574:
#  alas women trust wilderness born prophet immediately horse use times
# Topic 575:
#  times horse thinking elliot ill pity alas promise queequeg seek
# Topic 576:
#  change everything top kings alas hat women laid ill watch
# Topic 577:
#  change iniquity kingdom laid philistines forget times shame everything low
# Topic 578:
#  pioneers everything lion secret seem horse forward use wind ways
# Topic 579:
#  loved change horse use either large forward disciples destroy pioneers
# Topic 580:
#  pioneers trouble sometimes late pity speake ill low iniquity window
# Topic 581:
#  alas change vain pity late promise pioneers opened husband walked
# Topic 582:
#  pioneers seems alas vain anger able perfectly women covenant broken
# Topic 583:
#  pioneers large alas prophet ill solomon use lion secret destroy
# Topic 584:
#  trust anger sometimes speake added use sense mount change paul
# Topic 585:
#  alas pioneers sometimes thoughts trouble cometh loved wall horse excellent
# Topic 586:
#  alas loved everything lion iniquity either solomon fact speake received
# Topic 587:
#  loved seems prophet cometh hat goes promise kings ways ill
# Topic 588:
#  seems vain smile prophet disciples solomon forward sound perfectly line
# Topic 589:
#  trouble ways dare forward nature secret promise deal lion cometh
# Topic 590:
#  trouble secret lion kings sometimes iniquity pity opened use able
# Topic 591:
#  window prophet fact longer already sense either late beyond added
# Topic 592:
#  wall forward alas pity hat window able top goes trouble
# Topic 593:
#  sometimes wilderness hardly immediately kings either vain hamlet brutus ashamed
# Topic 594:
#  sometimes pity starbuck solomon window use watch pleased fact followed
# Topic 595:
#  either starbuck speake ill sound use secret loved smile ashamed
# Topic 596:
#  fact line sense sailor hat wilderness common promise pleased philistines
# Topic 597:
#  iniquity six fact cometh secret everything smile destroy hat horse
# Topic 598:
#  six ways lion struck late beginning seems trust month fact
# Topic 599:
#  low wilderness towards seems lion tribe pleased chief fact kings
# Topic 600:
#  window dare fact six pity wilderness smile loved forward large
# Topic 601:
#  fact smile able goes hat pleased sailor deliver trouble low
# Topic 602:
#  ashamed month righteousness ill six prophet enemies wilderness abraham hat
# Topic 603:
#  line sailor hardly thoughts goes town seed seems abraham secret
# Topic 604:
#  smile fair goes window able longer lo sailor excellent everything
# Topic 605:
#  ways towards town consider righteousness horse anger believed smile disciples
# Topic 606:
#  able line low six consider deal watch month lion received
# Topic 607:
#  town cometh excellent able francisco hat sense pleased low common
# Topic 608:
#  longer followed ways either wall angry turning able sailor town
# Topic 609:
#  excellent dare sailor goes pleased low disciples received wall starbuck
# Topic 610:
#  secret hair wall fair goes fact town able laugh beyond
# Topic 611:
#  late cometh pleased fair hardly dare lion seem sometimes hat
# Topic 612:
#  watch cometh fair vs abraham hardly seed trust low wilderness
# Topic 613:
#  hardly fact low fair trouble disciples laughing making prophet mount
# Topic 614:
#  town hair beginning dare enemies struck cometh smile rise sound
# Topic 615:
#  hat impossible smile struck speake longer sense laugh rise third
# Topic 616:
#  sound believed longer righteousness gate fair hat sometimes speake followed
# Topic 617:
#  sound altar goes able towards longer watch lion sometimes nations
# Topic 618:
#  beginning impossible immediately longer righteousness pharaoh disciples dream met born
# Topic 619:
#  line hair starbuck impossible received already mount sometimes window horse
# Topic 620:
#  watch pleased beginning sound mount pharaoh immediately large edward late
# Topic 621:
#  ashamed watch laugh midst longer beginning impossible egypt received pity
# Topic 622:
#  secret goes bare longer consider promise immediately enemies solomon meat
# Topic 623:
#  hair smile righteousness sailor paul either top ways th grace
# Topic 624:
#  sailor impossible fair ashamed able paul town seem dream th
# Topic 625:
#  midst fair beginning vs solomon struck bare lie covenant witness
# Topic 626:
#  impossible pleased struck seem town angry goes grace vs sense
# Topic 627:
#  beginning dare gate woodhouse struck hardly believed seeing perfectly low
# Topic 628:
#  sailor excellent midst chief already solomon fact sound watch towards
# Topic 629:
#  impossible excellent consider line dare hat watch able deliver town
# Topic 630:
#  laugh dream received secret month cold hardly laughing pharaoh th
# Topic 631:
#  speake pleased nations fair line believed midst low seems edward
# Topic 632:
#  pleased edward speake hardly wheeler perfectly laugh comfort consider knows
# Topic 633:
#  consider midst cometh secret nations ashamed sailor pharaoh francisco received
# Topic 634:
#  ashamed bare gate grace past nations trouble struck angry already
# Topic 635:
#  perfectly struck seeing francisco laugh sailor speake received piedro longer
# Topic 636:
#  dream excellent received pharaoh six believed wilderness longer goes knowledge
# Topic 637:
#  deal already chief seeing met past woodhouse comfort struck ashamed
# Topic 638:
#  edward ashamed dare seeing fair longer midst smile comfort horse
# Topic 639:
#  wall ashamed dream struck francisco believed speake late immediately princes
# Topic 640:
#  nations delivered believed bare deal mount month making met third
# Topic 641:
#  seem beyond edward watch consider received deal francisco knows break
# Topic 642:
#  vs dare francisco wood believed seems already heads company knows
# Topic 643:
#  already past consider laughing making dream longer edward wall pardon
# Topic 644:
#  perfectly met believed dream nations speake lie deliver bare seeing
# Topic 645:
#  midst perfectly righteous already low beginning laughing street paul gate
# Topic 646:
#  met th seem darkness hell angry covenant seeing tongue wilderness
# Topic 647:
#  pardon gentlemen beg met darkness perfectly believed comfort cold past
# Topic 648:
#  seem top willoughby farm hill struck early arose beyond met
# Topic 649:
#  already delivered farm seeing righteous seem nations wall early bare
# Topic 650:
#  comfort met bare top edward francisco knows cometh enemies hate
# Topic 651:
#  darkness farm francisco beyond woodhouse believed deliver enemies river vs
# Topic 652:
#  laughing third perfectly deal knows bare th excellent delivered pay
# Topic 653:
#  pardon beg cold deliver knows farm angry deal grace stone
# Topic 654:
#  met third midst peter grace speaking knowledge pay witness past
# Topic 655:
#  knows bare midst spirits gentlemen exactly woodhouse believed tears pardon
# Topic 656:
#  angry witness making cold consider receive th tears comfort hell
# Topic 657:
#  farm month comfort received dream righteousness gate hate knows lived
# Topic 658:
#  seeing willoughby pardon beg river laugh already madam beyond sound
# Topic 659:
#  grace darkness seem willoughby third company month married laughing deal
# Topic 660:
#  grace angry farm laughed meant hate iniquity top company frederick
# Topic 661:
#  farm th lie laughing already longer heads hell touch beyond
# Topic 662:
#  beyond angry farm early met tears third pardon edward beg
# Topic 663:
#  angry willoughby knows knowledge gentlemen touch real midst making stone
# Topic 664:
#  past willoughby knows righteous farm exactly lie th real rise
# Topic 665:
#  met dare witness grace chief hat laughing married thyself dream
# Topic 666:
#  spirits knowledge farm meant willoughby met delivered tears touch unclean
# Topic 667:
#  laughing knowledge comfort frederick pay consider watch early farm peter
# Topic 668:
#  break vs speaking tongue tears river covenant wheeler knows early
# Topic 669:
#  making woodhouse lie consider grace pharaoh bare fruit assure rise
# Topic 670:
#  past comfort righteous tears wheeler stone madam jews lie river
# Topic 671:
#  heads grace laughed touch righteous unclean turning arose heavens show
# Topic 672:
#  heads frederick jews company thyself temple knows tears perfectly hat
# Topic 673:
#  tears pardon knowledge angry speaking beg wood wheeler top turning
# Topic 674:
#  cold bare married lie peter vs hell farm wood forty
# Topic 675:
#  witness lie month speaking tongue already receive exactly struck forty
# Topic 676:
#  peter pardon receive darkness making righteous tongue beg knowledge top
# Topic 677:
#  knowledge righteous cold doctor sometimes deliver seem th caught thyself
# Topic 678:
#  dream company stone speaking jews wheeler heere tears iron tongue
# Topic 679:
#  making cold stone heavens lie thyself doctor wood arose nations
# Topic 680:
#  tears tongue wood meant madam laughed doctor bare clo seeing
# Topic 681:
#  turning jews gentlemen deliver dream pay thyself peter darkness dwelt
# Topic 682:
#  making witness meant cold seeing willoughby enemies gentlemen top thyself
# Topic 683:
#  rich tears delivered cold spirits darkness married river rise fancy
# Topic 684:
#  evan comfort angry third believed receive seeing heads hell met
# Topic 685:
#  lie angry hell rich married dwelt gentlemen able jews righteous
# Topic 686:
#  pay making visit rise caught tears lie chief laughed righteous
# Topic 687:
#  fruit company turning feelings hell caught desire righteous tongue real
# Topic 688:
#  forty feelings righteous heads tongue arose thyself reigned month dream
# Topic 689:
#  meant stone grace beyond madam witness catch vpon cold order
# Topic 690:
#  tongue heere receive rise vpon leonora frederick nations cold reigned
# Topic 691:
#  real leonora touch comfort delivered company caught forty wheeler enemy
# Topic 692:
#  turning evan meat clo dream th making knows standing close
# Topic 693:
#  knows vpon making account heere deliver meat iron held forty
# Topic 694:
#  feelings laughed ears delivered lie turning big spirits prophets twelve
# Topic 695:
#  street rich madam leonora nations woodhouse receive except vpon making
# Topic 696:
#  clo river married tongue iron th silver account pay comfort
# Topic 697:
#  exactly meat heads receive pay arose street church dwelt delivered
# Topic 698:
#  heavens flambeau hate feelings altar meat fruit big fancy rich
# Topic 699:
#  laughed evan real river twelve except princes blow wheeler married
# Topic 700:
#  married clo rich show flambeau knowledge hell comfort blow turning
# Topic 701:
#  clo feelings married spirits silver beyond wine heads everybody heavens
# Topic 702:
#  feelings heavens vpon show rise wood blow break twelve jews
# Topic 703:
#  clo touch madam heere twelve show ears real prophets stopped
# Topic 704:
#  doctor vpon thyself order willoughby except bare clo river frederick
# Topic 705:
#  real joseph feelings turning street frederick heere held assure righteous
# Topic 706:
#  fancy show ears horses luc company rise jews doctor plain
# Topic 707:
#  madam real exactly church jews heavens places clo arthur wine
# Topic 708:
#  account evan doctor meant church heads willoughby blow alive fruit
# Topic 709:
#  luc iron desire forgive jews serve leonora spirits dwelt account
# Topic 710:
#  frederick fancy hell leonora ears fruit rise human doctor touch
# Topic 711:
#  fancy street assure clo trees desire lifted twelve altar whales
# Topic 712:
#  flambeau princes wild madam receive number heavens show hate covenant
# Topic 713:
#  flambeau obliged close instant company street concerning different lie assure
# Topic 714:
#  assure stopped hell desire stone married prince concerning places catch
# Topic 715:
#  laughed meant cross woodhouse willoughby order jews places break feelings
# Topic 716:
#  laughed account perfect number clo mistaken leonora married order rise
# Topic 717:
#  mock deep turtle close fled rise church frederick street willoughby
# Topic 718:
#  street flambeau dwelt princes break rise altar doctor madam thyself
# Topic 719:
#  assure horses big receive close places thyself minute evan fancy
# Topic 720:
#  flambeau big luc talked madam meat account thyself show vpon
# Topic 721:
#  touch hell order rich twelve blow rise iron evan except
# Topic 722:
#  luc princes plain cubits daughters length married presence receive cross
# Topic 723:
#  arose trees cross standing rise company desire laughed vpon covenant
# Topic 724:
#  doctor fancy luc perfect obliged opinion stopped married beyond rise
# Topic 725:
#  flambeau perfect samuel seed obliged rich mock cloud ears witness
# Topic 726:
#  church fancy appeared serve break passage street fruit laugh seed
# Topic 727:
#  luc pull comfort ears seed company feelings meat fancy number
# Topic 728:
#  hate serve vpon heavens enemy prophets worship battle march fancy
# Topic 729:
#  cross madam perfect held heere lifted gregory show heavens caught
# Topic 730:
#  show passage safe arose gathered wild number daughters fruit blow
# Topic 731:
#  pull obliged doctor assure close hill leonora lifted presence desire
# Topic 732:
#  luc caught march close hill stopped order blow host heavens
# Topic 733:
#  talked subject church perfect nonsense standing equal held prophets assure
# Topic 734:
#  rich arose standing worship concerning silver heere account feelings seed
# Topic 735:
#  show instant luc evan appeared hell talked passage street prophets
# Topic 736:
#  safe ears arthur whales leonora hate daughters except exactly temple
# Topic 737:
#  passage twelve forty show caught safe flambeau obliged princes stone
# Topic 738:
#  account cross blow shut meant street plain caught lifted fifty
# Topic 739:
#  forty dwelt cross pull instant blow touch big understanding bell
# Topic 740:
#  perfect desire lifted blow cook doctor abraham makes passage evan
# Topic 741:
#  whales appeared instant church hell trees obliged stopped enemy altar
# Topic 742:
#  forgive account safe wild exactly hell fled real beast horses
# Topic 743:
#  deep safe blow silver subject prophets cook appeared prince killed
# Topic 744:
#  passage general hill princes stopped church mark touch desire big
# Topic 745:
#  order enemy passage blow gregory stopped joe witness equal trees
# Topic 746:
#  catch minute different seed leonora thunder temple alive difference wood
# Topic 747:
#  standing mark hate obliged concerning multitude papa number meat wrath
# Topic 748:
#  equal safe ears talked fat lifted appeared mock different samuel
# Topic 749:
#  enemy prince blow fled battle stone mistaken except church general
# Topic 750:
#  dinner twelve looks deep doctor alive broke cloud thunder greater
# Topic 751:
#  mock turtle passage standing blow mistaken worship human forgive ears
# Topic 752:
#  minute held mistaken prophets fled dinner equal bell arise alive
# Topic 753:
#  cross passage cloud whales caught gathered rich desire horses places
# Topic 754:
#  catch passage ears mark became carried human gregory hate hurt
# Topic 755:
#  alive opinion subject desire order plain concerning human hurt flambeau
# Topic 756:
#  mock seed court march turtle killed ho marry daughters obliged
# Topic 757:
#  standing fled seed carried arthur ghost order mark ear cross
# Topic 758:
#  equal happiness papa flambeau wild forgive passage hate except number
# Topic 759:
#  whales arthur march temple dinner instant perfect arise presence enemy
# Topic 760:
#  alive silver age trees piedro everybody different touch smote hill
# Topic 761:
#  cloud fled real multitude obliged different lifted heads pull vpon
# Topic 762:
#  presence age march wild human mistaken enemies smith character cross
# Topic 763:
#  gregory standing state bow happiness delight delivered ho big everybody
# Topic 764:
#  safe talked broke ii hate feelings creature bell arthur mistaken
# Topic 765:
#  stopped lips pull presence standing shut horses ear human doors
# Topic 766:
#  enemy prince close human caught tone pull equal piedro smith
# Topic 767:
#  appeared arthur looks offer gregory guess big wine ii begin
# Topic 768:
#  gregory dinner worship daughters joseph ears opinion write gathered simple
# Topic 769:
#  enemy thunder gregory looks places makes killed princes samuel grass
# Topic 770:
#  minute killed became passage everybody quick silver toward rejoice lived
# Topic 771:
#  instant age delight dashwood noble quick simple stopped forty doctor
# Topic 772:
#  quick understanding mark aaron cloud ladies battle prince killed fat
# Topic 773:
#  aloud sick except bowed obliged fat dance presence imagine difference
# Topic 774:
#  doe happiness smith big ile concerning lifted number safe worship
# Topic 775:
#  papa mouse concerning looks order presence arthur hurt sky carried
# Topic 776:
#  clear samuel seed marry happiness stranger minute farmer guess worship
# Topic 777:
#  lived dinner marry taking plain guess fat instant begin different
# Topic 778:
#  cook march ho gregory sick pull sorrow lived papa plain
# Topic 779:
#  satisfied delight general human scena church gathered understanding dinner pip
# Topic 780:
#  worship taking arise aloud held standing carried minute host samuel
# Topic 781:
#  dwelt sunday mal welcome march stranger news common visit sitting
# Topic 782:
#  scena street looks prince sign lifted doors perfect fat arthur
# Topic 783:
#  quick visit begin dinner mouse aaron leonora ho makes subject
# Topic 784:
#  human desire lest marry court looks doe mistaken lifted blue
# Topic 785:
#  different aloud character prince cook offerings deep mistaken lest begin
# Topic 786:
#  thunder entered tried subject prince creature became whales makes box
# Topic 787:
#  foot minute giue human beast minutes except samuel ear lifted
# Topic 788:
#  ho giue clear ile killed sign presence scena makes wrath
# Topic 789:
#  creature scena broke common age bursal thunder begin gregory dwelt
# Topic 790:
#  blue boys worth lest news became ho opinion stopped bound
# Topic 791:
#  looks quick killed english charles stranger equal safe sign aloud
# Topic 792:
#  obliged hosts age equal pip drew creature ile news beast
# Topic 793:
#  welcome mal scena meat clear except selfe bow subject mistaken
# Topic 794:
#  curious instant sick ladies sitting difference quick pip tried sorrow
# Topic 795:
#  pip carriage plain held smith stranger smote sky service ear
# Topic 796:
#  cook human foolish nonsense lips mountains fond mal shut assure
# Topic 797:
#  giue nonsense blind aloud instant mistaken equal clothes speech police
# Topic 798:
#  foot smote bound mal poet sitting clear quick carry rejoice
# Topic 799:
#  opinion bow prince character filled supper speech stranger foot banq

# %% [markdown]
# #### Apply Random Forest

# %%
# X_test_lsa = svd.fit(X_test_tfidf)

# %%
X_train_lsa.shape
# Out:
# (73914, 800)

# %%
rf_lsa = RandomForestClassifier(class_weight="balanced")
rf_lsa.fit(X_train_lsa,y_train_lsa)
predict_lsa = rf_lsa.predict(X_test_lsa)
print('accuracy %s' % accuracy_score(predict_lsa,y_test_lsa))
print(classification_report(y_test_lsa, predict_lsa))
# Out:
# c:\python\python37\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# accuracy 0.5390453770598262
#               precision    recall  f1-score   support
#
#            0       0.46      0.63      0.53      4232
#            1       0.67      0.90      0.77      7583
#            2       0.12      0.05      0.07       107
#            3       0.34      0.16      0.22       692
#            4       0.45      0.31      0.37       259
#            5       0.50      0.24      0.32       419
#            6       0.37      0.33      0.35      3042
#            7       0.37      0.22      0.28      2470
#            8       0.45      0.29      0.35      2520
#            9       0.49      0.08      0.14       473
#           10       0.60      0.58      0.59      1790
#           11       0.38      0.13      0.19      1051
#
#     accuracy                           0.54     24638
#    macro avg       0.43      0.33      0.35     24638
# weighted avg       0.51      0.54      0.51     24638

# %% [markdown]
# ### Test Model

# %%
docs_new_lsa = ['Even before Miss Taylor had ceased to hold the nominal office of governess',
                'Piping down the valleys wild',
                   'How sweet is the Shepherd sweet lot!',
                 'From the morn to the evening he stays',
                  "The sun does arise, And make happy the skies;  The merry bells ring To welcome the Spring;The skylark and thrush"
               ]
X_new_counts_lsa = vectorizer.transform(docs_new_lsa)
X_new_tranform_tfidf = tfidf_transformer.transform(X_new_counts_lsa)
X_new_test_lsa = svd.transform(X_new_tranform_tfidf)


predicted_lsa = rf_lsa.predict(X_new_test_lsa)
predicted_lsa
# Out:
# array([ 7, 11,  2,  0,  0], dtype=int64)

# %%
counter  = 0
for doc, category in zip(docs_new_lsa, predicted_lsa):
    print('%r => %s' % (doc, id_to_author_name[category]))
    if(counter == 10):
        break
    counter += 1
# Out:
# 'Even before Miss Taylor had ceased to hold the nominal office of governess' => edgeworth
# 'Piping down the valleys wild' => whitman
# 'How sweet is the Shepherd sweet lot!' => blake
# 'From the morn to the evening he stays' => austen
# 'The sun does arise, And make happy the skies;  The merry bells ring To welcome the Spring;The skylark and thrush' => austen

# %% [markdown]
# ### Apply with LogisticRegression

# %%
logreg_lsa = LogisticRegression(n_jobs=1, C=1e5)
logreg_lsa = logreg_lsa.fit(X_train_lsa,y_train_lsa)
predict_lsa = logreg_lsa.predict(X_test_lsa)
print('accuracy %s' % accuracy_score(predict_lsa,y_test_lsa))
print(classification_report(y_test_lsa, predict_lsa))
# Out:
# c:\python\python37\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# c:\python\python37\lib\site-packages\sklearn\linear_model\logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# accuracy 0.5937576101956328
#               precision    recall  f1-score   support
#
#            0       0.56      0.74      0.63      4232
#            1       0.79      0.92      0.85      7583
#            2       0.33      0.01      0.02       107
#            3       0.41      0.10      0.16       692
#            4       0.76      0.14      0.23       259
#            5       0.69      0.08      0.15       419
#            6       0.42      0.50      0.46      3042
#            7       0.37      0.17      0.23      2470
#            8       0.53      0.42      0.47      2520
#            9       0.56      0.12      0.20       473
#           10       0.44      0.70      0.54      1790
#           11       0.39      0.11      0.17      1051
#
#     accuracy                           0.59     24638
#    macro avg       0.52      0.33      0.34     24638
# weighted avg       0.57      0.59      0.56     24638

# %% [markdown]
# ### Conclusion
#
# > This data work not really well wwith LSA

# %% [markdown]
# # 9. Build LDA model

# %% [markdown]
# ## rebuild bag of word model

# %%
len(corpus)
# Out:
# 98552

# %%
print(corpus[:6])
# Out:
# ['emma jane austen', 'volume', 'chapter', 'emma woodhouse handsome clever rich comfortable home happy disposition seemed unite best blessings existence lived nearly twenty one years world little distress vex', 'youngest two daughters affectionate indulgent father consequence sister marriage mistress house early period', 'mother died long ago indistinct remembrance caresses place supplied excellent woman governess fallen little short mother affection']

# %%
vectorizer2 = CountVectorizer(analyzer='word',       
                             min_df=20,                        # minimum reqd occurences of a word 
                             stop_words='english',             # remove stop words
                             lowercase=True,                   # convert all words to lowercase
                             token_pattern='[a-zA-Z0-9]{3,}',  # num chars > 3
                             # max_features=50000,             # max number of uniq words
                            )

data_vectorized = vectorizer2.fit_transform(corpus)

# %%
data_vectorized.shape
# Out:
# (98552, 5858)

# %% [markdown]
# ## Check Sparsicity
#
# Sparsicity is nothing but the percentage of non-zero datapoints in the document-word matrix,

# %%
# Materialize the sparse data
data_dense = data_vectorized.todense()

# Compute Sparsicity = Percentage of Non-Zero cells
print("Sparsicity: ", ((data_dense > 0).sum()/data_dense.size)*100, "%")
# Out:
# Sparsicity:  0.1209261558372402 %

# %%
from sklearn.decomposition import LatentDirichletAllocation
import random

# %%
data_vectorized.shape
# Out:
# (98552, 5858)

# %%
downsample_train_data_features_bow, downsample_train_data_features_bow2 = train_test_split(data_vectorized, test_size=0.50,random_state=123)

# %%
downsample_train_data_features_bow.shape
# Out:
# (49276, 5858)

# %% [markdown]
# ### GridSearch the best LDA model

# %%
# Define Search Param
search_params = {'n_components': [10, 15, 20, 25], 'learning_decay': [.5, .7, .9]}

# Init the Model
lda = LatentDirichletAllocation()

# Init Grid Search Class
lda_cv = GridSearchCV(lda, param_grid=search_params, n_jobs =7)

# Do the Grid Search
lda_cv.fit(downsample_train_data_features_bow)
# Out:
# c:\python\python37\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# GridSearchCV(cv='warn', error_score='raise-deprecating',
#              estimator=LatentDirichletAllocation(batch_size=128,
#                                                  doc_topic_prior=None,
#                                                  evaluate_every=-1,
#                                                  learning_decay=0.7,
#                                                  learning_method='batch',
#                                                  learning_offset=10.0,
#                                                  max_doc_update_iter=100,
#                                                  max_iter=10,
#                                                  mean_change_tol=0.001,
#                                                  n_components=10, n_jobs=None,
#                                                  perp_tol=0.1,
#                                                  random_state=None,
#                                                  topic_word_prior=None,
#                                                  total_samples=1000000.0,
#                                                  verbose=0),
#              iid='warn', n_jobs=7,
#              param_grid={'learning_decay': [0.5, 0.7, 0.9],
#                          'n_components': [10, 15, 20, 25]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %%
print("tuned hpyerparameters :(best parameters) ",lda_cv.best_params_)
# print("accuracy :",lda_cv.best_score_)
# Out:
# tuned hpyerparameters :(best parameters)  {'learning_decay': 0.5, 'n_components': 10}
# accuracy : -1181842.6081458465

# %% [markdown]
# ### Apply LDA

# %%
# Build LDA Model
lda_model = LatentDirichletAllocation(n_components=10,               # Number of topics
                                      learning_decay = 0.5,
                                      max_iter=10,               # Max learning iterations
                                      learning_method='online',   
                                      random_state=100,          # Random state
                                      batch_size=128,            # n docs in each learning iter
                                      evaluate_every = -1,       # compute perplexity every n iters, default: Don't
                                      n_jobs = -1,               # Use all available CPUs
                                     )
lda_output = lda_model.fit_transform(data_vectorized)

print(lda_model)  # Model attributes
# Out:
# LatentDirichletAllocation(batch_size=128, doc_topic_prior=None,
#                           evaluate_every=-1, learning_decay=0.5,
#                           learning_method='online', learning_offset=10.0,
#                           max_doc_update_iter=100, max_iter=10,
#                           mean_change_tol=0.001, n_components=10, n_jobs=-1,
#                           perp_tol=0.1, random_state=100, topic_word_prior=None,
#                           total_samples=1000000.0, verbose=0)

# %% [markdown]
# ## Print 10 words for each topic

# %%
topic_words = {}
n_top_words = 10
vocab = vectorizer2.get_feature_names()
for topic, comp in enumerate(lda_model.components_):
    # for the n-dimensional array "arr":
    # argsort() returns a ranked n-dimensional array of arr, call it "ranked_array"
    # which contains the indices that would sort arr in a descending fashion
    # for the ith element in ranked_array, ranked_array[i] represents the index of the
    # element in arr that should be at the ith index in ranked_array
    # ex. arr = [3,7,1,0,3,6]
    # np.argsort(arr) -> [3, 2, 0, 4, 5, 1]
    # word_idx contains the indices in "topic" of the top num_top_words most relevant
    # to a given topic ... it is sorted ascending to begin with and then reversed (desc. now)    
    word_idx = np.argsort(comp)[::-1][:n_top_words]

    # store the words most relevant to the topic
    topic_words[topic] = [vocab[i] for i in word_idx]

# %%
for topic, words in topic_words.items():
    print('Topic: %d' % topic)
    print('  %s' % ', '.join(words))
# Out:
# Topic: 0
#   life, face, heart, body, war, nature, blood, best, work, past
# Topic: 1
#   earth, sea, death, whale, world, lord, eyes, air, white, stand
# Topic: 2
#   know, head, far, ship, ham, place, word, present, free, art
# Topic: 3
#   day, long, look, rest, came, water, days, women, comes, boat
# Topic: 4
#   thou, shall, thee, thy, time, heaven, till, things, tell, enter
# Topic: 5
#   come, said, let, hand, king, new, thought, hear, dead, mother
# Topic: 6
#   say, heard, voice, pass, sweet, true, stood, macb, away, return
# Topic: 7
#   men, little, way, saw, sun, thing, years, house, sing, right
# Topic: 8
#   man, old, night, like, love, high, round, land, forth, young
# Topic: 9
#   good, great, soul, god, haue, think, light, sight, close, end

# %%
lda_output.shape
# Out:
# (98552, 10)

# %%
# data['author_id'].shape

# %%
X_train_lda, X_test_lda, y_train_lda, y_test_lda = train_test_split(lda_output, data['author_id'],test_size=0.25,random_state=123)

# %% [markdown]
# ## Apply with LogisticRegression

# %%
logreg_lda = LogisticRegression(n_jobs=7, C=10)
logreg_lda = logreg_lda.fit(X_train_lda,y_train_lda)
predict_lda = logreg_lda.predict(X_test_lda)
print('accuracy %s' % accuracy_score(predict_lda,y_test_lda))
print(classification_report(y_test_lda, predict_lda))
# Out:
# c:\python\python37\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# c:\python\python37\lib\site-packages\sklearn\linear_model\logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# c:\python\python37\lib\site-packages\sklearn\linear_model\logistic.py:1544: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 7.
#   " = {}.".format(effective_n_jobs(self.n_jobs)))
# accuracy 0.35197662147901615
#               precision    recall  f1-score   support
#
#            0       0.25      0.43      0.32      4232
#            1       0.41      0.86      0.56      7583
#            2       0.00      0.00      0.00       107
#            3       0.00      0.00      0.00       692
#            4       0.00      0.00      0.00       259
#            5       0.00      0.00      0.00       419
#            6       0.25      0.07      0.12      3042
#            7       0.00      0.00      0.00      2470
#            8       0.22      0.01      0.02      2520
#            9       0.00      0.00      0.00       473
#           10       0.14      0.02      0.04      1790
#           11       0.00      0.00      0.00      1051
#
#     accuracy                           0.35     24638
#    macro avg       0.11      0.12      0.09     24638
# weighted avg       0.23      0.35      0.24     24638
# c:\python\python37\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# ## Test Model

# %%
docs_new_lda = ['Even before Miss Taylor had ceased to hold the nominal office of governess',
                'Piping down the valleys wild',
                   'How sweet is the Shepherd sweet lot!',
                 'From the morn to the evening he stays',
                  "The sun does arise, And make happy the skies;  The merry bells ring To welcome the Spring;The skylark and thrush"
               ]
X_new_counts_lda = vectorizer.transform(docs_new_lda)
lda_output_for_test = lda_model.fit_transform(X_new_counts_lda)

predicted_lda = logreg_lda.predict(lda_output_for_test)
# predicted_lsa
counter  = 0
for doc, category in zip(docs_new_lda, predicted_lda):
    print('%r => %s' % (doc, id_to_author_name[category]))
    if(counter == 10):
        break
    counter += 1
# Out:
# 'Even before Miss Taylor had ceased to hold the nominal office of governess' => bible
# 'Piping down the valleys wild' => bible
# 'How sweet is the Shepherd sweet lot!' => austen
# 'From the morn to the evening he stays' => shakespeare
# 'The sun does arise, And make happy the skies;  The merry bells ring To welcome the Spring;The skylark and thrush' => bible

# %% [markdown]
# ### Conclusion
#
#
# > The result is not as good as other models
